# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
encuesta = pd.read_excel('..\\Datos bkp\\Encuesta\\BASE MIL610 FEBRERO Encuesta 79.xlsx', header=1)

# %%
encuesta.shape
# Out:
# (354, 52)

# %%
encuesta.head(5)
# Out:
#                         Cliente         Proyecto  \
# 0         Andrea Belmar Vergara  Edificio Mil610
# 1  Raul Andres Fuentealba Godoy  Edificio Mil610
# 2        CLAUDIO LANDERO FLORES  Edificio Mil610
# 3                Rosse Chesta *  Edificio Mil610
# 4        Marcelo Muller Ramirez  Edificio Mil610
#
#                      Email cliente Telefonos de contacto Cliente    LLAMADO 1  \
# 0  Andreafernanda.belmar@gmail.com                      99422812    NO EXISTE
# 1               rfuentealba@udd.cl                   56965993262  NO CONTESTA
# 2         CLAUDIOLANDERO@GMAIL.COM                             /   SIN NUMERO
# 3             rosschesta@gmail.com                     964955552     CONTESTA
# 4         marcelomullerr@gmail.com                     961246350      APAGADO
#
#      LLAMADO 2    LLAMADO 3 SI / NO   P1           P2     ...       \
# 0    NO EXISTE    NO EXISTE      NO  NaN          NaN     ...
# 1     CONTESTA          NaN     NaN  NaN          NaN     ...
# ...

# %%
si_responde = encuesta[encuesta['SI / NO'] == 'SI']

# %%
si_responde.hist(figsize=(18,16))
plt.show()
