# %% [markdown]
# # 1.Collect Initial Data

# %%
import glob
import os
import numpy as np
import seaborn as sb
sb.set()
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %% [markdown]
# # 1 Cotización

# %%
cot_all = pd.read_excel('..\\..\\Datos\\cotizaciones_all.xlsx')
cot_all.head()
# Out:
#        ID    Fecha Cotizacion                    Medio Tipo de Medio  \
# 0  111502 2017-07-27 15:46:54  RECORRIDO POR EL SECTOR         Paseo
# 1  111611 2017-07-29 13:37:05               RECONTACTO    Recontacto
# 2  111629 2017-07-29 16:41:15  RECORRIDO POR EL SECTOR         Paseo
# 3  111766 2017-07-31 11:01:57               RECONTACTO    Recontacto
# 4  111794 2017-07-31 15:52:32  RECORRIDO POR EL SECTOR         Paseo
#
#           Proyecto          Etapa             Productos Presencial Remoto  \
# 0  Altos del Valle  ADV - Etapa 1         TB-104,Est-65         Si     No
# 1  Altos del Valle  ADV - Etapa 1  TA-302,Est-41,Bod-02         No     No
# 2  Altos del Valle  ADV - Etapa 1         TA-303,Est-01         Si     No
# 3  Altos del Valle  ADV - Etapa 1  TA-302,Est-41,Bod-06         No     No
# 4  Altos del Valle  ADV - Etapa 1         TA-604,Est-01         Si     No
#
#             Jefe Comercial        ...         Razon Social  Giro  \
# 0  Alejandra Pooley Flores        ...                  NaN   NaN
# 1  Alejandra Pooley Flores        ...                  NaN   NaN
# 2  Alejandra Pooley Flores        ...                  NaN   NaN
# 3  Alejandra Pooley Flores        ...                  NaN   NaN
# 4  Alejandra Pooley Flores        ...                  NaN   NaN
#
#    Nacionalidad  N° Grupo Familiar    Actividad Cargo Situacion Laboral  \
# 0           NaN                  3      Tecnico   NaN               NaN
# 1           NaN    Sin Información     Empleado   NaN               NaN
# 2           NaN                  3     Empleado   NaN               NaN
# 3       Chilena    Sin Información     Empleado     a   Sin Información
# 4       Chilena                  4  Profesional   NaN               NaN
#
#   Empleador Antiguedad Laboral          Profesión
# 0       NaN                0.0                NaN
# 1       NaN                0.0                NaN
# 2       NaN                0.0                NaN
# 3         a                1.0         Empresario
# 4       NaN                0.0  Constructor Civil
#
# [5 rows x 41 columns]

# %% [markdown]
# ### 2.1.Data Description Single File: Cotizacion

# %%
#Variables categoricas
def ver_atributo_categorico(df,col,limit=False,lim=10,log=False,hue=None,palette=None):
    l = df[col].unique().tolist()
    l_len = len(l)
    
    if log:
        print(l_len,l)
    
    sb.set_color_codes("muted")
    if limit:
        return sb.countplot(y=col, data=df, color="r", order=df[col].value_counts().index[:lim],hue=hue,palette=palette);
    else:
        return sb.countplot(y=col, data=df, color="r", order=df[col].value_counts().index[:l_len],hue=hue,palette=palette);

# %% [markdown]
# ## Categorical Exploration

# %%
ver_atributo_categorico(cot_all,'Medio')

# %%
ver_atributo_categorico(cot_all,'Proyecto')

# %%
ver_atributo_categorico(cot_all,'Tipo de Medio',lim=10,limit=True)

# %%
ver_atributo_categorico(cot_all,'Sexo')

# %%
ver_atributo_categorico(cot_all,'Remoto')

# %%
ver_atributo_categorico(cot_all,'Presencial')

# %%
ver_atributo_categorico(cot_all,'Region',lim=10,limit=True)

# %%
ver_atributo_categorico(cot_all,'Provincia',lim=10,limit=True)

# %%
ver_atributo_categorico(cot_all,'Comuna',lim=10,limit=True)

# %%
ver_atributo_categorico(cot_all,'Estado Civil')

# %%
palette=["C0","C1","C2"]
ver_atributo_categorico(cot_all,'Etapa',hue='Sexo',palette=palette)

# %%
ver_atributo_categorico(cot_all,'Actividad')

# %%
ver_atributo_categorico(cot_all,'N° Grupo Familiar')

# %%
ver_atributo_categorico(cot_all,'Cargo',limit=True,lim=40)

# %%
ver_atributo_categorico(cot_all,'Situacion Laboral')

# %%
ver_atributo_categorico(cot_all,'Nacionalidad')

# %%
ver_atributo_categorico(cot_all,'Antiguedad Laboral')

# %%
ver_atributo_categorico(cot_all,'Empleador',log=True, limit = True, lim=30)
# Out:
# 510 [nan, 'a', 'Norteamericano / USS / UDD', 'Cesfam Lautaro Caceres', 'BioForest S.A.', 'DGAC', 'ACCIONA agua', 'Constructora Aitue \xa0\xa0\xa0', 'Arrigoni Ing.Y Const. S.A', 'Soc. Transportes Maritimo Service Ltda', 'Traumatologico', 'Besalco MD Montajes', 'Management Solutions Limitada', 'Forestal Celco', 'Caufmann', 'Inmobiliaria Los Pellines S.A.', 'MOP', '*', 'DFV Ingeniería y Gestión', 'Clinical Service', 'Hospital de Tomé', 'Municipalidad de Penco', 'Sanatorio Aleman \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0', 'Huachipato', 'Catim', 'CAP \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0', 'Municipalidad de Lota', 'Banco Estado', 'SVTI', 'Forestal papelera concepción', 'H&M Hennes & Mauritz SPA', '.', 'Chilena Consolidada seguros generales', 'Sociedad Educacional Juan Bosco LTDA', 'DAEM Hualpen', 'Ausenco Chile LTDA', 'HOSPITAL CLINICO DEL SUR SPA', 'Corporación Adventista \xa0\xa0\xa0\xa0\xa0\xa0\xa0', '\xa0\xa0\xa0', 'Clinica Sanatorio Aleman', 'Camino del Agua', 'Luis Miranda', 'Codelco', 'colegio almondale lomas', 'tottus', 'hospital san vicente de arauco', 'north face', 'Comercializadora de productos viales ltda', 'Arauco', 'asmar', 'Constructora DUC', 'Banco Santander', 'Comercial Itahua Ltda.', 'Hospital Victor Rios Ruiz', 'Gestion Aitue S.A. \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0', 'Consultorio San Pedro Costa \xa0\xa0', 'Inversiones Los Colonos Ltda.', 'metro de santiago', 'ARMADA DE CHILE', 1, 'Jardin Tutumpi', 'servicio impuestos internos', 'Banco Chile \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0', 'Parques de Carriel S.A.', 'Siemens', 'Bata Chile S.A.', 'Aitue', 'Sociedad Educacional el Libertador LTDA', 'emca', 'Armada de Chile', 'Sociedad Latsague Ltda', 'Bioforest', 'Arauco SA', 'Constructora JCE S.A \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0', 'Hospital Coronel', 'DSD construcciones y montajes', 'LFI', 'Megasalud', 'seremi', 'Subsecretaria Educación Parvularia', 'Legal Publishing Ltda.', 'Banco chile', 'pendiente', 'Faret S.A.', 'Tarragona', 'BITUMIX S.A.', 'FLSmidth', 'Independiente', 'Tineos LTDA', 'Gestión Aitue', 'MADERAS CAMPANARIO LTDA', 'Sin empleador', 'Fosis', 'CARABINEROS DE CHILE', 'SERVICIO SALUD TALCAHUANO - FUNDACION LAS ROZAS', 'Municipalidad de Concepción', 'RKLO S.A.', 'MECVA S.A.', 'Sapu', 'Hospital Traumatologico', 'Construcciones y montajes com S.A', 'Bureau Veritas', 'Soc. Inversiones Unisur', 'Patricio Lagos y Compañía Servicio Jurídico', 'Ecore', 'Anco', 'No indicado', 'MASISA', 'acs', 'sin informacion', 'Celulosa Arauco y Constitución', 'Worley Parsons', 'Indpendiente \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0', 'BANCO ESTADO', 'Ejercito de Chile', 'Masisa', 'Agrosuper', 'Hospital Higueras', 'Universidad San Sebastián', 'Endesa', 'Poch y Asociados', 'constructora tres Alpes', 'UNIVERSIDAD ANDRES BELLO', 'Hispital Las Higueras', 'PDI', 'ASB Ingeniería y Construcción', 'Universidad del desarrollo', '\xa0\xa0', 'ARAUCO S.A', 'Banco Bice', 'Essbio', 'Constructora Moller Perez - Cotapos', 'Ninguno', 'Transportes Koyam \xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0', 'x', 'Inmobiliaria Valmar', 'Planta Termoeléctrica', 'Transelec S.A', 'Serema', 'Celulosa Arauco y Constitución S.A.', 'Clinica Universitaria', 'Gendarmería de Chile', 'Enap Refinerías', 'Victor Antonio', 'Policia De Investigaciones', 'AGROSUPER', 'Constructora Avatar ltda.', 'Dirección Regional de Gendarmeria', 'm', 'Sanatorio Alemán', 'Claro Vicuña Ingetal', 'Bechtel', 'Abengoa S.A.', 'Essbio S.A.', 'Nautronika Eirl', 'Bureau Veritas S.A', 'Geoprospec', 'cccc', 'SQM Industrial', 'Michelin Chile Ltda.', 'Inacap', 'Bago', 'no tiene', 'Vidrios Lirquén', 'Constructora Carrie ltda', 'Vigaflow S.A.', 'Frigorífico Osorno S.A.', 'SERGIO ESCOBAR', 'Fisco', 'Belsaco Construcciones S.A', 'Servicio de Salud de Talcahuano', 'JEJ ingenieria S.A.', 'Sin informacion', 'Terra Vial', 'CMR', 'Constructora EBCO', 'Servi ...

# %%
ver_atributo_categorico(cot_all,'Profesión',log=True, limit = True, lim=30)
# Out:
# 130 [nan, 'Empresario', 'Constructor Civil', 'Traductor e Interprete', 'Matrona', 'Odontólogo', 'Profesor', 'Ingeniería en Biotecnología', 'Otro', 'Ingeniero Eléctrico', 'Técnico en Construcción', 'Fonoaudiólogo', 'Diseño Industrial', 'Mecánico Industrial', 'Empleado Público', 'Enfermería', 'Ingeniero en Administración', 'Contador Auditor', 'Ingeniero Comercial', 'Ingeniero en Construcción', 'Ingeniero', 'Empleado', 'Agronomo', 'Prevencionista de Riesgos', 'Ingeniero Civil Química', 'Administrador', 'Ingeniero Civil Industrial', 'Nutrición y Dietética', 'Tecnólogo Médico', 'Abogado', 'Médico', 'Educadora de Párvulos', 'Administrador Público', 'Periodista', 'Ingeniero de Ejecución', 'Psicólogo', 'Arquitecto', 'Ingeniero Civil Electrónico', 'Ingeniero en Prevención de Riesgo', 'Ingeniero Civil Eléctrico', 'Vendedor', 'Pastor', 'Administración de Empresas', 'Administrativo', 'Docente', 'Ingeniero Agronomo', 'Trabajo Social', 'Ingeniero Biomédica', 'Dueña De Casa', 'Ingeniero Civil en Informática', 'Asistente Social', 'Técnico de Nivel Superior', 'Controlador de Tránsito Aéreo', 'Constructor', 'Contador', 'Ingeniero Civil', 'Ingeniero en Informática', 'Jubilado', 'Diseñador de Ambientes', 'Bioquimico', 'Diseñador Gráfico', 'Químico Farmaceutico', 'Independiente', 'Kinesiologo', 'Publicidad', 'Ingeniero Forestal', 'Ingeniero Civil Mecánico', 'Medico Veterinario', 'Ingeniero Ambiental', 'Oficial de Marina', 'Cirujano Dentista', 'Técnico Mecánico', 'Ciencias Políticas', 'Secretaria', 'Notario Público', 'Carabinero', 'Ingeniero en Industrias de la Madera', 'Transportista', 'Ingeniero Mecánico', 'Ingeniero en Ejecución Mecánica', 'Ingeniero en Ejecución Eléctrica', 'Peluquería', 'Proyectista', 'FFAA', 'Comerciante', 'Ingeniero en Minas', 'Geologo', 'Técnico', 'Ingeniero Civil en Biotecnología', 'Contador Técnico', 'Contratista', 'Técnico en Administración', 'Servicio Social', 'Analista de Sistemas', 'Técnico Jurídico', 'Ingeniero en Transporte Marítimo', 'Futbolista', 'Sociología', 'Ingeniero Civil Metalúrgico', 'Rubro Inmobiliario', 'Ejecutivo de Negocios', 'Empleado Bancario', 'Ingeniero en Administración de Empresas', 'Dibujante Proyectista', 'Estudiante', 'Topógrafo', 'Educador Diferencial', 'Técnico Agrícola', 'Biologo', 'Ingeniero en Ejecución Electrónica', 'Técnico en Electricidad', 'Contratista AITUE', 'Operador', 'Ingeniero Geomensor', 'Técnico en Enfermería', 'Técnico en Logística', 'Técnico en Electricidad Industrial', 'Visitador Médico', 'Oficial de Gendarmería', 'Microbiólogo', 'Técnico Forestal', 'Técnico Electrónico', 'Oceanografo', 'Ingeniero Estadístico', 'Auditor', 'Jefe de Tienda', 'Terapeuta Ocupacional', 'Jefe de Compra', 'Piloto', 'Ingeniero Naval']

# %%
ver_atributo_categorico(cot_all,'Tipo Cliente',log=True, limit = True, lim=20)
# Out:
# 3 ['Natural', 'Jurídico', nan]

# %%
#rows
df = cot_all
print("Filas: ",df.shape[0])
print("Columnas: ",df.shape[1])
print("Primer Registro: ",(pd.to_datetime(df['Fecha Cotizacion'].tolist()).min()))
print("Ultimo Registro: ",pd.to_datetime(df['Fecha Cotizacion'].tolist()).max())
print("Ruts Unicos: ",len(df['RUT'].unique()))
# Out:
# Filas:  16592
# Columnas:  41
# Primer Registro:  2013-08-19 16:58:26
# Ultimo Registro:  2018-05-22 13:42:53
# Ruts Unicos:  6184

# %% [markdown]
# ## Checking malformed values in attribute

# %%
f = plt.figure()
ver_atributo_categorico(cot_all,'Nombre', limit = True, lim=30)
f.savefig('img/nombre_check.png',bbox_inches='tight')

# %%
f = plt.figure()
ver_atributo_categorico(cot_all,'Apellido 1', limit = True, lim=30)
f.savefig('img/apellido1_check.png',bbox_inches='tight')

# %%
f = plt.figure()
ver_atributo_categorico(cot_all,'Apellido 2',log=True, limit = True, lim=5)
f.savefig('img/apellido2_check.png',bbox_inches='tight')
# Out:
# 1666 ['Ulloa', 'Torres', 'Manriquez', 'Martinez', 'Gajardo', 'l', '.', 'Campos', 'Fica', 'Pineda', 'Erle', 'Vega', 'Casanova', 'Villegas', 'Herrera', 'Rodriguez', 'Lopez', 'Oliva', 'Cabezas', 'Figueroa', 'Lobos', 'Sanchez', 'Becerra', 'Reyes', 'Miranda', 'Vergara', 'Marianjel', 'Acuña', '*', 'Paredes', 'Larenas', 'Seguek', 'Olivares', '-', 'Guzman', 'Molina', 'Opazo', 'Vilugrón', '..', 'Esparza', 'Vivanco', 'Silva', 'Brañas', 'Quiroga', 'Mora', 'Rojas', 'Nuñez', 'Lazo', 'Ortiz', 'Sandoval', 'Höger', 'Araya', 'Ramirez', 'Cadenas', 'Vera', 'Contreras', 'Hoffmann', 'Cartes', 'Mahuzier', 'Salaberri', 'Hernandez', 'Flores', 'Ilufin', 'Sorensen', 'Romero', 'Jara', 'Suazo', 'Orellana', 'Navarrete', 'Roman', 'Pinto', 'Cottet', 'Irribarra', 'Lecaros', nan, 'Mella', 'Arevalo', 'Aguilera', 'Rios', 'Bolados', 'Vallejos', 'Maldonado', 'Sanchéz', 'Neira', 'Castillo', 'carter', 'Bobadilla', 'Ortega', 'Avello', 'Carmona', 'Carvallo', 'Valenzuela', 'Revello', 'Adonis', 'Martínez', 'Cifuentes', 'Cabrera', 'Bernal', 'Manbran', 'Rawera', 'Toro', 'Esquivel', 'Manquel', 'Marchant', 'Andrade', 'Cardenas', 'Astorga', 'C', 'Ceballos', 'Fara', 'Araneda', 'Merino', 'Saavedra', 'L', 'Calbucoy', 'Bahamondes', 'Aravena', 'Muñoz', 'Soto', 'Mesas', 'QUINTANA', 'Peña', 'Del Valle', 'Salazar', 'Sepúlveda', 'Almendra', 'Padilla', 'Saez', 'Pelen', 'Morales', 'Baeza', 'Smith', 'Perez', 'Duran', 'Montecinos', 'Fernnadez', 'Castro', 'Quezada', 'Rivera', 'Gallardo', 'Pereira', 'Villagra', 'Roco', 'Sanhueza', 'Riquelme', 'Moscoso', 'Neewman', 'Arteaga', 'Vidal', 'Estai', 'sanzana', 'Beltran', 'oliveros', 'Gerra', 'Arriagada', 'Prieto', 'avila', 'Lewis', 'varas', 'Díaz', 'Pardo', 'Jimenez', 'Luengo', 'Fernandez', 'Rubilar', 'Anabalon', 'borzone', 'Velozo', 'betarcur', 'Serrano', 'vasquez', 'gonzalez', 'López', 'Fuentes', 'Medina', 'Caro', 'Fonseca', 'jara', 'Feris', 'Osorio', 'Wallace', 'Wilson', 'Altamirano', 'VERA', 'Fontalba', 'Ruiz', 'Cuevas', 'Alarcon', 'Rodríguez', 'Cuadra', 'mendoza', 'Vila', 'Garrido', 'Risopatrón', 'Pinochet', 'Nieto', 'salas', 'Gutierrez', 'Lagos', 'A', 'Cabalá', 'Bournas', 'Angulo', 'Bestagno', 'Martines', 'Coser', 'Moreno', 'Asenjo', 'Cespedes', 'Cassinelli', 'O´Reilly', 'Sepulveda', 'Erices', 'Garcia', 'Riffo', 'Elgart', 'S.', 'Sfeir', 'I.', 'Señor', 'Bieschke', 'Güell', 'Jequier', 'Campodonico', 'Dal Borgo', 'Menchaca', 'Laissle', 'Maass', 'R.', 'G', 'Partarrieu', 'Schovelin', 'Robin', 'Duque', 'Arellano', 'García', 'L.', 'Villalobos', 'Solis', 'P.', 'T.', 'Betancurt', 'Calzadilla', 'Blaña', 'Grant', 'Diez', 'Toledo', 'Vargas', 'Oneto', 'Zarges', 'San Martin', 'Matus', 'Pavon', 'Mendez', 'Navarro', 'PLAZA DE LOS REYES', 'Palacios', 'Landa', 'Igesias', 'Pantoja', 'Yasin', 'Concha', 'Salinas', 'Beckdorf', 'Yañez', 'Aldunate', 'lavado', 'Vacaresa', 'Santibañez', 'Saldias', 'Voglio', 'Hansens', 'Madson', 'Chiang', 'Carillo', 'Bertin', 'K', 'G.', 'Hazboun', 'Rosello', 'A.', 'WACHSMANN', 'Gredillas', 'Avendaño', 'Cortez', 'Cuevaz', 'Quilodran', 'BANCALARI', 'Germany', 'Careaga', 'Adauy', 'Carrasco', 'Jaña', 'Yerkovic', 'Marin', 'Palma', 'Hidalgo', 'Bordagorry', 'Vasquez', 'Zanzi', 'SAndoval', 'Escalona', 'Alvarez', 'Diaz', 'Munita', 'Bavestrello', 'Worner', 'Sánchez', 'Barrios', 'Pérez', 'Arrieta', 'Assef', 'jimenez', 'Laucirica', 'Villagran', 'Spencer', 'Islas', 'Villagrán', 'Liapiz', 'Cares', 'Petrescu', 'meza', 'Giacaman', 'San Jose', 'Farfan', 'Gatica', 'Salas', 'Levasier', 'Pizarro', 'Robles', 'Ibieta', 'Rodas', 'Belmar', 'Jofre', 'Gonzalez', 'Villaseñor', 'Salgado', 'Aguayo', 'Enríquez', 'Reese', 'Pucheu', 'Albrecht', 'Rivas', 'Olave', 'Acevedo', 'x', 'MAUDIER', 'Mandiola', 'Maudier', 'Chacon', 'Sazo', 'Henriquez', 'Alarcón', 'Leiva', 'Jeria', 'neuber', 'millan', 'Melin', 'Poch', 'Arias', 'Astete', 'atik', 'Buchon', 'Zeller', 'Ahumada', 'Feliu', 'Gomez', 'caceres', 'Catalán', 'M', 'spano', 'Fernanadez', 'Ravanal', 'Chamal', 'sepulveda', 'vergara', 'Olivarria', 'Stromback', 'Barrera', 'Roa', 'Espinoza', 'Bellolio', 'Picini', 'Binimelis',  ...

# %%
f = plt.figure()
ver_atributo_categorico(cot_all,'Telefono', limit = True, lim=10)
f.savefig('img/telefono_check.png',bbox_inches='tight')

# %%
f = plt.figure()
ver_atributo_categorico(cot_all,'Celular',log=True, limit = True, lim=5)
f.savefig('img/celular_check.png',bbox_inches='tight')
# Out:
# 6038 [953748134, 76374699, 968441156, 2990590, 981372543, 90834457, 958295551, 995072841, 92449494, 942522023, 984192601, 98836621, 956181171, 85480235, 92493350, 968960554, 991280936, 988894560, 94007891, 956282212, 991299568, 988289650, 979575691, 95209394, 993118503, 88305206, 98873258, 95123765, 999684600, 962374072, 93206658, 98446361, 982314411, 987367733, 9981556548, 52080367, 76694924, 994698200, 981496410, 78995130, 950702404, 93090821, 2225841, 964427332, 994486955, 57568731, 981987470, 992953522, 97955039, 975361247, 74540483, 998279335, 987690273, 982085008, 77934502, 990938143, 998472754, 95990362, 974771402, 974878745, 950196206, 982347427, 964328618, 991390292, 961611186, 65991253, 98717377, 981385833, 942051491, 998847907, 942132618, 996412302, 956787113, '+56 9 61227693', 998950598, 99697471, 86651069, 982788710, 95395290, 82344634, 993443523, 89711239, 99999999, 99496404, '+56 9 75181074', 956675683, 990604760, 92749284, 968989297, 99356039, 98760877, 82995455, 981902687, 991014039, 956315361, 989711239, 996772931, 942876489, 81573006, 99915628, 972044985, 71392911, 992651828, 931214946, 93177792, 974783582, 990788440, 98221429, 82104297, 954008529, 66078380, 76672866, 62183646, nan, 991583190, 978468848, 57981059, 73612187, 96162192, 996620767, 942508323, 954162662, 991629658, 86840125, 97994458, 65748382, 96790291, 90015364, 98219775, 984578611, 988013751, 953710217, 2748824, 996730548, 996387254, 989023713, 76997826, 974797092, 56688038, '569-88947532', 998896667, 84433280, 987784010, 412552423, 992992018, '.', 984516068, 991298312, 950483817, 963724415, 89449618, 998739772, 93463853, 942306431, 967759098, 979629232, 77505124, 77310780, 66097842, 984796877, 983618925, 94792475, 997169117, 971354767, 998684570, 967107476, 985512426, 984331102, 997795806, 93453813, '+56 9 88058014 \xa0\xa0', 93695189, 84373281, 944145956, 94455046, 82943120, 977489640, 972542584, 982678576, 972705817, 944043887, 956701399, 990666215, 994527187, 999381208, 982982713, '+56 9 98831604', 962274238, 953962910, 99198805, 79391436, 961409489, 82920995, 991342334, 91906049, 942633318, '975487051 mariela fonseca', 994008350, 996302425, 94377175, 942741531, 950644281, 963063206, 962418235, 961257423, 82102129, 981463229, 957899894, 981694116, 942708368, 997913362, 977643614, '981378430 2797042', 975647671, 984621790, 968982793, 995121418, 962360386, 977571289, 976156073, 932434904, 81881127, 994338486, 997966055, 974911746, 952562146, 979599682, 985485312, 995063653, 996897911, 99910287, 988672640, 942966705, 979096084, 98373903, 979794496, 976942945, 956613430, 976541814, 993188511, 988681492, 977122799, 984225571, '17677360-k', 984388111, -75580900, '...', 75499236, 961918400, 984897732, '+56 9 95180595 \xa0\xa0', 962035471, 978026325, 75290615, 9318454, 87683514, 94451051, 56675624, 98857757, 94365636, 99179327, 94194207, 99691731, 412341211, 982072089, 79791733, 979093212, 91656600, 72135157, 99990247, 96386363, 985670937, '41-2224071', 84365518, 84091769, 99338401, 412135279, 98844317, 992590325, 94491560, 982297510, 985493164, 81886442, 984581077, 942825199, 984197307, 93215875, 998187621, 978092945, 981887143, 997456932, 85960451, 993199505, 973897590, 995381021, 992897615, 82899894, 98864566, 99917805, 99394046, 98831908, 2791120, 98447473, 93439502, 54125575, 98957701, 82025839, 96716411, 92194216, 81498467, 90876560, 76670304, 82594604, 87290329, 'not-yet', 93138648, 0, 98851151, 95462262, 2225708, 86130463, 75698905, 987763805, 98739539, 62060827, 79453436, 96923648, 94891822, 94506722, 98402326, 985295113, 98253663, 993095640, 981595808, 99053193, 994994843, 989949444, 90472076, 998868928, 942444656, 982992359, 90993413, 987312263, 966779440, 998731229, 977590995, 995512527, 998856789, 65381790, 973993607, 984299862, 988995143, 965943382, 992220684, 968396348, 982280697, 979580756, 998713064, 968473020, 962388535, 985272601, 974959031, 98255565, 966674099, 963711357, 993187947, 971070765, 998182778, 90341536, 978888765, 96 ...

# %%
f = plt.figure()
ver_atributo_categorico(cot_all,'Nombre Completo', limit = True, lim=40)
f.savefig('img/nombrecompleto_check.png',bbox_inches='tight')

# %% [markdown]
# # 3.Explore Data

# %% [markdown]
# ### 3.1.Explore Data: Single File Cotizacion

# %%
print("Cot rut promedio: ",get_col_group_description(df,'RUT')['mean'])
print("Cot rut desviacion: ",get_col_group_description(df,'RUT')['std'])
print("Cot por rut maximo: ",get_col_group_description(df,'RUT')['max'])
# Out:
# Cot rut promedio:  2.683053040103493
# Cot rut desviacion:  2.6119688668842644
# Cot por rut maximo:  45

# %% [markdown]
# ### 2.4.Describe Data Combined Files: Negociacion

# %%
neg_all = pd.read_excel('..\\..\\Datos\\negocios_all.xlsx')
neg_all.head()
# Out:
#       ID        Fecha Cotizacion  ID Cotizacion                    Medio  \
# 0  42212 2017-07-27 15:46:58.750         111502  RECORRIDO POR EL SECTOR
# 1  42242 2017-07-29 13:42:09.993         111611               RECONTACTO
# 2  42263 2017-07-31 11:02:25.760         111766               RECONTACTO
# 3  42379 2017-08-11 16:07:40.227         112677               RECONTACTO
# 4  42382 2017-08-11 16:13:46.600         112680               RECONTACTO
#
#   Tipo de Medio         Proyecto          Etapa             Productos  \
# 0         Paseo  Altos del Valle  ADV - Etapa 1         TB-104,Est-65
# 1    Recontacto  Altos del Valle  ADV - Etapa 1                TA-303
# 2    Recontacto  Altos del Valle  ADV - Etapa 1  TA-302,Est-41,Bod-06
# 3    Recontacto  Altos del Valle  ADV - Etapa 1  Bod-01,TA-301,Est-26
# 4    Recontacto  Altos del Valle  ADV - Etapa 1         Est-17,Est-18
#
#             Jefe Comercial      Ejecutivo Comercial     ...      Razon Social  \
# 0  Alejandra Pooley Flores  Graciela Pareja Cancino     ...               NaN
# 1  Alejandra Pooley Flores          Lilian Harrison     ...               NaN
# 2  Alejandra Pooley Flores          Lilian Harrison     ...               NaN
# 3  Alejandra Pooley Flores          Lilian Harrison     ...               NaN
# 4  Alejandra Pooley Flores          Lilian Harrison     ...               NaN
#
#    Giro  Nacionalidad N° Grupo Familiar    Actividad       Cargo  \
# 0   NaN           NaN                 3      Tecnico         NaN
# 1   NaN           NaN   Sin Información     Empleado         NaN
# 2   NaN       Chilena   Sin Información     Empleado           a
# 3   NaN       Chilena                 5  Profesional     Matrona
# 4   NaN       Chilena   Sin Información  Profesional  Odontologo
#
#   Situacion Laboral               Empleador Antiguedad Laboral   Profesión
# 0               NaN                     NaN                0.0         NaN
# 1               NaN                     NaN                0.0         NaN
# 2   Sin Información                       a                1.0  Empresario
# 3       Dependiente                     NaN                1.0     Matrona
# 4       Dependiente  Cesfam Lautaro Caceres                5.0  Odontólogo
#
# [5 rows x 49 columns]

# %%
ver_atributo_categorico(neg_all,'Estado Civil')

# %%
ver_atributo_categorico(neg_all,'Etapa')

# %%
ver_atributo_categorico(neg_all,'Proyecto')

# %%
ver_atributo_categorico(neg_all,'Estado Comercial',log=True)
# Out:
# 3 ['Normal', 'Desistimiento', 'Resciliacion']

# %%
ver_atributo_categorico(neg_all,'Estado',log=True)
# Out:
# 5 ['Anulada', 'Promesado', 'Reservado', 'Escriturado', 'Entregado']

# %%
ver_atributo_categorico(neg_all,'Medio')

# %%
ver_atributo_categorico(neg_all,'Tipo de Medio',limit=True,lim=10)

# %%
#rows
df = neg_all
print("Filas: ",df.shape[0])
print("Columnas: ",df.shape[1])
print("Primer Registro: ",(pd.to_datetime(df['Fecha Cotizacion'].tolist()).min()))
print("Ultimo Registro: ",pd.to_datetime(df['Fecha Cotizacion'].tolist()).max())
print("Ruts Unicos: ",len(df['RUT'].unique()))
# Out:
# Filas:  2347
# Columnas:  49
# Primer Registro:  2013-08-19 18:35:56.620000
# Ultimo Registro:  2018-05-21 17:12:31.210000
# Ruts Unicos:  1103

# %% [markdown]
# ### 3.2.Data Exploration: Negocios

# %%
print("Neg rut promedio: ",get_col_group_description(df,'RUT')['mean'])
print("Neg rut desviacion: ",get_col_group_description(df,'RUT')['std'])
print("Neg por rut maximo: ",get_col_group_description(df,'RUT')['max'])
print("Neg estado anulados: ",len(df[df['Estado'] == 'Anulada'])/neg_all.shape[0])
print("Neg estado promesa: ",len(df[df['Estado'] == 'Promesado'])/neg_all.shape[0])
print("Neg estado reservado: ",len(df[df['Estado'] == 'Reservado'])/neg_all.shape[0])
print("Neg estado comercial desistimiento: ",len(df[df['Estado Comercial'] == 'Desistimiento'])/neg_all.shape[0])
print("Neg estado comercial normal: ",len(df[df['Estado Comercial'] == 'Normal'])/neg_all.shape[0])
# Out:
# Neg rut promedio:  2.127833182230281
# Neg rut desviacion:  1.7149326870075374
# Neg por rut maximo:  17
# Neg estado anulados:  0.6352790796761824
# Neg estado promesa:  0.12228376651043886
# Neg estado reservado:  0.11844908393694077
# Neg estado comercial desistimiento:  0.12270984235193864
# Neg estado comercial normal:  0.8363868768640818

# %%
#columns droped 'Fecha Promesa', 'Telefono', 'Fecha Escritura', 'Fecha Desistimiento', 'Fecha Resciliacion', 
# 'Resciliacion por Modificacion', 'Motivo Desis/Resc', 'Description Desis/Resc'

#columnas no importantes para el sgte paso
unimportant_columns = ['Apellido 1','Apellido 2','Celular','Ejecutivo Comercial','Region','Provincia','Jefe Comercial','ID']
to_select_cols = df.count().sort_values(ascending=True).index.tolist()
to_select_cols = to_select_cols[8:]
to_select_cols = [item for item in to_select_cols if item not in unimportant_columns]
# to_select_cols

# %% [markdown]
# ### 3.3.Exploracion de los ruts

# %%
## Clientes en Negocios que no estan en Cotizaciones

cot_rut = cot_all['RUT'].unique().tolist()
neg_rut = neg_all['RUT'].unique().tolist()

not_in = [item for item in neg_rut if item not in cot_rut]
print("Clientes en neg que no esta en cot: ",not_in)

## Clientes en Cotizaciones que no estan en Negocios
not_in = [item for item in cot_rut if item not in neg_rut]
print("Clientes en cot que no estan en neg ",len(not_in))

# verificacion si los numeros encajan
print("cantidad de ruts unicos en cot: ",len(cot_rut))
print("cantidad de ruts unicos en neg: ",len(neg_rut))
print("total de ruts unicos en cot: neg_ruts_unicos + cot_not_in_neg = ",len(not_in) +len(neg_rut))
# Out:
# Clientes en neg que no esta en cot:  ['15671306-6']
# Clientes en cot que no estan en neg  5082
# cantidad de ruts unicos en cot:  6184
# cantidad de ruts unicos en neg:  1103
# total de ruts unicos en cot: neg_ruts_unicos + cot_not_in_neg =  6185

# %% [markdown]
# ### 3.4.Exploracion de ID y ID COTIZACION

# %%
# hay 7 id_negocio que tienen mas de un id_cotizacion
print("Filas :",neg_all['ID Cotizacion'].shape[0])
print("ID Cot unicos ",len(neg_all['ID Cotizacion'].unique()))
# Out:
# Filas : 2347
# ID Cot unicos  2340

# %%
# que filas en negocios correspondern a los 7 ruts que tienen mas de 1 negocio
neg_id_cot_count = neg_all.groupby('ID Cotizacion').count().sort_values(by='ID',ascending=False)
neg_multiples_id = neg_id_cot_count[neg_id_cot_count['ID'] >= 2]

neg_id_rep = neg_multiples_id['ID'].index.tolist()

# view = neg_all.loc[neg_all['ID Cotizacion']==multiple_rows[1]]
view = neg_all.loc[neg_all['ID Cotizacion'].isin(neg_id_rep)]
view.loc[:,to_select_cols]
# df.loc[df['column_name'].isin(some_values)]
# Out:
#       Telefono Fecha Promesa      Cargo   Empleador Situacion Laboral  \
# 85         NaN           NaT        NaN         NaN     Independiente
# 88         NaN    2018-02-22        NaN         NaN     Independiente
# 4          NaN           NaT        NaN         NaN               NaN
# 5          NaN           NaT        NaN         NaN               NaN
# 6          NaN    2016-02-12        NaN         NaN               NaN
# 13   982297510           NaT        NaN         NaN               NaN
# 14   982297510    2016-08-31        NaN         NaN               NaN
# 125   78442661           NaT      Dueño         NaN               NaN
# 135        NaN    2014-04-30  Ejecutivo  Banco Bice       Dependiente
# 142        NaN    2014-04-30  Ejecutivo  Banco Bice       Dependiente
# 143   78442661    2014-04-30      Dueño         NaN               NaN
# 325        NaN           NaT        NaN         NaN               NaN
# 326        NaN           NaT        NaN         NaN               NaN
#
#     Fecha Nacimiento Nacionalidad          Profesión  \
# 85        1967-01-20      Chilena           Profesor
# 88        1967-01-20      Chilena           Profesor
# 4                NaT          NaN                NaN
# 5                NaT          NaN                NaN
# 6                NaT          NaN                NaN
# 13               NaT          NaN                NaN
# 14               NaT          NaN                NaN
# 125       1985-10-04          NaN                NaN
# 135       1979-08-19      Chilena                NaN
# 142       1979-08-19      Chilena                NaN
# 143       1985-10-04          NaN                NaN
# 325              NaT          NaN  Constructor Civil
# 326              NaT          NaN  Constructor Civil
#
#                                     Direccion N° Grupo Familiar  \
# 85                       Camino Al Venado 585   Sin Información
# 88                       Camino Al Venado 585   Sin Información
# 4    Avenida inglesa 220 9F Pedro de Valdivia                 2
# 5    Avenida inglesa 220 9F Pedro de Valdivia                 2
# 6    Avenida inglesa 220 9F Pedro de Valdivia                 2
# 13                                 Vilumanque               NaN
# 14                                 Vilumanque               NaN
# 125     av. Los Presidentes 1533 Depto casa 5   Sin Información
# 135              Ramón Carrasco 239 Depto 264                 3
# 142              Ramón Carrasco 239 Depto 264                 3
# 143     av. Los Presidentes 1533 Depto casa 5   Sin Información
# 325                                       NaN               NaN
# 326                                       NaN               NaN
#
#           ...                          Tipo de Medio              Proyecto  \
# 85        ...                             Recontacto       Altos del Valle
# 88        ...                             Recontacto       Altos del Valle
# 4         ...                                Tercero        Edificio Junge
# 5         ...                                Tercero        Edificio Junge
# 6         ...                                Tercero        Edificio Junge
# 13        ...         Cliente Aitue de otro proyecto        Edificio Junge
# 14        ...         Cliente Aitue de otro proyecto        Edificio Junge
# 125       ...                                  Paseo  San Andres Del Valle
# 135       ...                             Recontacto  San Andres Del Valle
# 142       ...                             Recontacto  San Andres Del Valle
# 143       ...                                  Paseo  San Andres Del Valle
# 325       ...                              Web Aitue  San Andres Del Valle
# 326       ...                              Web Aitue  San Andres Del Valle
#
#                              Etapa Total Productos       Estado  \
# 85                   ADV - Etapa 1          6040.0      Anulada
# 88                   ADV - Etapa 1          6040.0    Promesado
# 4           Quinta Junge - Torre B          8934.0      Anulada
# 5           Quinta Junge - Torre B          8934.0      Anulada
# 6           Quinta Junge - Torre B          8934.0  Escriturado
# 13          Quinta Junge - Torre B          5447.0      Anulada
# 14          Quinta Junge - Torre B          5447.0    Promesado
# 125  SADV - ET02 Condominio Choapa          3835.0      Anulada
# 135   SADV - ET01 Condominio Azapa          3532.0      Anulada
# 142   SADV - ET01 Condominio Azapa          3532.0    Promesado
# 143  SADV - ET02 Condominio Choapa          4261.0    Promesado
# 325   SADV - ET01 Condominio Azapa          3585.0    Reservado
# 326   SADV - ET01 Condominio Azapa          4590.0      Anulada
#
#                                Correo Electronico               Comuna  \
# 85   lulapolidori@gmail.com / galcazar@molicop.cl  San Pedro de la Paz
# 88   lulapolidori@gmail.com / galcazar@molicop.cl  San Pedro de la Paz
# 4                           arturospoerer@vtr.net           Concepción
# 5                           arturospoerer@vtr.net           Concepción
# 6                           arturospoerer@vtr.net           Concepción
# 13                            subgerenteassuan.cl           Concepción
# 14                            subgerenteassuan.cl           Concepción
# 125                  claudiogajardo_s@hotmail.com           Concepción
# 135                                mbarra@bice.cl           Concepción
# 142                                mbarra@bice.cl           Concepción
# 143                  claudiogajardo_s@hotmail.com           Concepción
# 325                    felipejaraconcha05yahoo.es           Concepción
# 326                    felipejaraconcha05yahoo.es           Concepción
#
#      Estado Comercial         RUT           Nombre
# 85             Normal   9879501-4  Maria de la Luz
# 88             Normal   9879501-4  Maria de la Luz
# 4              Normal   4028907-0   Gustavo Arturo
# 5              Normal   4028907-0   Gustavo Arturo
# 6              Normal   4028907-0   Gustavo Arturo
# 13             Normal  16766381-8   Cristian Jesus
# 14       Resciliacion  16766381-8   Cristian Jesus
# 125            Normal  16138640-5  Claudio Alberto
# 135            Normal  13628528-9     Mario Marcel
# 142      Resciliacion  13628528-9     Mario Marcel
# 143      Resciliacion  16138640-5  Claudio Alberto
# 325     Desistimiento  13308886-5           Felipe
# 326            Normal  13308886-5           Felipe
#
# [13 rows x 33 columns]

# %% [markdown]
# ### 2.5.Data Description Table Relations: Negocios & Cotizaciones

# %% [markdown]
# ### 2.5.1.Columnas

# %%
cot_cols = cot_all.columns.tolist()
neg_cols = neg_all.columns.tolist()

# %%
# ver columnas de negocios que no estan en las columnas de cotizaciones
not_in = [item for item in neg_cols if item not in cot_cols]
print("No en cotizaciones: ",not_in)
# Out:
# No en cotizaciones:  ['ID Cotizacion', 'Estado', 'Estado Comercial', 'Fecha Promesa', 'Fecha Escritura', 'Fecha Desistimiento', 'Fecha Resciliacion', 'Motivo Desis/Resc', 'Description Desis/Resc', 'Resciliacion por Modificacion']

# %%
# ver columnas de cotizaciones que no estan en las columnas de negocios
not_in = [item for item in cot_cols if item not in neg_cols]
print("No en negocios:",not_in)
# Out:
# No en negocios: ['Presencial', 'Remoto']

# %%
# ver columnas compartidas
not_in = [item for item in cot_cols if item in neg_cols]
print("Compartidas: ",not_in)
# Out:
# Compartidas:  ['ID', 'Fecha Cotizacion', 'Medio', 'Tipo de Medio', 'Proyecto', 'Etapa', 'Productos', 'Jefe Comercial', 'Ejecutivo Comercial', 'Total Productos', 'Descuentos', 'Valor Final Venta', 'RUT', 'Nombre', 'Apellido 1', 'Apellido 2', 'Nombre Completo', 'Telefono', 'Celular', 'Direccion', 'Region', 'Provincia', 'Comuna', 'Correo Electronico', 'Sexo', 'Estado Civil', 'Rango Edad', 'Fecha Nacimiento', 'Tipo Cliente', 'Razon Social', 'Giro', 'Nacionalidad', 'N° Grupo Familiar', 'Actividad', 'Cargo', 'Situacion Laboral', 'Empleador', 'Antiguedad Laboral', 'Profesión']

# %% [markdown]
# ### 2.5.2.Merging de las tablas (Necesario?). Negocios es subconjunto de Cotizacion

# %%
print(cot_all['ID'].shape[0])
print(len(cot_all['ID'].unique()))

neg_all.set_index('ID Cotizacion')
cot_all.set_index('ID')
print(neg_all.shape[0])
print(cot_all.shape[0])

merged_all =pd.merge(cot_all, neg_all, how='inner', left_index=True, right_index=True)
merged_all.shape[0]
# Out:
# 16592
# 16592
# 2347
# 16592
# 9308

# %% [markdown]
# ### 3.3.Exploración de Estado

# %%
# ver ruts de estado == entregado
neg_listos = neg_all.loc[neg_all['Estado'] == 'Entregado']

neg_listos.shape[0]

neg_listos_ruts = neg_listos.RUT.tolist()
neg_listos_ruts_unicos = neg_listos.RUT.unique().tolist()

cot_listos_rut = cot_all.loc[cot_all['RUT'].isin(neg_listos_ruts)]
# cot_listos_rut.info()

# %% [markdown]
# ### 3.4.Explore: Ver atributos de los cotizantes que llegan a Negocio

# %%
# ruts de los clientes en negocio
neg_ruts = neg_all['RUT'].unique().tolist()

cot_neg = cot_all.copy()
cot_neg['Negocio'] = cot_all['RUT'].isin(neg_ruts)

print(neg_all.shape[0])
print("Nro Filas en cot que tienen ruts en neg :",cot_neg.loc[cot_neg['Negocio']==True].shape[0])
# Out:
# 2347
# Nro Filas en cot que tienen ruts en neg : 5697

# %%
sb.factorplot(x='Sexo', col='Negocio', kind='count', data=cot_neg);

# %%
g = sb.factorplot(x='Medio', col='Negocio', kind='count', data=cot_neg);
g.set_xticklabels(rotation=90)

# %%
g = sb.factorplot(x='Proyecto', col='Negocio', kind='count', data=cot_neg);
g.set_xticklabels(rotation=90)

# %%
g = sb.factorplot(x='Estado Civil', col='Negocio', kind='count', data=cot_neg);
g.set_xticklabels(rotation=90)

# %%
g = sb.factorplot(x='Jefe Comercial', col='Negocio', kind='count', data=cot_neg);
g.set_xticklabels(rotation=90)

# %%
g = sb.factorplot(x='Ejecutivo Comercial', col='Negocio', kind='count', data=cot_neg);
g.set_xticklabels(rotation=90)

# %% [markdown]
# ### Comparacion Edades

# %%
### Ver edades en cotizantes y cotizantes que llegan a negocios
rango_edad = cot_neg['Rango Edad'].tolist()
rango_edad_min = [];rango_edad_max = []

for e in rango_edad:
    try:
        edad = e.split('-')
        rango_edad_min.append(int(edad[0]))
        rango_edad_max.append(int(edad[1]))
    except (ValueError, AttributeError):
        rango_edad_min.append(0)
        rango_edad_max.append(0)

# %%
cot_neg['Edad Min'] = rango_edad_min
cot_neg['Edad Max'] = rango_edad_max

# %%
g = sb.factorplot(x='Edad Min', col='Proyecto', kind='count', data=cot_neg);

# %%
g = sb.factorplot(x='Edad Max', col='Proyecto', kind='count', data=cot_neg);

# %%
cot_neg_si = cot_neg[cot_neg['Negocio']==True]
g = sb.factorplot(x='Edad Min', col='Proyecto', kind='count', data=cot_neg_si);

# %%
cot_neg_no = cot_neg[cot_neg['Negocio']==False]
g = sb.factorplot(x='Edad Min', col='Proyecto', kind='count', data=cot_neg_no);

# %% [markdown]
# ### Comparacion Presenciales

# %%
cot_neg_si = cot_neg[cot_neg['Negocio']==True]
g = sb.factorplot(x='Presencial', col='Proyecto', kind='count', data=cot_neg_si);

# %% [markdown]
# ### Comparacion Grupos Familiares

# %%
cot_neg_si = cot_neg[cot_neg['Negocio']==True]
g = sb.factorplot(x='N° Grupo Familiar', col='Proyecto', kind='count', data=cot_neg_si);

# %%
cot_neg_si = cot_neg[cot_neg['Negocio']==False]
g = sb.factorplot(x='N° Grupo Familiar', col='Proyecto', kind='count', data=cot_neg_si);

# %%
sb.stripplot(x='Negocio', y='Valor Final Venta', data=cot_neg, jitter=True)

# %%
# sb.swarmplot(x='Negocio', y='Valor Final Venta', data=cot_neg)

# %%
sb.boxplot(x='Negocio', y='Valor Final Venta',hue='Sexo', data=cot_neg)

# %%
sb.violinplot(x='Negocio', y='Valor Final Venta', data=cot_neg)

# %%
f = plt.figure(figsize=(10,10))
sb.violinplot(x='Negocio', y='Valor Final Venta',hue='Sexo', data=cot_neg)

# %%
sb.violinplot(x='Negocio', y='Descuentos', data=cot_neg)

# %%
f = plt.figure(figsize=(8,6))
sb.violinplot(x='Negocio', y='Descuentos',hue='Sexo', data=cot_neg)

# %%
f = plt.figure(figsize=(8,10))
g = sb.factorplot(x='Negocio', col='Proyecto', kind='count', data=cot_neg_si);
