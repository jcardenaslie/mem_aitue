# %%
import pandas as pd
import seaborn as sb

# %% [markdown]
# # 1 Select Data

# %%
cot_mod = pd.read_csv("..\\..\\Datos\\working\\cotizaciones_cleaned.csv",encoding = "ISO-8859-1")
cot_all = pd.read_excel("..\\..\\Datos\\working\\cotizaciones_all.xlsx")
neg_all = pd.read_excel("..\\..\\Datos\\working\\negocios_all.xlsx")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (20,32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## 3.1 Nuevos Atributos

# %% [markdown]
# ### 3.1.1 Edad
# Variable construida a partir de la fecha de nacimiento

# %%
# Construir variable 'Edad' a partir de fecha de Nacimiento
import datetime
now = datetime.datetime.now().year

fechas_nacimiento = pd.to_datetime(cot_all['Fecha Nacimiento']).apply(lambda x: x.date()).tolist()

def anio_nac(x):
    try:
        year = int(x.year)
        dif = now - year
        if dif >= 18:
            return dif
        else:
            return 0
    except (ValueError,AttributeError):
        return 0
        
    return r

edad = [anio_nac(x) for x in fechas_nacimiento]
cot_mod['edad'] = edad

# %%
# cot_mod = cot_mod.drop(['Fecha Nacimiento'], axis=1)

# %% [markdown]
# ### 3.1.2 Descuento
# Variable que indica si el cliente recibio descuento

# %%
# Construir 'descuento': binario : [True, False]
recibio_descuento = cot_all['Descuentos'].tolist()

def is_desc(x):
    try:
        desc = int(x)
        if desc > 0:
            return True
        else:
            return False
    except ValueError:
        return False

descuento = [is_desc(x) for x in recibio_descuento]
cot_mod['recibio_descuento'] = descuento
# descuento

# %% [markdown]
# ### 3.1.3.Cantidad de Productos

# %%
# Construir 'productos': categorico : ['depto','casa','estacionamiento','bodega','Estudio']
productos = cot_all['Productos'].tolist()
depto = []; estacionamiento=[]; bodega = []; estudio = [];nan = 0
def get_products(x,word,numeric=False):
    w=0
    try:
        p =str(x)
        arr_p = x.split(',')
        for e in arr_p:
            if word in e:
                w+=1
#                 print(word + " :",e)
                break
            elif numeric and ('B' not in e or 'Est' not in e):
                try:
                    int(e)
#                     print(word + " :",e)
                    w+=1
                except ValueError:
                    pass
        return w
    except (ValueError,AttributeError):
        try:
            int(x)
            if numeric:
                return 1
            else:
                return 0
        except ValueError:
            return 0

cot_mod['#vivienda'] = [get_products(x,'T',numeric=True) for x in productos]
cot_mod['#bodega'] = [get_products(x,'Bod') for x in productos]
cot_mod['#estacionamiento'] = [get_products(x,'Est') for x in productos]
cot_mod['#estudio'] = [get_products(x,'Estudio') for x in productos]
cot_mod['#lan'] = [get_products(x,'lan') for x in productos]

# %%
print(cot_mod[['Productos','#vivienda','#bodega','#estacionamiento','#estudio','#lan']].head())
print(cot_mod[['Productos','#vivienda','#bodega','#estacionamiento','#estudio','#lan']].tail())
# Out:
#               Productos  #vivienda  #bodega  #estacionamiento  #estudio  #lan
# 0         TB-104,Est-65          1        0                 1         0     0
# 1  TA-302,Est-41,Bod-02          1        1                 1         0     0
# 2         TA-303,Est-01          1        0                 1         0     0
# 3  TA-302,Est-41,Bod-06          1        1                 1         0     0
# 4         TA-604,Est-01          1        0                 1         0     0
#          Productos  #vivienda  #bodega  #estacionamiento  #estudio  #lan
# 16587  703,Est-003          1        0                 1         0     0
# 16588          912          1        0                 0         0     0
# 16589  Est-002,703          1        0                 1         0     0
# 16590  912,Est-002          1        0                 1         0     0
# 16591          912          1        0                 0         0     0

# %%
cot_mod = cot_mod.drop(['Productos'], axis=1)

# %% [markdown]
# ### 3.1.4 Latitud y Longitud

# %%
from geopy.geocoders import Nominatim

def get_latlong(direccion):
    geolocator = Nominatim()
    direccion = "TUCAPEL 937 , CONCEPCION CENTRO"
    location = geolocator.geocode(direccion)
#     print(location.address)
    # Flatiron Building, 175, 5th Avenue, Flatiron, New York, NYC, New York, ...
    print((location.latitude, location.longitude))
    # (40.7410861, -73.9896297241625)
#     print(location.raw)

# get_latlong('')

# cot_mod['loc_lat'] = []

# %% [markdown]
# ### 3.1.6 Region

# %%
cot_mod.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Fecha Cotizacion', 'Medio', 'Tipo de Medio',
#        'Proyecto', 'Etapa', 'Presencial', 'Remoto', 'Jefe Comercial',
#        'Ejecutivo Comercial', 'Total Productos', 'Descuentos',
#        'Valor Final Venta', 'RUT', 'Nombre', 'Apellido 1', 'Apellido 2',
#        'Nombre Completo', 'Telefono', 'Celular', 'Direccion', 'Region',
#        'Provincia', 'Comuna', 'Correo Electronico', 'Sexo', 'Estado Civil',
#        'Rango Edad', 'Fecha Nacimiento', 'Tipo Cliente', 'Razon Social',
#        'Giro', 'Nacionalidad', 'N° Grupo Familiar', 'Actividad', 'Cargo',
#        'Situacion Laboral', 'Empleador', 'Antiguedad Laboral', 'Profesión',
#        'Negocio', 'Clean Rut', 'Valid Rut', 'Format Rut', 'profesion_agg',
#        'edad', 'recibio_descuento', '#vivienda', '#bodega', '#estacionamiento',
#        '#estudio', '#lan'],
#       dtype='object')

# %%
cot_mod['Region'].unique()
# Out:
# array(['VIII Región del Bío-Bío', 'XIII Región Metropolitana de Santiago',
#        'VII Región del Maule', 'II Región de Antofagasta',
#        'IV Región de Coquimbo', 'X Región de Los Lagos',
#        'XII Región de Magallanes y de La Antártica Chilena',
#        'V Región de Valparaíso',
#        'VI Región del Libertador General Bernardo O Higgins',
#        'XIV Región de Los Ríos',
#        'XI Región de Aysen del General Carlos Ibáñez del Campo',
#        'I Región de Tarapacá', 'IX Región de La Araucanía',
#        'III Región de Atacama', 'XV Region de Arica y Parinacota'],
#       dtype=object)

# %%
cot_mod['region'] = cot_mod['Region']
cot_mod['region'] = cot_mod['region'].replace(
    {'VIII Región del Bío-Bío':'Bio-Bio',
     'XIII Región Metropolitana de Santiago':'Metropolitana'}
)
cot_mod['region'] = cot_mod['region'].replace(
    ['II Región de Antofagasta',
       'IV Región de Coquimbo', 'VII Región del Maule',
       'X Región de Los Lagos',
       'V Región de Valparaíso',
       'VI Región del Libertador General Bernardo O Higgins',
       'XIV Región de Los Ríos',
       'XI Región de Aysen del General Carlos Ibáñez del Campo',
       'I Región de Tarapacá', 'IX Región de La Araucanía',
       'XII Región de Magallanes y de La Antártica Chilena',
       'XV Region de Arica y Parinacota', 'III Región de Atacama'],'Otro'
)

# %%
cot_mod['region'] = cot_mod['region'].astype('category')
cot_mod['region'].head()
# Out:
# 0    Bio-Bio
# 1    Bio-Bio
# 2    Bio-Bio
# 3    Bio-Bio
# 4    Bio-Bio
# Name: region, dtype: category
# Categories (3, object): [Bio-Bio, Metropolitana, Otro]

# %%
cot_mod = cot_mod.drop(['Region'], axis=1)

# %% [markdown]
# ### 3.1.7 Provincia
# Esta variable indica si el cliente facilito el correo en alguna cotizacion

# %%
cot_all['Provincia'].unique()
# Out:
# array(['Concepción', 'Ñuble', 'Santiago', 'Talca', 'Biobío', 'Maipo',
#        'Antofagasta', 'Limarí', 'Llanquihue', 'Magallanes', 'El Loa',
#        'Isla de Pascua', 'Valparaíso', 'Cachapoal', 'Arauco',
#        'Cordillera', 'Valdivia', 'Coyhaique', 'Linares', 'Osorno',
#        'San Felipe de Aconcagua', 'Iquique', 'Cautín', 'Capitán Prat',
#        'Aysén', 'Chacabuco', 'Copiapó', 'Melipilla', 'Malleco', 'Arica',
#        'Elqui', 'Cauquenes', 'Colchagua', 'Última Esperanza', 'Curicó',
#        'Chiloé', 'Choapa', 'Huasco'], dtype=object)

# %%
cot_mod['provincia'] = cot_mod['Provincia'].copy()
cot_mod['provincia'] = cot_mod['provincia'].replace(
    {'Concepción':'Concepcion',
     'Santiago':'Santiago'}
)
cot_mod['provincia'] = cot_mod['provincia'].replace(
    ['Antofagasta', 'Limarí', 'Talca', 'Biobío', 'Ñuble',
       'Llanquihue','Maipo', 'Valparaíso', 'Cachapoal',
       'Arauco', 'Valdivia', 'Coyhaique', 'Linares', 'Osorno',
       'San Felipe de Aconcagua', 'Iquique', 'Cautín', 'Capitán Prat',
       'Aysén', 'Chacabuco', 'Melipilla', 'Magallanes', 'Malleco',
       'Arica ', 'Elqui', 'El Loa', 'Cauquenes', 'Colchagua', 'Valdivia ',
       'Copiapó', 'Última Esperanza', 'Cordillera', 'Curicó', 'Chiloé',
       'Choapa', 'Huasco','Arica','Isla de Pascua'],'Otro'
)

# %%
cot_mod['provincia'] = cot_mod['provincia'].astype('category')
cot_mod['provincia'].head()
# Out:
# 0    Concepcion
# 1    Concepcion
# 2    Concepcion
# 3    Concepcion
# 4          Otro
# Name: provincia, dtype: category
# Categories (3, object): [Concepcion, Otro, Santiago]

# %%
cot_mod = cot_mod.drop(['Provincia'], axis=1)

# %% [markdown]
# ### 3.1.8 Comuna
# Esta variable indica si el cliente facilito el correo en alguna cotizacion

# %%
cot_all['Comuna'].unique()
# Out:
# array(['Concepción', 'Chillán', 'San Pedro de la Paz', 'Talcahuano',
#        'La Florida', 'Hualpén', 'Santiago', 'Constitución', 'Los Ángeles',
#        'Ñuñoa', 'Providencia', 'Penco', 'Tomé', 'Buin', 'Antofagasta',
#        'Ovalle', 'Puerto Montt', 'Punta Arenas', 'Chiguayante',
#        'El Bosque', 'Yungay', 'Florida', 'Calama', 'Lota', 'Coronel',
#        'Isla de Pascua', 'Viña del Mar', 'Machalí', 'Arauco',
#        'Las Condes', 'Vitacura', 'Pirque', 'Contulmo', 'Concón',
#        'Santa Juana', 'Puerto Varas', 'Cañete', 'Huechuraba', 'Valdivia',
#        'Coyhaique', 'Colbún', 'Osorno', 'San Felipe', 'Iquique',
#        'Rancagua', 'Temuco', 'Cochrane', 'Chillán Viejo', 'Maipú',
#        'Aysén', 'Villarrica', 'La Reina', 'Peñalolén', 'Estación Central',
#        'Colina', 'Quilicura', 'Curanilahue', 'Copiapó', 'Algarrobo',
#        'Talca', 'San Carlos', 'Mulchén', 'Coelemu', 'Angol', 'Laja',
#        'Nacimiento', 'Arica', 'La Serena', 'Hualqui', 'San Miguel',
#        'Pelluhue', 'Quillón', 'Valparaíso', 'Llanquihue', 'Los Álamos',
#        'Renca', 'Santa Cruz', 'Panguipulli', 'Cabrero', 'Cerrillos',
#        'Pudahuel', 'Natales', 'Tirúa', 'Cauquenes', 'La Cisterna',
#        'Yumbel', 'Ránquil', 'Padre Las Casas', 'Las Cabras', 'Coquimbo',
#        'Lebu', 'San José de Maipo', 'San Ramón', 'Curicó',
#        'Independencia', 'Lampa', 'Castro', 'Punitaqui', 'Conchalí',
#        'San Rosendo', 'Alto Hospicio', 'Illapel', 'Huasco', 'Alto Biobío',
#        'Collipulli', 'Tucapel'], dtype=object)

# %%
cot_mod['comuna'] = cot_mod['Comuna'].copy()

cot_mod['comuna'] = cot_mod['comuna'].replace(
    ['Ovalle', 'Constitución','Tomé', 'Chillán','Yungay',
     'Puerto Montt', 'Santiago', 'El Bosque', 'La Florida','Las Condes',
     'Ñuñoa', 'Providencia', 'Buin','Florida','Viña del Mar',
     'Machalí', 'Vitacura', 'Arauco', 'Contulmo', 'Concón',
     'Santa Juana', 'Puerto Varas', 'Cañete', 'Huechuraba', 'Valdivia',
     'Coyhaique', 'Colbún', 'Osorno', 'San Felipe', 'Iquique',
     'Rancagua', 'Lota', 'Temuco', 'Cochrane', 'Chillán Viejo', 'Maipú',
     'Aysén', 'Villarrica', 'La Reina', 'Peñalolén', 'Estación Central',
     'Colina', 'Quilicura', 'Curanilahue', 'Algarrobo', 'Talca',
     'San Carlos', 'Punta Arenas', 'Mulchén', 'Coelemu', 'Angol',
     'Laja', 'Nacimiento', 'Arica', 'La Serena', 'Hualqui',
     'San Miguel', 'Calama', 'Pelluhue', 'Quillón', 'Valparaíso',
     'Llanquihue', 'Los Álamos', 'Renca', 'Santa Cruz', 'Panguipulli',
     'Cabrero', 'Cerrillos', 'Pudahuel', 'Copiapó', 'Natales', 'Tirúa',
     'Cauquenes', 'La Cisterna', 'Yumbel', 'Ránquil', 'Padre Las Casas',
     'Las Cabras', 'Coquimbo', 'Lebu', 'San José de Maipo', 'San Ramón',
     'Curicó', 'Independencia', 'Lampa ', 'Castro', 'Punitaqui',
     'Conchalí', 'San Rosendo', 'Alto Hospicio', 'Illapel', 'Huasco',
     'Collipulli', 'Tucapel', 'Alto Biobío','Pirque','Lampa','Isla de Pascua','Antofagasta', 'Arica'],'Otro'
)

# %%
cot_mod['comuna'] = cot_mod['comuna'].astype('category')
cot_mod['comuna'].head()
# Out:
# 0    Concepción
# 1    Concepción
# 2    Concepción
# 3    Concepción
# 4          Otro
# Name: comuna, dtype: category
# Categories (9, object): [Chiguayante, Concepción, Coronel, Hualpén, ..., Otro, Penco, San Pedro de la Paz, Talcahuano]

# %%
cot_mod = cot_mod.drop(['Comuna'], axis=1)

# %% [markdown]
# ### 3.1.9 Atributos Provistos

# %%
cot_mod['is_nombre'] = ~cot_mod['Nombre'].isnull()
cot_mod['is_apellido1'] = ~cot_mod['Apellido 1'].isnull()
cot_mod['is_apellido2'] = ~cot_mod['Apellido 2'].isnull()
cot_mod['is_nombrecompleto'] = ~cot_mod['Nombre Completo'].isnull()
cot_mod['is_correo'] = ~cot_mod['Correo Electronico'].isnull()
cot_mod['is_direccion'] = ~cot_mod['Direccion'].isnull()
cot_mod['is_telefono'] = ~cot_mod['Telefono'].isnull()
cot_mod['is_actividad'] = ~cot_mod['Actividad'].isnull()
cot_mod['is_estado_civil'] = ~cot_mod['Estado Civil'].isnull()
cot_mod['is_fnac'] = ~cot_mod['Fecha Nacimiento'].isnull()
cot_mod['is_celular'] = ~cot_mod['Celular'].isnull()

cot_mod['is_profesion'] = ~cot_mod['profesion_agg'].isnull()

cot_mod = cot_mod.drop(['Profesión','Telefono','Correo Electronico','Telefono','Nombre','Apellido 1','Apellido 2','Nombre Completo'], axis=1)

# %% [markdown]
# ### 3.1.9 Atributos Provistos
# Esta variable indica el numero de veces que el cliente ha hecho cotizaciones

# %% [markdown]
# ### 3.1.4 Cotizaciones por Proyecto

# %%
rut_dict = dict()

    
for index, row in cot_mod.iterrows():
    rut = row['Format Rut']
    pr = row['Proyecto']
    
    if rut not in rut_dict.keys():
        rut_dict[rut] = dict()
        rut_dict[rut]['Altos del Valle'] = 0
        rut_dict[rut]['Edificio Urban 1470'] = 0
        rut_dict[rut]['San Andres Del Valle'] = 0
        rut_dict[rut]['Edificio Mil610'] = 0
        rut_dict[rut]['Edificio Junge'] = 0
    
    rut_dict[rut][pr] +=1



rut_proyectos = pd.DataFrame.from_dict(rut_dict,orient='index').reset_index()
rut_proyectos.head()

# cot_mod = pd.merge(cot_mod_cp, rut_proyectos,how='left', left_on='Format Rut', right_on='index')
# Out:
#            index  Altos del Valle  Edificio Urban 1470  San Andres Del Valle  \
# 0  000.000.000-0                0                    1                     1
# 1    1.462.558-5                0                    0                     0
# 2   10.000.513-1                0                    0                     0
# 3   10.000.522-0                0                    0                     0
# 4   10.005.853-7                0                    0                     0
#
#    Edificio Mil610  Edificio Junge
# 0                0               0
# 1                1               0
# 2                0               2
# 3                0               2
# 4                0               2

# %%
cot_mod.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Fecha Cotizacion', 'Medio', 'Tipo de Medio',
#        'Proyecto', 'Etapa', 'Presencial', 'Remoto', 'Jefe Comercial',
#        'Ejecutivo Comercial', 'Total Productos', 'Descuentos',
#        'Valor Final Venta', 'RUT', 'Celular', 'Direccion', 'Sexo',
#        'Estado Civil', 'Rango Edad', 'Fecha Nacimiento', 'Tipo Cliente',
#        'Razon Social', 'Giro', 'Nacionalidad', 'N° Grupo Familiar',
#        'Actividad', 'Cargo', 'Situacion Laboral', 'Empleador',
#        'Antiguedad Laboral', 'Negocio', 'Clean Rut', 'Valid Rut', 'Format Rut',
#        'profesion_agg', 'edad', 'recibio_descuento', '#vivienda', '#bodega',
#        '#estacionamiento', '#estudio', '#lan', 'region', 'provincia', 'comuna',
#        'is_nombre', 'is_apellido1', 'is_apellido2', 'is_nombrecompleto',
#        'is_correo', 'is_direccion', 'is_telefono', 'is_actividad',
#        'is_estado_civil', 'is_fnac', 'is_celular', 'is_profesion'],
#       dtype='object')

# %% [markdown]
# ### 3.1.9 Rango Edad
# Esta variable indica el numero de veces que el cliente ha hecho cotizaciones

# %%
### Ver edades en cotizantes y cotizantes que llegan a negocios
rango_edad = cot_mod['Rango Edad'].tolist()
rango_edad_min = [];rango_edad_max = []

for e in rango_edad:
    try:
        edad = e.split('-')
        rango_edad_min.append(int(edad[0]))
        rango_edad_max.append(int(edad[1]))
    except (ValueError, AttributeError):
        rango_edad_min.append(0)
        rango_edad_max.append(0)
        
cot_mod['Edad Min'] = rango_edad_min
cot_mod['Edad Max'] = rango_edad_max

# %% [markdown]
# ### 3.1.11 Negocio
# Indica si el cliente siguio el proceso de cotizacion y lo transformo en un proceso de negocio

# %%
# ruts de los clientes en negocio
neg_ids = neg_all['ID Cotizacion'].unique().tolist()

# cot_neg = cot_all.copy()
cot_mod['Negocio'] = cot_mod['ID'].isin(neg_ids)
cot_mod[cot_mod['Negocio'] == True].shape
# Out:
# (2336, 60)

# %% [markdown]
# ### 3.1.12 N° Grupo Familiar

# %%
cot_mod['N° Grupo Familiar']=cot_mod['N° Grupo Familiar'].fillna('Sin Información')

# %%
def is_nrofam(x):
    if x == 'Sin Información':
        return False
    else:
        return True

cot_mod['is_nrofam'] = [ is_nrofam(x) for x in cot_mod['N° Grupo Familiar'] ]

# %%
cot_mod.to_excel('..\\..\\Datos\\working\\cotizaciones_transformed.xlsx')

# %% [markdown]
# ### 3.1.12 N° Grupo Familiar

# %% [markdown]
# ### 3.2. Extraccion de Datos
# Esta variable indica el numero de veces que el cliente ha hecho cotizaciones

# %%
#View data integration
iterator = 0
for group, frame in  cot_mod.groupby('Format Rut'):
    
#     print(frame['N° Grupo Familiar'].isnull())
    #Check , debe ir a data exploration
    
    for i in range(0, len(frame['Medio'])):
        
        if frame['Presencial'].iloc[i] == frame['Remoto'].iloc[i]:
            print(group)
            print(
                frame['Proyecto'].iloc[i],
                frame['Medio'].iloc[i], 
                frame['Presencial'].iloc[i], 
                frame['Remoto'].iloc[i], 
                frame['Negocio'].iloc[i]
            )
            iterator +=1
        
    
    arr = frame['Medio'].unique()
    l = len(arr)
    if l > 1:
        if True in arr: 
            iterator +=1
#             print(group)
#         print(l)

print(iterator)
# Out:
# 10.000.522-0
# Edificio Junge RECONTACTO No No True
# 10.000.522-0
# Edificio Junge RECONTACTO No No True
# 10.014.880-3
# San Andres Del Valle INTERNET Si Si True
# 10.016.093-5
# Edificio Junge RECONTACTO No No True
# 10.016.093-5
# San Andres Del Valle RECONTACTO No No False
# 10.016.093-5
# San Andres Del Valle RECONTACTO No No False
# 10.023.667-2
# Edificio Urban 1470 FINCO No No False
# 10.033.390-2
# San Andres Del Valle RECONTACTO No No True
# 10.034.279-0
# Edificio Mil610 RECORRIDO POR EL SECTOR No No True
# 10.037.786-1
# San Andres Del Valle RECONTACTO No No False
# 10.037.786-1
# San Andres Del Valle RECONTACTO No No False
# 10.037.848-5
# San Andres Del Valle INTERNET Si Si False
# 10.037.848-5
# San Andres Del Valle INTERNET Si Si False
# 10.038.900-2
# San Andres Del Valle RECONTACTO No No False
# 10.040.204-1
# Edificio Urban 1470 REFERIDOS No No False
# 10.051.640-3
# Edificio Urban 1470 REFERIDOS Si Si False
# 10.051.640-3
# Edificio Urban 1470 REFERIDOS No No False
# 10.051.640-3
# Edificio Urban 1470 REFERIDOS No No True
# 10.054.460-1
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 10.054.460-1
# San Andres Del Valle RECONTACTO No No False
# 10.057.512-4
# Edificio Mil610 RECONTACTO No No False
# 10.063.198-9
# San Andres Del Valle RECONTACTO Si Si False
# 10.063.198-9
# San Andres Del Valle RECONTACTO Si Si False
# 10.069.788-2
# San Andres Del Valle RECONTACTO Si Si False
# 10.076.241-2
# Altos del Valle RECONTACTO No No True
# 10.142.997-0
# San Andres Del Valle INTERNET Si Si False
# 10.142.997-0
# San Andres Del Valle INTERNET Si Si False
# 10.155.954-8
# Edificio Urban 1470 FINCO No No False
# 10.161.184-1
# San Andres Del Valle RECONTACTO No No False
# 10.169.741-k
# San Andres Del Valle RECONTACTO Si Si False
# 10.171.120-k
# Edificio Junge RECORRIDO POR EL SECTOR No No False
# 10.180.285-k
# San Andres Del Valle INTERNET Si Si False
# 10.180.285-k
# San Andres Del Valle INTERNET Si Si False
# 10.186.597-5
# San Andres Del Valle REFERIDOS No No False
# 10.193.821-2
# Altos del Valle INTERNET No No False
# 10.193.821-2
# Altos del Valle INTERNET No No False
# 10.193.821-2
# Altos del Valle INTERNET No No False
# 10.214.251-9
# San Andres Del Valle INTERNET Si Si False
# 10.214.251-9
# San Andres Del Valle INTERNET Si Si False
# 10.214.251-9
# San Andres Del Valle INTERNET Si Si False
# 10.214.251-9
# San Andres Del Valle INTERNET Si Si False
# 10.228.682-0
# San Andres Del Valle RECONTACTO No No True
# 10.272.204-3
# Edificio Urban 1470 FINCO No No False
# 10.272.204-3
# Edificio Urban 1470 FINCO No No False
# 10.278.036-1
# Edificio Junge INTERNET Si Si False
# 10.290.085-5
# San Andres Del Valle INTERNET No No False
# 10.292.510-6
# Edificio Urban 1470 RECORRIDO POR EL SECTOR Si Si False
# 10.305.436-2
# San Andres Del Valle RECONTACTO No No False
# 10.305.957-7
# Edificio Urban 1470 FINCO No No False
# 10.308.520-9
# San Andres Del Valle FINCO No No False
# 10.316.844-9
# Edificio Urban 1470 FINCO No No False
# 10.323.247-3
# Edificio Urban 1470 FINCO No No False
# 10.323.248-1
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 10.323.248-1
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 10.323.248-1
# San Andres Del Valle RECONTACTO No No False
# 10.324.991-0
# San Andres Del Valle INTERNET Si Si False
# 10.324.991-0
# San Andres Del Valle INTERNET Si Si False
# 10.324.991-0
# San Andres Del Valle INTERNET Si Si False
# 10.327.568-7
# San Andres Del Valle INTERNET Si Si False
# 10.331.526-3
# Edificio Urban 1470 RECORRIDO POR EL SECTOR No No False
# 10.333.153-6
# Edificio Urban 1470 FINCO No No False
# 10.341.629-9
# Edificio Urban 1470 FINCO No No False
# 10.344.658-9
# San Andres Del Valle INTERNET No No False
# 10.345.538-3
# Edificio Urban 1470 REFERIDOS No No False
# 10.345.538-3
# Edificio Urban 1470 REFERIDOS No No False
# 10.350.350-7
# Edificio Mil610 RECONTACTO No No False
# 10.350.350-7
# Edificio Mil610 INTERNET Si Si False
# 10.350.350-7
# Edificio Mil610 INTERNET Si Si False
# 10.352.115-7
# San Andres Del Valle RECONTACTO No No False
# 10.364.660-k
# San Andres Del Valle FINCO No No False
# 10.395.384-7
# Altos del Valle RECORRIDO POR EL SECTOR Si Si False
# 10.395.384-7
# Altos del Valle RECORRIDO POR EL SECTOR Si Si False
# 10.424.643-5
# San Andres Del Valle RECONTACTO No No True
# 10.444.048-7
# Altos del Valle RECONTACTO No No False
# 10.444.048-7
# San Andres Del Valle INTERNET Si Si False
# 10.444.048-7
# San Andres Del Valle RECONTACTO No No False
# 10.444.048-7
# San Andres Del Valle RECONTACTO No No True
# 10.444.048-7
# San Andres Del Valle RECONTACTO No No True
# 10.444.048-7
# San Andres Del Valle RECONTACTO No No True
# 10.444.114-9
# San Andres Del Valle RECONTACTO No No False
# 10.462.028-0
# San Andres Del Valle RECONTACTO No No True
# 10.462.028-0
# San Andres Del Valle RECONTACTO No No True
# 10.475.609-3
# San Andres Del Valle INTERNET No No False
# 10.480.255-9
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 10.481.398-4
# Edificio Urban 1470 FINCO No No False
# 10.496.229-7
# San Andres Del Valle FINCO No No False
# 10.498.832-6
# San Andres Del Valle RECONTACTO Si Si True
# 10.500.435-4
# Edificio Urban 1470 RECONTACTO No No False
# 10.500.603-9
# Edificio Junge INTERNET Si Si False
# 10.506.030-0
# Edificio Urban 1470 RECONTACTO No No False
# 10.540.790-4
# Altos del Valle LETREROS Si Si False
# 10.540.790-4
# Altos del Valle LETREROS Si Si False
# 10.545.485-6
# Edificio Urban 1470 FINCO No No False
# 10.552.598-2
# Edificio Urban 1470 FINCO No No False
# 10.552.598-2
# Edificio Urban 1470 FINCO No No False
# 10.552.598-2
# Edificio Urban 1470 INTERNET No No False
# 10.552.598-2
# Edificio Urban 1470 INTERNET No No False
# 10.552.598-2
# Edificio Urban 1470 INTERNET No No False
# 10.552.598-2
# Edificio Urban 1470 INTERNET No No True
# 10.577.927-5
# San Andres Del Valle RECONTACTO No No False
# 10.598.648-3
# Edificio Urban 1470 FINCO No No False
# 10.627.157-7
# San Andres Del Valle RECONTACTO Si Si False
# 10.627.157-7
# San Andres Del Valle RECONTACTO Si Si True
# 10.627.157-7
# San Andres Del Valle RECONTACTO Si Si False
# 10.627.157-7
# San Andres Del Valle RECONTACTO Si Si False
# 10.636.583-0
# Edificio Urban 1470 INTERNET No No False
# 10.636.583-0
# Edificio Urban 1470 INTERNET No No False
# 10.637.991-2
# San Andres Del Valle RECORRIDO POR EL SECTOR No No True
# 10.637.991-2
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 10.637.993-9
# San Andres Del Valle INTERNET Si Si False
# 10.637.993-9
# San Andres Del Valle INTERNET Si Si False
# 10.637.993-9
# San Andres Del Valle INTERNET Si Si False
# 10.637.993-9
# San Andres Del Valle RECONTACTO No No False
# 10.645.374-8
# Edificio Mil610 INTERNET No No False
# 10.662.350-3
# Edificio Urban 1470 RECONTACTO No No False
# 10.662.350-3
# Edificio Urban 1470 RECONTACTO No No False
# 10.662.350-3
# Edificio Urban 1470 RECONTACTO No No True
# 10.662.350-3
# Edificio Urban 1470 RECONTACTO No No False
# 10.664.273-7
# Edificio Urban 1470 FINCO No No False
# 10.665.303-8
# Edificio Junge INTERNET Si Si True
# 10.673.784-3
# Edificio Junge INTERNET No No False
# 10.674.993-0
# Edificio Urban 1470 RECORRIDO POR EL SECTOR Si Si False
# 10.675.549-3
# Edificio Urban 1470 FINCO No No False
# 10.675.554-k
# Edificio Urban 1470 FINCO No No False
# 10.681.800-2
# Edificio Urban 1470 FINCO No No False
# 10.686.068-8
# San Andres Del Valle FINCO No No False
# 10.686.102-1
# San Andres Del Valle RECONTACTO Si Si False
# 10.686.102-1
# San Andres Del Valle RECORRIDO POR EL SECTOR No No True
# 10.691.607-1
# Edificio Urban 1470 FINCO No No False
# 10.699.889-2
# San Andres Del Valle RECONTACTO No No False
# 10.699.889-2
# San Andres Del Valle RECONTACTO No No False
# 10.731.863-1
# Edificio Urban 1470 FINCO No No False
# 10.736.871-k
# San Andres Del Valle RECONTACTO No No False
# 10.736.871-k
# San Andres Del Valle RECONTACTO No No False
# 10.736.871-k
# San Andres Del Valle RECONTACTO No No False
# 10.748.815-4
# San Andres Del Valle RECONTACTO No No True
# 10.758.920-1
# San Andres Del Valle INTERNET Si Si False
# 10.758.920-1
# San Andres Del Valle INTERNET Si Si False
# 10.758.920-1
# San Andres Del Valle RECONTACTO No No False
# 10.758.920-1
# San Andres Del Valle RECONTACTO No No False
# 10.770.093-5
# Edificio Mil610 RECONTACTO No No False
# 10.770.093-5
# Edificio Mil610 RECONTACTO No No False
# 10.770.093-5
# Edificio Mil610 RECONTACTO No No False
# 10.772.385-4
# Edificio Urban 1470 FINCO No No False
# 10.775.855-0
# Edificio Junge RECONTACTO No No False
# 10.775.855-0
# Edificio Junge RECONTACTO No No False
# 10.775.855-0
# Edificio Junge RECONTACTO No No False
# 10.775.855-0
# Edificio Junge RECONTACTO No No False
# 10.780.375-0
# San Andres Del Valle RECONTACTO Si Si False
# 10.780.375-0
# San Andres Del Valle RECONTACTO Si Si False
# 10.789.924-3
# Edificio Urban 1470 INTERNET No No False
# 10.789.924-3
# Edificio Urban 1470 INTERNET No No False
# 10.816.944-3
# Edificio Urban 1470 RECONTACTO No No True
# 10.816.944-3
# Edificio Urban 1470 RECONTACTO No No True
# 10.816.944-3
# Edificio Urban 1470 RECONTACTO No No True
# 10.816.944-3
# Edificio Urban 1470 RECONTACTO No No True
# 10.824.498-4
# San Andres Del Valle RECONTACTO No No False
# 10.842.123-1
# San Andres Del Valle INTERNET No No False
# 10.845.422-9
# San Andres Del Valle RECONTACTO No No False
# 10.858.552-8
# San Andres Del Valle FINCO No No True
# 10.858.552-8
# San Andres Del Valle FINCO No No True
# 10.858.552-8
# San Andres Del Valle RECONTACTO No No True
# 10.858.552-8
# San Andres Del Valle FINCO No No True
# 10.858.552-8
# San Andres Del Valle RECONTACTO Si Si False
# 10.858.552-8
# San Andres Del Valle RECONTACTO Si Si True
# 10.858.552-8
# San Andres Del Valle RECONTACTO Si Si False
# 10.869.847-0
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 10.869.847-0
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 10.877.862-8
# Altos del Valle EVENTOS No No False
# 10.879.781-9
# Edificio Urban 1470 INTERNET No No False
# 10.879.781-9
# Edificio Urban 1470 INTERNET No No False
# 10.906.135-2
# San Andres Del Valle INTERNET No No False
# 10.924.000-1
# San Andres Del Valle FINCO No No False
# 10.931.624-5
# Edificio Junge RECONTACTO No No True
# 10.931.624-5
# Edificio Junge INTERNET Si Si True
# 10.931.772-1
# San Andres Del Valle RECONTACTO No No False
# 10.932.083-8
# Altos del Valle RECONTACTO No No False
# 10.939.389-4
# San Andres Del Valle RECONTACTO No No True
# 10.940.668-6
# San Andres Del Valle RECONTACTO No No False
# 10.964.075-1
# Edificio Junge INTERNET No No False
# 10.964.075-1
# Edificio Junge INTERNET No No False
# 10.972.232-4
# San Andres Del Valle RECONTACTO No No False
# 10.972.232-4
# San Andres Del Valle RECONTACTO No No False
# 10.972.232-4
# San Andres Del Valle RECONTACTO No No False
# 10.972.232-4
# San Andres Del Valle RECONTACTO No No False
# 10.972.232-4
# San Andres Del Valle RECONTACTO No No False
# 10.972.232-4
# San Andres Del Valle RECONTACTO No No False
# 10.972.232-4
# San Andres Del Valle RECONTACTO No No False
# 10.972.232-4
# San Andres Del Valle RECONTACTO No No False
# 10.981.269-2
# Edificio Mil610 RECORRIDO POR EL SECTOR No No False
# 10.993.225-6
# San Andres Del Valle INTERNET No No False
# 11.034.322-1
# San Andres Del Valle INTERNET No No False
# 11.179.049-3
# Edificio Urban 1470 FINCO No No False
# 11.212.784-4
# San Andres Del Valle RECONTACTO No No True
# 11.239.681-0
# Edificio Junge RECONTACTO No No True
# 11.239.681-0
# Edificio Junge RECORRIDO POR EL SECTOR No No True
# 11.239.877-5
# San Andres Del Valle FINCO No No False
# 11.259.106-0
# Edificio Junge RECORRIDO POR EL SECTOR No No False
# 11.276.929-3
# San Andres Del Valle INTERNET Si Si False
# 11.281.545-7
# Edificio Urban 1470 FINCO No No False
# 11.290.892-7
# San Andres Del Valle INTERNET Si Si False
# 11.290.892-7
# San Andres Del Valle INTERNET Si Si False
# 11.290.892-7
# San Andres Del Valle INTERNET Si Si False
# 11.291.147-2
# Edificio Urban 1470 FINCO No No False
# 11.294.789-2
# San Andres Del Valle INTERNET No No False
# 11.307.631-3
# San Andres Del Valle RECONTACTO No No False
# 11.307.631-3
# San Andres Del Valle RECORRIDO POR EL SECTOR No No True
# 11.428.316-9
# Edificio Urban 1470 FINCO No No False
# 11.448.329-k
# San Andres Del Valle REFERIDOS Si Si False
# 11.448.329-k
# San Andres Del Valle REFERIDOS No No False
# 11.449.329-5
# Edificio Mil610 LETREROS No No False
# 11.449.329-5
# Edificio Mil610 LETREROS No No False
# 11.468.542-9
# Altos del Valle INTERNET No No False
# 11.468.542-9
# San Andres Del Valle RECONTACTO No No False
# 11.492.842-9
# Edificio Mil610 RECONTACTO No No False
# 11.492.842-9
# Edificio Mil610 RECONTACTO No No False
# 11.492.842-9
# Edificio Mil610 RECONTACTO No No False
# 11.492.842-9
# Edificio Mil610 RECONTACTO No No False
# 11.493.548-4
# San Andres Del Valle RECONTACTO No No False
# 11.493.548-4
# San Andres Del Valle RECONTACTO No No False
# 11.493.548-4
# San Andres Del Valle RECONTACTO No No False
# 11.493.588-3
# Edificio Mil610 EVENTOS No No False
# 11.495.487-K
# Edificio Urban 1470 FINCO No No False
# 11.495.822-0
# San Andres Del Valle RECORRIDO POR EL SECTOR Si Si False
# 11.501.343-2
# San Andres Del Valle RECONTACTO Si Si False
# 11.537.425-7
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 11.537.783-3
# Edificio Urban 1470 FINCO No No False
# 11.569.893-1
# San Andres Del Valle RECONTACTO Si Si False
# 11.570.114-2
# Edificio Urban 1470 FINCO No No False
# 11.571.110-5
# Edificio Urban 1470 REFERIDOS No No False
# 11.571.110-5
# Edificio Urban 1470 REFERIDOS No No False
# 11.571.110-5
# Edificio Urban 1470 RECONTACTO No No False
# 11.572.060-0
# San Andres Del Valle RECONTACTO No No True
# 11.572.060-0
# San Andres Del Valle RECONTACTO No No True
# 11.582.754-5
# San Andres Del Valle FINCO Si Si False
# 11.582.754-5
# San Andres Del Valle FINCO Si Si True
# 11.583.365-0
# San Andres Del Valle RECONTACTO No No True
# 11.583.365-0
# San Andres Del Valle RECONTACTO No No True
# 11.621.915-8
# San Andres Del Valle FINCO Si Si False
# 11.631.525-4
# San Andres Del Valle RECONTACTO Si Si False
# 11.631.525-4
# San Andres Del Valle RECONTACTO Si Si False
# 11.631.525-4
# San Andres Del Valle RECONTACTO Si Si False
# 11.677.730-4
# Edificio Mil610 RECORRIDO POR EL SECTOR Si Si False
# 11.677.730-4
# Edificio Mil610 RECORRIDO POR EL SECTOR Si Si False
# 11.677.730-4
# Edificio Mil610 RECORRIDO POR EL SECTOR Si Si False
# 11.678.193-K
# Edificio Urban 1470 INTERNET No No False
# 11.678.289-8
# Edificio Urban 1470 FINCO No No False
# 11.679.955-3
# San Andres Del Valle FINCO No No False
# 11.682.150-8
# San Andres Del Valle RECONTACTO No No False
# 11.685.504-6
# San Andres Del Valle INTERNET Si Si False
# 11.687.356-7
# Edificio Urban 1470 REFERIDOS No No False
# 11.699.470-4
# San Andres Del Valle FINCO No No False
# 11.699.470-4
# San Andres Del Valle FINCO No No True
# 11.699.808-4
# Edificio Urban 1470 FINCO No No False
# 11.704.750-4
# Altos del Valle RECORRIDO POR EL SECTOR No No False
# 11.774.825-1
# San Andres Del Valle RECONTACTO No No False
# 11.774.825-1
# San Andres Del Valle RECONTACTO No No False
# 11.774.825-1
# San Andres Del Valle RECONTACTO No No False
# 11.774.825-1
# San Andres Del Valle RECONTACTO No No False
# 11.824.699-3
# San Andres Del Valle RECONTACTO No No False
# 11.835.549-0
# San Andres Del Valle RECONTACTO No No False
# 11.896.358-k
# Edificio Mil610 RECONTACTO No No False
# 11.896.415-2
# Edificio Urban 1470 FINCO No No False
# 11.896.505-1
# San Andres Del Valle RECORRIDO POR EL SECTOR No No True
# 11.896.950-2
# San Andres Del Valle INTERNET Si Si False
# 11.896.950-2
# San Andres Del Valle INTERNET Si Si True
# 11.897.047-0
# Edificio Urban 1470 RECORRIDO POR EL SECTOR No No False
# 11.897.173-6
# San Andres Del Valle INTERNET Si Si False
# 11.897.173-6
# San Andres Del Valle INTERNET Si Si False
# 11.897.397-6
# San Andres Del Valle FINCO No No False
# 11.898.429-3
# San Andres Del Valle RECONTACTO No No True
# 11.898.967-8
# Edificio Urban 1470 INTERNET No No False
# 11.900.777-1
# San Andres Del Valle RECONTACTO No No True
# 11.900.777-1
# San Andres Del Valle RECONTACTO No No True
# 11.900.777-1
# San Andres Del Valle RECONTACTO No No True
# 11.900.777-1
# San Andres Del Valle INTERNET Si Si True
# 11.901.004-7
# Edificio Urban 1470 FINCO No No False
# 11.902.644-K
# San Andres Del Valle FINCO No No False
# 11.903.043-9
# San Andres Del Valle RECONTACTO No No False
# 11.903.043-9
# San Andres Del Valle RECONTACTO No No True
# 11.903.043-9
# San Andres Del Valle RECONTACTO No No True
# 11.903.947-9
# Edificio Mil610 RECONTACTO No No False
# 11.928.191-1
# San Andres Del Valle FINCO No No False
# 11.943.281-2
# San Andres Del Valle RECONTACTO Si Si False
# 11.946.680-6
# Edificio Urban 1470 FINCO No No False
# 11.956.403-4
# Edificio Urban 1470 FINCO No No False
# 11.963.070-3
# San Andres Del Valle RECONTACTO No No False
# 11.963.070-3
# San Andres Del Valle RECONTACTO No No False
# 11.963.692-2
# San Andres Del Valle RECONTACTO No No False
# 11.963.692-2
# San Andres Del Valle RECONTACTO No No False
# 11.963.692-2
# San Andres Del Valle RECONTACTO No No False
# 11.966.351-2
# Edificio Urban 1470 INTERNET No No False
# 11.984.618-8
# San Andres Del Valle RECONTACTO No No True
# 11.984.618-8
# San Andres Del Valle RECONTACTO No No True
# 11.986.490-9
# San Andres Del Valle INTERNET No No False
# 11.986.911-0
# San Andres Del Valle RECONTACTO No No True
# 11.987.756-3
# Edificio Mil610 RECONTACTO No No False
# 12.007.730-9
# Edificio Urban 1470 FINCO No No False
# 12.018.043-6
# Edificio Urban 1470 FINCO No No False
# 12.028.813-k
# San Andres Del Valle INTERNET Si Si False
# 12.028.813-k
# San Andres Del Valle INTERNET Si Si False
# 12.028.813-k
# San Andres Del Valle INTERNET Si Si False
# 12.028.813-k
# San Andres Del Valle RECONTACTO No No False
# 12.028.855-5
# San Andres Del Valle INTERNET Si Si False
# 12.028.855-5
# San Andres Del Valle RECONTACTO No No False
# 12.035.115-k
# San Andres Del Valle REFERIDOS No No True
# 12.073.545-4
# Altos del Valle INTERNET Si Si False
# 12.073.545-4
# Altos del Valle INTERNET Si Si False
# 12.082.863-0
# San Andres Del Valle INTERNET No No False
# 12.083.736-2
# San Andres Del Valle RECONTACTO No No False
# 12.112.503-k
# San Andres Del Valle REFERIDOS No No True
# 12.114.019-5
# San Andres Del Valle RECORRIDO POR EL SECTOR No No True
# 12.120.812-1
# San Andres Del Valle INTERNET Si Si False
# 12.120.812-1
# San Andres Del Valle INTERNET Si Si False
# 12.132.168-8
# Edificio Junge RECONTACTO No No False
# 12.132.168-8
# Edificio Junge RECONTACTO No No False
# 12.132.168-8
# Edificio Junge RECONTACTO No No False
# 12.132.168-8
# Edificio Junge RECONTACTO No No False
# 12.137.489-7
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 12.137.489-7
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 12.137.489-7
# Edificio Urban 1470 RECORRIDO POR EL SECTOR No No True
# 12.141.201-2
# Edificio Urban 1470 RECORRIDO POR EL SECTOR Si Si False
# 12.142.839-3
# San Andres Del Valle FINCO No No False
# 12.143.630-2
# San Andres Del Valle RECONTACTO Si Si False
# 12.154.155-6
# San Andres Del Valle INTERNET Si Si False
# 12.161.476-6
# San Andres Del Valle RECONTACTO No No False
# 12.181.016-6
# San Andres Del Valle RECONTACTO Si Si True
# 12.181.016-6
# San Andres Del Valle RECONTACTO No No True
# 12.181.016-6
# San Andres Del Valle RECONTACTO No No True
# 12.182.826-k
# San Andres Del Valle RECONTACTO Si Si False
# 12.187.396-6
# Edificio Mil610 RECONTACTO No No False
# 12.187.442-3
# San Andres Del Valle RECONTACTO No No False
# 12.187.442-3
# San Andres Del Valle RECONTACTO No No False
# 12.187.442-3
# San Andres Del Valle RECONTACTO No No False
# 12.187.442-3
# San Andres Del Valle FINCO No No True
# 12.187.442-3
# San Andres Del Valle FINCO No No True
# 12.193.132-k
# Edificio Urban 1470 FINCO No No False
# 12.261.869-2
# San Andres Del Valle INTERNET No No False
# 12.288.162-8
# Edificio Urban 1470 RECONTACTO No No False
# 12.299.188-1
# San Andres Del Valle RECONTACTO No No False
# 12.299.188-1
# San Andres Del Valle RECONTACTO No No False
# 12.300.136-2
# San Andres Del Valle RECONTACTO No No False
# 12.302.618-7
# San Andres Del Valle REFERIDOS No No True
# 12.318.328-2
# Edificio Urban 1470 RECONTACTO Si Si True
# 12.318.328-2
# Edificio Urban 1470 RECONTACTO Si Si False
# 12.326.138-0
# Edificio Urban 1470 INTERNET No No False
# 12.326.138-0
# Edificio Urban 1470 INTERNET No No False
# 12.329.033-K
# San Andres Del Valle FINCO No No False
# 12.329.033-K
# San Andres Del Valle FINCO No No False
# 12.329.033-K
# San Andres Del Valle FINCO No No False
# 12.332.355-6
# Edificio Urban 1470 INTERNET Si Si False
# 12.332.355-6
# Edificio Urban 1470 INTERNET Si Si True
# 12.332.678-4
# San Andres Del Valle RECONTACTO No No True
# 12.332.678-4
# San Andres Del Valle RECONTACTO No No True
# 12.380.987-4
# Edificio Urban 1470 RECORRIDO POR EL SECTOR Si Si False
# 12.380.987-4
# Edificio Urban 1470 INTERNET No No False
# 12.381.126-7
# Edificio Urban 1470 FINCO No No False
# 12.381.629-3
# San Andres Del Valle RECORRIDO POR EL SECTOR Si Si False
# 12.487.518-8
# Edificio Urban 1470 FINCO No No False
# 12.498.210-3
# San Andres Del Valle FINCO No No False
# 12.523.441-0
# San Andres Del Valle RECONTACTO Si Si False
# 12.524.132-8
# Altos del Valle RECONTACTO No No False
# 12.524.132-8
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 12.524.132-8
# San Andres Del Valle RECONTACTO No No True
# 12.524.132-8
# San Andres Del Valle RECONTACTO No No True
# 12.524.814-4
# San Andres Del Valle FINCO No No True
# 12.526.002-0
# San Andres Del Valle REFERIDOS No No True
# 12.527.807-8
# San Andres Del Valle RECONTACTO No No False
# 12.527.807-8
# San Andres Del Valle RECONTACTO No No True
# 12.527.807-8
# San Andres Del Valle RECONTACTO No No True
# 12.527.807-8
# San Andres Del Valle RECONTACTO No No False
# 12.527.807-8
# San Andres Del Valle RECONTACTO No No True
# 12.527.807-8
# San Andres Del Valle RECONTACTO No No True
# 12.527.807-8
# San Andres Del Valle RECONTACTO No No True
# 12.528.281-4
# Edificio Urban 1470 RECONTACTO Si Si False
# 12.528.281-4
# Edificio Urban 1470 INTERNET No No False
# 12.528.437-k
# Edificio Mil610 INTERNET Si Si False
# 12.529.962-8
# Altos del Valle INTERNET Si Si False
# 12.531.567-4
# Edificio Mil610 RECONTACTO No No False
# 12.548.392-5
# San Andres Del Valle RECONTACTO No No True
# 12.548.392-5
# San Andres Del Valle RECONTACTO No No True
# 12.548.392-5
# San Andres Del Valle RECONTACTO No No False
# 12.548.392-5
# San Andres Del Valle RECONTACTO No No False
# 12.550.894-4
# San Andres Del Valle RECONTACTO Si Si False
# 12.550.894-4
# San Andres Del Valle RECONTACTO Si Si False
# 12.553.027-3
# San Andres Del Valle REFERIDOS No No False
# 12.553.027-3
# San Andres Del Valle REFERIDOS No No False
# 12.553.027-3
# San Andres Del Valle RECONTACTO No No True
# 12.553.027-3
# San Andres Del Valle RECONTACTO No No True
# 12.553.455-4
# San Andres Del Valle INTERNET No No False
# 12.553.455-4
# San Andres Del Valle INTERNET No No False
# 12.553.455-4
# San Andres Del Valle INTERNET No No False
# 12.553.842-8
# San Andres Del Valle RECONTACTO No No True
# 12.554.257-3
# San Andres Del Valle RECONTACTO Si Si False
# 12.554.257-3
# San Andres Del Valle RECONTACTO Si Si False
# 12.554.983-7
# San Andres Del Valle REFERIDOS No No False
# 12.554.983-7
# San Andres Del Valle RECONTACTO No No False
# 12.554.983-7
# San Andres Del Valle RECONTACTO No No False
# 12.556.307-4
# San Andres Del Valle RECONTACTO No No True
# 12.560.783-7
# Edificio Urban 1470 FINCO No No False
# 12.589.268-K
# Edificio Urban 1470 FINCO No No False
# 12.615.588-3
# San Andres Del Valle INTERNET No No False
# 12.620.994-0
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 12.620.994-0
# San Andres Del Valle RECORRIDO POR EL SECTOR No No True
# 12.656.520-8
# San Andres Del Valle RECONTACTO No No True
# 12.662.024-1
# Edificio Mil610 INTERNET Si Si False
# 12.695.985-0
# San Andres Del Valle RECONTACTO No No False
# 12.695.985-0
# San Andres Del Valle RECONTACTO No No False
# 12.695.985-0
# San Andres Del Valle RECONTACTO No No False
# 12.695.985-0
# San Andres Del Valle RECONTACTO No No True
# 12.695.985-0
# San Andres Del Valle RECONTACTO No No True
# 12.696.165-0
# San Andres Del Valle RECONTACTO No No False
# 12.696.165-0
# San Andres Del Valle RECONTACTO No No False
# 12.696.165-0
# San Andres Del Valle RECONTACTO No No False
# 12.697.013-7
# Edificio Urban 1470 INTERNET Si Si False
# 12.697.338-1
# Altos del Valle RECONTACTO No No False
# 12.697.496-5
# San Andres Del Valle RECONTACTO No No True
# 12.697.496-5
# San Andres Del Valle RECONTACTO No No True
# 12.698.377-8
# San Andres Del Valle INTERNET Si Si True
# 12.698.906-7
# Edificio Urban 1470 FINCO No No False
# 12.699.942-9
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 12.699.942-9
# San Andres Del Valle RECONTACTO No No False
# 12.699.942-9
# San Andres Del Valle RECONTACTO No No False
# 12.700.311-4
# San Andres Del Valle INTERNET Si Si False
# 12.700.311-4
# San Andres Del Valle INTERNET Si Si False
# 12.700.311-4
# San Andres Del Valle INTERNET Si Si False
# 12.702.320-4
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 12.702.320-4
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 12.702.424-3
# San Andres Del Valle RECORRIDO POR EL SECTOR No No True
# 12.702.424-3
# San Andres Del Valle RECONTACTO No No False
# 12.709.577-9
# San Andres Del Valle FINCO No No False
# 12.722.074-3
# San Andres Del Valle RECONTACTO No No False
# 12.722.074-3
# San Andres Del Valle RECONTACTO Si Si False
# 12.729.942-0
# San Andres Del Valle FINCO No No False
# 12.732.521-9
# Edificio Urban 1470 INTERNET No No False
# 12.732.636-3
# Edificio Urban 1470 INTERNET No No False
# 12.732.636-3
# Edificio Urban 1470 RECORRIDO POR EL SECTOR Si Si False
# 12.733.181-2
# San Andres Del Valle RECONTACTO No No True
# 12.735.204-6
# San Andres Del Valle INTERNET Si Si False
# 12.735.204-6
# San Andres Del Valle INTERNET Si Si False
# 12.735.204-6
# San Andres Del Valle INTERNET Si Si False
# 12.735.204-6
# San Andres Del Valle INTERNET Si Si False
# 12.740.137-3
# Edificio Urban 1470 REFERIDOS No No True
# 12.749.021-k
# San Andres Del Valle RECONTACTO Si Si False
# 12.749.021-k
# San Andres Del Valle RECONTACTO Si Si True
# 12.749.021-k
# San Andres Del Valle RECONTACTO Si Si True
# 12.764.758-5
# San Andres Del Valle INTERNET No No False
# 12.766.588-5
# San Andres Del Valle INTERNET Si Si False
# 12.766.588-5
# San Andres Del Valle INTERNET Si Si False
# 12.766.588-5
# San Andres Del Valle INTERNET Si Si False
# 12.771.954-3
# San Andres Del Valle FINCO Si Si True
# 12.771.954-3
# San Andres Del Valle FINCO No No True
# 12.778.443-4
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 12.793.453-3
# San Andres Del Valle RECONTACTO Si Si False
# 12.793.453-3
# San Andres Del Valle RECONTACTO Si Si False
# 12.796.159-K
# Edificio Urban 1470 FINCO No No False
# 12.796.213-8
# San Andres Del Valle RECONTACTO No No False
# 12.796.213-8
# San Andres Del Valle RECONTACTO No No False
# 12.796.213-8
# San Andres Del Valle RECONTACTO No No True
# 12.796.213-8
# San Andres Del Valle RECONTACTO No No True
# 12.819.862-8
# San Andres Del Valle RECONTACTO Si Si False
# 12.834.305-9
# San Andres Del Valle RECONTACTO No No True
# 12.834.305-9
# San Andres Del Valle RECONTACTO No No False
# 12.850.535-0
# San Andres Del Valle FINCO No No False
# 12.862.679-4
# Edificio Urban 1470 LETREROS No No False
# 12.917.859-0
# Edificio Urban 1470 FINCO No No False
# 12.918.270-9
# Edificio Urban 1470 FINCO No No False
# 12.919.263-1
# San Andres Del Valle RECONTACTO No No False
# 12.919.263-1
# San Andres Del Valle RECONTACTO No No False
# 12.919.263-1
# San Andres Del Valle RECONTACTO No No True
# 12.919.263-1
# San Andres Del Valle RECONTACTO No No True
# 12.920.845-7
# Edificio Urban 1470 INTERNET No No False
# 12.922.084-8
# San Andres Del Valle INTERNET Si Si False
# 12.923.181-5
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 12.923.181-5
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 12.923.271-4
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 12.924.552-2
# San Andres Del Valle RECONTACTO No No False
# 12.924.552-2
# San Andres Del Valle RECORRIDO POR EL SECTOR No No True
# 12.924.552-2
# San Andres Del Valle RECONTACTO No No True
# 12.924.552-2
# San Andres Del Valle LETREROS No No False
# 12.924.552-2
# San Andres Del Valle RECONTACTO No No False
# 12.926.706-2
# San Andres Del Valle LETREROS No No False
# 12.926.706-2
# San Andres Del Valle RECONTACTO No No False
# 12.969.798-9
# San Andres Del Valle RECONTACTO No No False
# 12.969.798-9
# San Andres Del Valle RECONTACTO No No False
# 12.969.798-9
# San Andres Del Valle RECONTACTO No No False
# 12.972.300-9
# Altos del Valle RECONTACTO No No False
# 12.972.958-9
# San Andres Del Valle RECONTACTO No No False
# 12.973.266-0
# San Andres Del Valle RECORRIDO POR EL SECTOR No No True
# 12.973.266-0
# San Andres Del Valle RECONTACTO Si Si True
# 12.973.266-0
# San Andres Del Valle RECONTACTO No No True
# 12.973.266-0
# San Andres Del Valle RECONTACTO No No True
# 12.973.373-k
# San Andres Del Valle RECONTACTO No No False
# 12.973.373-k
# San Andres Del Valle RECONTACTO No No False
# 12.973.373-k
# San Andres Del Valle RECONTACTO No No True
# 12.973.373-k
# San Andres Del Valle RECONTACTO No No True
# 12.973.373-k
# San Andres Del Valle RECONTACTO No No True
# 12.973.373-k
# San Andres Del Valle RECONTACTO No No True
# 12.973.373-k
# San Andres Del Valle RECONTACTO No No False
# 12.973.374-8
# San Andres Del Valle FINCO No No False
# 12.973.374-8
# San Andres Del Valle RECONTACTO No No False
# 12.974.804-4
# Edificio Mil610 RECORRIDO POR EL SECTOR No No False
# 12.974.804-4
# Edificio Mil610 RECORRIDO POR EL SECTOR No No False
# 12.975.518-0
# Edificio Urban 1470 RECORRIDO POR EL SECTOR Si Si False
# 12.975.518-0
# Edificio Urban 1470 RECORRIDO POR EL SECTOR Si Si False
# 12.975.771-k
# San Andres Del Valle INTERNET No No False
# 12.975.845-7
# San Andres Del Valle INTERNET Si Si False
# 12.975.845-7
# San Andres Del Valle INTERNET Si Si False
# 12.975.973-9
# Edificio Mil610 RECONTACTO No No False
# 12.979.333-3
# San Andres Del Valle RECONTACTO No No False
# 13.005.940-6
# San Andres Del Valle RECONTACTO Si Si False
# 13.005.940-6
# San Andres Del Valle RECONTACTO Si Si False
# 13.068.456-4
# Edificio Mil610 RECORRIDO POR EL SECTOR No No False
# 13.069.668-6
# San Andres Del Valle RECORRIDO POR EL SECTOR Si Si False
# 13.069.668-6
# San Andres Del Valle RECORRIDO POR EL SECTOR Si Si False
# 13.077.929-8
# Edificio Urban 1470 FINCO No No False
# 13.098.189-5
# Edificio Mil610 RECONTACTO No No False
# 13.102.633-1
# San Andres Del Valle FINCO No No True
# 13.102.644-7
# Edificio Urban 1470 RECONTACTO No No False
# 13.103.501-2
# San Andres Del Valle RECONTACTO No No True
# 13.103.505-5
# San Andres Del Valle RECONTACTO No No False
# 13.103.505-5
# San Andres Del Valle RECONTACTO No No False
# 13.103.505-5
# San Andres Del Valle RECONTACTO No No False
# 13.103.505-5
# San Andres Del Valle RECONTACTO Si Si False
# 13.103.505-5
# San Andres Del Valle RECONTACTO Si Si False
# 13.103.909-4
# Edificio Urban 1470 INTERNET No No False
# 13.104.169-1
# San Andres Del Valle INTERNET Si Si False
# 13.104.169-1
# San Andres Del Valle INTERNET Si Si False
# 13.104.169-1
# San Andres Del Valle INTERNET Si Si False
# 13.104.403-8
# Altos del Valle INTERNET Si Si False
# 13.105.034-8
# Edificio Urban 1470 INTERNET No No False
# 13.105.124-7
# San Andres Del Valle INTERNET Si Si False
# 13.105.124-7
# San Andres Del Valle INTERNET Si Si False
# 13.105.206-5
# San Andres Del Valle RECONTACTO No No True
# 13.106.654-6
# San Andres Del Valle FINCO No No False
# 13.106.654-6
# San Andres Del Valle FINCO No No False
# 13.107.429-8
# San Andres Del Valle FINCO Si Si False
# 13.107.625-8
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 13.107.720-3
# San Andres Del Valle INTERNET Si Si False
# 13.116.858-6
# San Andres Del Valle RECONTACTO No No True
# 13.116.858-6
# San Andres Del Valle RECONTACTO No No True
# 13.117.727-5
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 13.117.727-5
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 13.117.727-5
# San Andres Del Valle RECONTACTO No No False
# 13.126.434-8
# San Andres Del Valle RECONTACTO No No True
# 13.126.458-5
# San Andres Del Valle INTERNET No No False
# 13.126.458-5
# San Andres Del Valle RECONTACTO No No False
# 13.126.458-5
# San Andres Del Valle RECONTACTO No No False
# 13.126.458-5
# San Andres Del Valle RECONTACTO No No False
# 13.130.752-7
# Edificio Mil610 RECONTACTO No No False
# 13.130.752-7
# San Andres Del Valle RECONTACTO No No False
# 13.132.593-2
# San Andres Del Valle RECONTACTO No No False
# 13.132.593-2
# San Andres Del Valle RECONTACTO No No False
# 13.132.593-2
# San Andres Del Valle RECONTACTO No No False
# 13.132.593-2
# San Andres Del Valle RECONTACTO No No False
# 13.132.593-2
# San Andres Del Valle RECONTACTO No No False
# 13.133.134-7
# Edificio Urban 1470 INTERNET Si Si True
# 13.133.171-1
# Edificio Mil610 INTERNET Si Si False
# 13.133.452-4
# Edificio Urban 1470 RECORRIDO POR EL SECTOR Si Si False
# 13.133.758-2
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 13.133.866-k
# San Andres Del Valle REFERIDOS No No False
# 13.133.866-k
# San Andres Del Valle REFERIDOS No No False
# 13.133.866-k
# San Andres Del Valle REFERIDOS No No False
# 13.133.866-k
# San Andres Del Valle RECONTACTO No No False
# 13.134.302-7
# Edificio Urban 1470 FINCO No No False
# 13.134.981-5
# Edificio Mil610 INTERNET No No False
# 13.134.981-5
# Edificio Mil610 INTERNET No No False
# 13.134.981-5
# Edificio Mil610 INTERNET No No False
# 13.135.119-4
# San Andres Del Valle INTERNET Si Si False
# 13.135.119-4
# San Andres Del Valle RECONTACTO No No True
# 13.136.616-7
# San Andres Del Valle RECONTACTO No No False
# 13.136.819-4
# Edificio Mil610 RECONTACTO No No False
# 13.137.486-0
# San Andres Del Valle RECONTACTO No No True
# 13.137.784-3
# San Andres Del Valle RECORRIDO POR EL SECTOR Si Si False
# 13.145.693-K
# Edificio Urban 1470 FINCO No No False
# 13.147.372-9
# Edificio Mil610 RECONTACTO No No False
# 13.147.372-9
# Edificio Mil610 RECONTACTO No No False
# 13.147.372-9
# Edificio Mil610 RECONTACTO No No False
# 13.147.372-9
# Edificio Mil610 RECONTACTO No No False
# 13.148.125-k
# San Andres Del Valle REFERIDOS No No False
# 13.148.125-k
# San Andres Del Valle REFERIDOS No No False
# 13.148.125-k
# San Andres Del Valle REFERIDOS No No False
# 13.148.125-k
# San Andres Del Valle REFERIDOS No No False
# 13.172.456-k
# Edificio Urban 1470 FINCO No No False
# 13.192.077-6
# San Andres Del Valle LETREROS No No False
# 13.210.276-7
# San Andres Del Valle RECONTACTO No No True
# 13.210.276-7
# San Andres Del Valle RECONTACTO No No True
# 13.234.833-2
# San Andres Del Valle RECONTACTO No No False
# 13.234.833-2
# San Andres Del Valle RECONTACTO No No False
# 13.234.833-2
# San Andres Del Valle RECONTACTO No No False
# 13.234.833-2
# San Andres Del Valle RECONTACTO No No False
# 13.256.553-8
# San Andres Del Valle REFERIDOS No No False
# 13.281.974-2
# San Andres Del Valle RECONTACTO No No True
# 13.306.269-6
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 13.306.269-6
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 13.306.414-1
# San Andres Del Valle RECONTACTO No No True
# 13.306.414-1
# San Andres Del Valle RECONTACTO No No True
# 13.306.613-6
# Edificio Junge INTERNET Si Si False
# 13.306.613-6
# Edificio Junge INTERNET Si Si False
# 13.306.613-6
# Edificio Junge INTERNET Si Si False
# 13.307.174-1
# San Andres Del Valle RECORRIDO POR EL SECTOR No No True
# 13.307.174-1
# San Andres Del Valle RECONTACTO No No True
# 13.307.174-1
# San Andres Del Valle RECONTACTO No No True
# 13.307.323-k
# San Andres Del Valle RECONTACTO No No True
# 13.307.323-k
# San Andres Del Valle RECONTACTO No No True
# 13.308.879-2
# San Andres Del Valle INTERNET Si Si False
# 13.308.879-2
# San Andres Del Valle INTERNET Si Si False
# 13.308.934-9
# Edificio Urban 1470 INTERNET No No False
# 13.308.962-4
# Edificio Urban 1470 FINCO No No False
# 13.309.838-0
# Edificio Urban 1470 RECORRIDO POR EL SECTOR Si Si False
# 13.309.929-8
# Edificio Urban 1470 INTERNET No No False
# 13.309.929-8
# Edificio Urban 1470 INTERNET No No False
# 13.309.954-9
# Altos del Valle RECONTACTO No No True
# 13.310.071-7
# San Andres Del Valle INTERNET Si Si False
# 13.310.071-7
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 13.310.521-2
# San Andres Del Valle REFERIDOS No No False
# 13.310.521-2
# San Andres Del Valle RECONTACTO No No True
# 13.311.686-9
# San Andres Del Valle RECONTACTO No No False
# 13.311.686-9
# San Andres Del Valle RECONTACTO No No False
# 13.311.686-9
# San Andres Del Valle RECONTACTO No No False
# 13.311.686-9
# San Andres Del Valle RECONTACTO No No False
# 13.313.168-K
# San Andres Del Valle REFERIDOS No No False
# 13.313.168-K
# San Andres Del Valle REFERIDOS No No False
# 13.313.168-K
# San Andres Del Valle REFERIDOS No No True
# 13.313.168-K
# San Andres Del Valle RECONTACTO No No True
# 13.315.154-0
# San Andres Del Valle RECONTACTO No No False
# 13.315.154-0
# San Andres Del Valle RECONTACTO No No False
# 13.325.708-K
# San Andres Del Valle RECONTACTO No No False
# 13.325.708-K
# San Andres Del Valle RECONTACTO No No False
# 13.336.368-8
# San Andres Del Valle RECONTACTO No No True
# 13.336.368-8
# San Andres Del Valle RECONTACTO No No True
# 13.336.368-8
# San Andres Del Valle RECONTACTO No No True
# 13.336.368-8
# San Andres Del Valle RECONTACTO No No False
# 13.377.606-0
# Edificio Urban 1470 RECONTACTO No No False
# 13.377.606-0
# Edificio Urban 1470 RECONTACTO No No False
# 13.380.512-5
# Edificio Urban 1470 RECORRIDO POR EL SECTOR Si Si False
# 13.380.781-0
# Edificio Urban 1470 FINCO No No False
# 13.380.975-9
# San Andres Del Valle FINCO No No False
# 13.382.230-5
# San Andres Del Valle INTERNET Si Si False
# 13.382.230-5
# San Andres Del Valle INTERNET Si Si False
# 13.383.152-5
# San Andres Del Valle RECONTACTO No No False
# 13.389.182-k
# Edificio Urban 1470 RECONTACTO No No False
# 13.389.361-k
# San Andres Del Valle FINCO No No True
# 13.390.356-9
# San Andres Del Valle FINCO No No False
# 13.393.044-2
# Edificio Mil610 RECONTACTO No No False
# 13.393.044-2
# Edificio Mil610 RECORRIDO POR EL SECTOR Si Si False
# 13.393.044-2
# Edificio Mil610 RECONTACTO No No False
# 13.420.858-9
# San Andres Del Valle INTERNET Si Si False
# 13.427.435-2
# San Andres Del Valle INTERNET No No False
# 13.448.493-4
# San Andres Del Valle RECONTACTO No No False
# 13.456.276-5
# Edificio Urban 1470 FINCO No No False
# 13.506.568-4
# Edificio Mil610 RECONTACTO No No False
# 13.507.027-0
# San Andres Del Valle RECONTACTO No No False
# 13.507.738-0
# Edificio Urban 1470 INTERNET No No False
# 13.507.738-0
# Edificio Urban 1470 INTERNET No No False
# 13.507.738-0
# Edificio Urban 1470 INTERNET No No False
# 13.508.013-6
# Edificio Junge RECONTACTO No No False
# 13.508.270-8
# San Andres Del Valle RECONTACTO No No False
# 13.508.270-8
# San Andres Del Valle RECONTACTO No No True
# 13.508.270-8
# San Andres Del Valle FINCO No No True
# 13.508.645-2
# San Andres Del Valle INTERNET No No False
# 13.508.645-2
# San Andres Del Valle INTERNET No No True
# 13.510.489-2
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 13.510.721-2
# Edificio Urban 1470 FINCO No No False
# 13.510.967-3
# Edificio Mil610 RECORRIDO POR EL SECTOR Si Si False
# 13.512.102-9
# San Andres Del Valle RECONTACTO No No False
# 13.512.102-9
# San Andres Del Valle RECONTACTO No No False
# 13.512.102-9
# San Andres Del Valle RECONTACTO No No False
# 13.512.403-6
# Edificio Urban 1470 FINCO No No False
# 13.512.952-6
# San Andres Del Valle RECONTACTO No No True
# 13.521.552-k
# San Andres Del Valle INTERNET No No False
# 13.548.562-4
# San Andres Del Valle RECONTACTO No No False
# 13.548.562-4
# San Andres Del Valle RECONTACTO No No True
# 13.548.562-4
# San Andres Del Valle RECONTACTO No No False
# 13.577.947-4
# San Andres Del Valle FINCO No No True
# 13.580.015-5
# San Andres Del Valle INTERNET No No False
# 13.580.015-5
# San Andres Del Valle INTERNET No No False
# 13.580.015-5
# San Andres Del Valle INTERNET No No False
# 13.580.015-5
# San Andres Del Valle INTERNET No No False
# 13.580.015-5
# San Andres Del Valle INTERNET No No False
# 13.580.015-5
# San Andres Del Valle INTERNET No No False
# 13.580.015-5
# San Andres Del Valle INTERNET No No False
# 13.581.726-0
# San Andres Del Valle RECONTACTO No No True
# 13.597.477-3
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 13.597.477-3
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 13.602.263-6
# Edificio Urban 1470 FINCO No No False
# 13.603.605-k
# San Andres Del Valle RECORRIDO POR EL SECTOR Si Si False
# 13.604.689-6
# San Andres Del Valle INTERNET Si Si False
# 13.604.689-6
# San Andres Del Valle INTERNET Si Si False
# 13.604.689-6
# San Andres Del Valle INTERNET Si Si False
# 13.605.449-K
# San Andres Del Valle FINCO No No False
# 13.608.443-7
# Edificio Urban 1470 RECONTACTO No No False
# 13.608.443-7
# Edificio Urban 1470 RECONTACTO No No False
# 13.608.443-7
# Edificio Urban 1470 RECONTACTO No No False
# 13.608.443-7
# Edificio Urban 1470 RECONTACTO No No False
# 13.610.394-6
# Edificio Urban 1470 FINCO No No False
# 13.611.348-8
# San Andres Del Valle INTERNET Si Si False
# 13.619.601-4
# San Andres Del Valle INTERNET No No False
# 13.625.005-1
# San Andres Del Valle INTERNET Si Si False
# 13.625.005-1
# San Andres Del Valle INTERNET Si Si False
# 13.625.005-1
# San Andres Del Valle RECONTACTO No No False
# 13.625.065-5
# San Andres Del Valle RECONTACTO No No False
# 13.625.576-2
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 13.625.576-2
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 13.625.641-6
# San Andres Del Valle INTERNET Si Si False
# 13.628.528-9
# San Andres Del Valle RECONTACTO No No False
# 13.628.528-9
# San Andres Del Valle RECONTACTO Si Si True
# 13.628.528-9
# San Andres Del Valle RECONTACTO Si Si False
# 13.635.633-k
# San Andres Del Valle INTERNET No No False
# 13.635.633-k
# San Andres Del Valle INTERNET No No False
# 13.660.093-1
# San Andres Del Valle RECONTACTO No No True
# 13.723.285-5
# Edificio Mil610 RECONTACTO No No False
# 13.723.296-0
# Edificio Urban 1470 INTERNET No No False
# 13.723.990-6
# San Andres Del Valle FINCO No No False
# 13.724.549-3
# Edificio Urban 1470 INTERNET Si Si False
# 13.724.549-3
# Edificio Urban 1470 INTERNET Si Si False
# 13.724.549-3
# Edificio Urban 1470 INTERNET Si Si True
# 13.725.016-0
# Edificio Mil610 RECONTACTO No No False
# 13.725.016-0
# Edificio Mil610 RECONTACTO No No False
# 13.725.016-0
# Edificio Mil610 RECONTACTO No No False
# 13.725.016-0
# San Andres Del Valle RECONTACTO Si Si False
# 13.725.016-0
# San Andres Del Valle RECONTACTO Si Si False
# 13.725.016-0
# San Andres Del Valle RECONTACTO Si Si False
# 13.725.049-7
# San Andres Del Valle RECONTACTO Si Si False
# 13.725.192-2
# San Andres Del Valle RECONTACTO No No False
# 13.725.223-6
# Edificio Urban 1470 REFERIDOS No No False
# 13.725.533-2
# San Andres Del Valle INTERNET Si Si False
# 13.760.470-1
# Edificio Mil610 RECONTACTO No No False
# 13.778.363-0
# Edificio Junge RECORRIDO POR EL SECTOR Si Si False
# 13.778.363-0
# Edificio Mil610 RECONTACTO No No False
# 13.778.363-0
# Edificio Mil610 RECONTACTO No No False
# 13.793.287-3
# Edificio Urban 1470 RECORRIDO POR EL SECTOR No No False
# 13.794.500-2
# San Andres Del Valle RECONTACTO No No False
# 13.795.707-8
# San Andres Del Valle RECONTACTO No No True
# 13.795.707-8
# San Andres Del Valle RECONTACTO No No True
# 13.796.015-k
# San Andres Del Valle RECONTACTO No No False
# 13.796.831-2
# San Andres Del Valle RECONTACTO No No False
# 13.796.831-2
# San Andres Del Valle RECONTACTO No No False
# 13.796.831-2
# San Andres Del Valle RECONTACTO No No False
# 13.799.068-7
# San Andres Del Valle FINCO No No False
# 13.799.970-6
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 13.799.970-6
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 13.799.970-6
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 13.801.087-2
# San Andres Del Valle FINCO No No False
# 13.801.634-k
# Edificio Urban 1470 RECORRIDO POR EL SECTOR Si Si False
# 13.804.341-k
# San Andres Del Valle RECONTACTO Si Si False
# 13.804.341-k
# San Andres Del Valle RECONTACTO Si Si False
# 13.804.341-k
# San Andres Del Valle RECONTACTO Si Si True
# 13.804.341-k
# San Andres Del Valle RECONTACTO No No True
# 13.804.883-7
# San Andres Del Valle RECORRIDO POR EL SECTOR Si Si False
# 13.842.077-9
# San Andres Del Valle RECONTACTO No No False
# 13.842.077-9
# San Andres Del Valle RECONTACTO No No False
# 13.842.771-4
# Altos del Valle RECONTACTO No No True
# 13.843.209-2
# San Andres Del Valle RECONTACTO No No True
# 13.843.209-2
# San Andres Del Valle RECONTACTO No No True
# 13.843.209-2
# San Andres Del Valle RECONTACTO No No False
# 13.846.909-3
# Edificio Urban 1470 FINCO No No False
# 13.853.044-2
# San Andres Del Valle RECONTACTO No No True
# 13.854.974-7
# San Andres Del Valle RECONTACTO No No False
# 13.858.687-1
# Edificio Urban 1470 FINCO No No False
# 13.859.184-0
# San Andres Del Valle RECONTACTO No No True
# 13.859.636-2
# San Andres Del Valle FINCO No No True
# 13.859.636-2
# San Andres Del Valle FINCO No No False
# 13.861.445-k
# San Andres Del Valle RECORRIDO POR EL SECTOR Si Si False
# 13.883.068-3
# San Andres Del Valle RECONTACTO No No True
# 13.883.068-3
# San Andres Del Valle RECONTACTO No No True
# 13.883.068-3
# San Andres Del Valle RECONTACTO No No True
# 13.883.068-3
# San Andres Del Valle RECONTACTO No No True
# 13.883.068-3
# San Andres Del Valle RECONTACTO No No True
# 13.883.068-3
# San Andres Del Valle RECONTACTO No No True
# 13.900.217-2
# San Andres Del Valle INTERNET Si Si False
# 13.900.217-2
# San Andres Del Valle RECONTACTO No No False
# 13.941.422-8
# San Andres Del Valle RECONTACTO No No False
# 13.941.422-8
# San Andres Del Valle RECONTACTO No No False
# 13.951.913-2
# San Andres Del Valle INTERNET No No False
# 13.951.954-k
# San Andres Del Valle INTERNET Si Si False
# 13.951.954-k
# San Andres Del Valle INTERNET Si Si False
# 13.951.954-k
# San Andres Del Valle INTERNET Si Si False
# 13.951.954-k
# San Andres Del Valle INTERNET Si Si False
# 13.952.049-1
# Edificio Urban 1470 FINCO No No False
# 13.952.329-6
# San Andres Del Valle RECONTACTO No No False
# 13.952.329-6
# San Andres Del Valle RECONTACTO No No False
# 13.952.329-6
# San Andres Del Valle RECONTACTO No No False
# 13.952.329-6
# San Andres Del Valle RECONTACTO No No True
# 13.952.329-6
# San Andres Del Valle RECONTACTO No No True
# 13.952.363-6
# Edificio Urban 1470 FINCO No No False
# 13.952.650-3
# Altos del Valle RECORRIDO POR EL SECTOR No No False
# 13.952.650-3
# Altos del Valle RECORRIDO POR EL SECTOR No No False
# 13.953.155-8
# Edificio Junge INTERNET Si Si False
# 13.953.155-8
# Edificio Junge INTERNET Si Si False
# 13.953.482-4
# Edificio Mil610 RECONTACTO No No False
# 13.953.845-5
# Edificio Urban 1470 RECORRIDO POR EL SECTOR Si Si False
# 13.954.197-9
# San Andres Del Valle INTERNET No No False
# 13.955.396-9
# Edificio Urban 1470 INTERNET No No False
# 13.957.635-7
# Edificio Urban 1470 RECORRIDO POR EL SECTOR Si Si False
# 13.958.743-k
# Altos del Valle RECONTACTO No No False
# 13.958.743-k
# Altos del Valle RECONTACTO No No False
# 13.959.431-2
# San Andres Del Valle RECONTACTO No No False
# 13.959.431-2
# San Andres Del Valle RECONTACTO No No False
# 13.959.562-9
# San Andres Del Valle RECONTACTO Si Si False
# 13.967.702-1
# San Andres Del Valle RECONTACTO No No False
# 13.967.702-1
# San Andres Del Valle RECONTACTO No No False
# 13.967.702-1
# San Andres Del Valle RECONTACTO No No False
# 13.967.734-k
# Edificio Urban 1470 FINCO No No False
# 13.967.734-k
# Edificio Urban 1470 FINCO No No False
# 13.971.547-0
# San Andres Del Valle REFERIDOS No No False
# 13.971.547-0
# San Andres Del Valle REFERIDOS No No False
# 13.971.547-0
# San Andres Del Valle RECONTACTO No No False
# 13.971.547-0
# San Andres Del Valle RECONTACTO No No False
# 13.971.547-0
# San Andres Del Valle RECONTACTO No No False
# 13.990.767-1
# Edificio Urban 1470 INTERNET No No False
# 13.990.767-1
# Edificio Urban 1470 INTERNET No No False
# 13.990.767-1
# Edificio Urban 1470 INTERNET No No False
# 13.994.909-9
# Altos del Valle RECONTACTO No No False
# 13.997.707-6
# Edificio Urban 1470 INTERNET Si Si True
# 14.018.165-k
# San Andres Del Valle INTERNET Si Si False
# 14.024.818-5
# San Andres Del Valle INTERNET Si Si True
# 14.024.818-5
# San Andres Del Valle RECONTACTO No No True
# 14.025.556-4
# Edificio Urban 1470 RECORRIDO POR EL SECTOR No No False
# 14.025.556-4
# Edificio Urban 1470 RECONTACTO No No False
# 14.025.556-4
# Edificio Urban 1470 RECONTACTO No No False
# 14.026.135-1
# Edificio Mil610 RECONTACTO No No False
# 14.026.135-1
# Edificio Mil610 LETREROS No No False
# 14.027.328-7
# San Andres Del Valle RECONTACTO No No False
# 14.030.103-5
# Edificio Mil610 RECONTACTO No No False
# 14.030.103-5
# Edificio Mil610 RECONTACTO No No False
# 14.030.125-6
# San Andres Del Valle INTERNET No No False
# 14.030.274-6
# San Andres Del Valle FINCO No No True
# 14.030.374-7
# Altos del Valle EVENTOS No No False
# 14.044.303-4
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 14.051.253-2
# Edificio Urban 1470 FINCO No No False
# 14.057.523-2
# Altos del Valle RECONTACTO No No True
# 14.057.523-2
# Altos del Valle RECONTACTO No No False
# 14.058.795-8
# San Andres Del Valle RECONTACTO Si Si False
# 14.058.795-8
# San Andres Del Valle RECONTACTO Si Si False
# 14.058.795-8
# San Andres Del Valle RECONTACTO No No True
# 14.058.795-8
# San Andres Del Valle RECONTACTO No No True
# 14.058.795-8
# San Andres Del Valle RECONTACTO No No True
# 14.058.795-8
# San Andres Del Valle RECONTACTO No No True
# 14.059.499-7
# San Andres Del Valle INTERNET No No False
# 14.059.668-k
# Altos del Valle RECONTACTO No No False
# 14.059.668-k
# Altos del Valle RECONTACTO No No False
# 14.059.943-3
# Edificio Urban 1470 INTERNET No No False
# 14.059.943-3
# Edificio Urban 1470 INTERNET No No False
# 14.059.943-3
# Edificio Urban 1470 INTERNET No No True
# 14.060.290-6
# San Andres Del Valle FINCO No No False
# 14.060.867-k
# San Andres Del Valle RECONTACTO Si Si False
# 14.061.851-9
# San Andres Del Valle EVENTOS No No False
# 14.062.580-9
# San Andres Del Valle RECONTACTO Si Si False
# 14.062.580-9
# San Andres Del Valle RECONTACTO Si Si False
# 14.064.458-7
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 14.066.513-4
# San Andres Del Valle RECONTACTO No No False
# 14.066.513-4
# San Andres Del Valle RECONTACTO Si Si True
# 14.066.732-3
# Edificio Urban 1470 FINCO No No False
# 14.067.673-k
# San Andres Del Valle RECORRIDO POR EL SECTOR No No True
# 14.067.673-k
# San Andres Del Valle RECONTACTO No No True
# ...
# 76.181.594-6
# Edificio Junge RECONTACTO No No True
# 76.194.872-5
# San Andres Del Valle INTERNET Si Si False
# 76.235.401-2
# Altos del Valle RECONTACTO No No False
# 76.235.401-2
# Altos del Valle RECONTACTO No No False
# 76.516.199-1
# San Andres Del Valle RECONTACTO No No True
# 76.517.824-k
# Edificio Urban 1470 REFERIDOS No No True
# 77.234.300-0
# Edificio Mil610 RECONTACTO No No False
# 78.383.710-2
# Edificio Mil610 RECONTACTO No No False
# 8.002.568-8
# Edificio Urban 1470 INTERNET No No False
# 8.002.568-8
# Edificio Urban 1470 INTERNET No No False
# 8.019.560-5
# San Andres Del Valle RECORRIDO POR EL SECTOR Si Si False
# 8.080.873-9
# San Andres Del Valle RECORRIDO POR EL SECTOR No No True
# 8.095.083-7
# Edificio Mil610 INTERNET No No False
# 8.097.530-9
# Edificio Urban 1470 RECONTACTO No No False
# 8.104.482-1
# Edificio Urban 1470 INTERNET No No True
# 8.132.938-9
# Edificio Urban 1470 REFERIDOS No No False
# 8.177.382-3
# San Andres Del Valle INTERNET Si Si False
# 8.180.159-2
# Edificio Mil610 INTERNET No No False
# 8.180.159-2
# Edificio Mil610 INTERNET No No False
# 8.180.159-2
# Edificio Mil610 INTERNET No No False
# 8.180.159-2
# Edificio Mil610 INTERNET No No False
# 8.189.972-k
# San Andres Del Valle INTERNET No No False
# 8.193.470-3
# Edificio Mil610 RECONTACTO No No False
# 8.213.765-3
# Edificio Urban 1470 INTERNET No No True
# 8.220.685-k
# Edificio Urban 1470 INTERNET No No False
# 8.220.685-k
# Edificio Urban 1470 FINCO No No True
# 8.229.101-6
# Edificio Urban 1470 FINCO No No False
# 8.230.535-1
# San Andres Del Valle RECONTACTO No No True
# 8.230.535-1
# San Andres Del Valle RECONTACTO No No False
# 8.230.535-1
# San Andres Del Valle RECONTACTO No No False
# 8.230.535-1
# San Andres Del Valle RECONTACTO No No False
# 8.234.007-6
# San Andres Del Valle RECONTACTO Si Si False
# 8.234.007-6
# San Andres Del Valle RECONTACTO Si Si False
# 8.234.007-6
# San Andres Del Valle RECONTACTO Si Si False
# 8.239.956-9
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 8.239.956-9
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 8.239.956-9
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 8.273.219-5
# Edificio Urban 1470 INTERNET No No False
# 8.277.774-1
# Edificio Urban 1470 FINCO No No False
# 8.304.152-8
# San Andres Del Valle RECONTACTO No No True
# 8.304.152-8
# San Andres Del Valle RECONTACTO No No True
# 8.372.739-K
# Edificio Urban 1470 PRENSA No No False
# 8.372.739-K
# Edificio Urban 1470 RECONTACTO No No False
# 8.372.739-K
# Edificio Urban 1470 INTERNET No No False
# 8.372.739-K
# Edificio Urban 1470 INTERNET No No False
# 8.377.143-7
# Edificio Junge RECONTACTO No No False
# 8.377.143-7
# Edificio Junge RECONTACTO No No False
# 8.377.143-7
# Edificio Junge RECONTACTO No No False
# 8.393.429-8
# San Andres Del Valle INTERNET No No False
# 8.394.965-1
# Edificio Urban 1470 RECORRIDO POR EL SECTOR Si Si False
# 8.395.621-6
# Edificio Junge INTERNET Si Si False
# 8.395.621-6
# Edificio Junge INTERNET Si Si False
# 8.395.621-6
# Edificio Junge INTERNET Si Si False
# 8.395.621-6
# Edificio Junge INTERNET Si Si False
# 8.395.621-6
# Edificio Junge INTERNET Si Si False
# 8.395.621-6
# Edificio Junge INTERNET Si Si False
# 8.399.766-4
# San Andres Del Valle RECONTACTO Si Si False
# 8.399.766-4
# Edificio Urban 1470 RECONTACTO No No False
# 8.399.766-4
# Edificio Urban 1470 REVISTAS No No False
# 8.399.904-7
# Edificio Urban 1470 FINCO No No False
# 8.415.960-3
# San Andres Del Valle INTERNET No No False
# 8.415.960-3
# San Andres Del Valle INTERNET No No False
# 8.415.960-3
# San Andres Del Valle INTERNET No No False
# 8.422.682-3
# San Andres Del Valle RECONTACTO No No False
# 8.436.962-4
# Edificio Mil610 RECORRIDO POR EL SECTOR Si Si False
# 8.484.417-9
# San Andres Del Valle INTERNET Si Si False
# 8.484.417-9
# San Andres Del Valle INTERNET Si Si False
# 8.524.307-1
# Edificio Mil610 INTERNET No No False
# 8.544.600-2
# Edificio Urban 1470 RECONTACTO No No True
# 8.544.600-2
# Edificio Urban 1470 RECONTACTO No No True
# 8.544.600-2
# Edificio Urban 1470 RECONTACTO No No True
# 8.544.600-2
# Edificio Urban 1470 RECONTACTO No No True
# 8.544.600-2
# Edificio Urban 1470 RECONTACTO No No True
# 8.575.867-5
# Edificio Mil610 RECONTACTO No No False
# 8.575.867-5
# Edificio Mil610 RECONTACTO No No False
# 8.592.589-k
# Edificio Mil610 LETREROS No No False
# 8.592.589-k
# Edificio Mil610 LETREROS No No False
# 8.595.810-0
# Edificio Urban 1470 RECORRIDO POR EL SECTOR Si Si False
# 8.601.718-0
# Edificio Junge INTERNET Si Si False
# 8.601.718-0
# Edificio Junge INTERNET Si Si False
# 8.601.718-0
# Edificio Junge INTERNET Si Si False
# 8.608.303-5
# Edificio Junge RECONTACTO No No False
# 8.616.105-2
# Edificio Mil610 RECONTACTO No No False
# 8.616.105-2
# San Andres Del Valle RECONTACTO No No False
# 8.616.455-8
# San Andres Del Valle RECONTACTO No No False
# 8.628.737-4
# Edificio Urban 1470 FINCO No No False
# 8.677.162-4
# Edificio Urban 1470 FINCO No No False
# 8.684.144-4
# San Andres Del Valle INTERNET No No False
# 8.684.144-4
# San Andres Del Valle INTERNET No No False
# 8.684.144-4
# San Andres Del Valle INTERNET No No False
# 8.684.144-4
# San Andres Del Valle INTERNET No No False
# 8.695.462-1
# Edificio Urban 1470 INTERNET No No False
# 8.699.650-2
# San Andres Del Valle FINCO No No False
# 8.704.276-6
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 8.704.276-6
# San Andres Del Valle RECONTACTO No No True
# 8.704.276-6
# San Andres Del Valle RECONTACTO No No True
# 8.704.276-6
# San Andres Del Valle RECONTACTO No No True
# 8.704.276-6
# San Andres Del Valle RECONTACTO No No True
# 8.704.276-6
# San Andres Del Valle RECONTACTO No No True
# 8.704.276-6
# San Andres Del Valle RECONTACTO No No False
# 8.704.276-6
# San Andres Del Valle RECONTACTO No No True
# 8.704.276-6
# San Andres Del Valle RECONTACTO No No True
# 8.704.276-6
# San Andres Del Valle RECONTACTO No No False
# 8.704.276-6
# San Andres Del Valle RECONTACTO No No True
# 8.704.276-6
# San Andres Del Valle RECONTACTO No No True
# 8.704.276-6
# San Andres Del Valle RECONTACTO No No False
# 8.704.276-6
# San Andres Del Valle RECONTACTO No No False
# 8.731.596-7
# San Andres Del Valle RECORRIDO POR EL SECTOR Si Si False
# 8.731.596-7
# San Andres Del Valle RECORRIDO POR EL SECTOR Si Si False
# 8.743.950-K
# Edificio Mil610 RECONTACTO No No True
# 8.743.950-K
# Edificio Mil610 RECONTACTO No No True
# 8.753.525-8
# San Andres Del Valle FINCO No No False
# 8.775.853-2
# San Andres Del Valle INTERNET No No False
# 8.775.853-2
# San Andres Del Valle INTERNET Si Si False
# 8.789.354-5
# Edificio Urban 1470 INTERNET No No False
# 8.804.171-2
# Edificio Junge REFERIDOS No No False
# 8.804.171-2
# Edificio Junge REFERIDOS No No False
# 8.809.159-0
# Edificio Urban 1470 FINCO No No False
# 8.813.297-1
# San Andres Del Valle RECONTACTO No No False
# 8.824.135-5
# Edificio Urban 1470 FINCO No No False
# 8.824.135-5
# Edificio Urban 1470 FINCO No No False
# 8.833.228-8
# Edificio Urban 1470 FINCO No No False
# 8.833.330-6
# San Andres Del Valle RECONTACTO No No False
# 8.846.770-1
# San Andres Del Valle RECORRIDO POR EL SECTOR No No True
# 8.849.919-0
# Edificio Urban 1470 FINCO No No False
# 8.869.707-3
# Edificio Mil610 RECONTACTO No No False
# 8.875.279-1
# Edificio Junge INTERNET No No False
# 8.875.279-1
# Edificio Junge INTERNET No No False
# 8.886.116-7
# Altos del Valle INTERNET No No False
# 8.886.116-7
# Altos del Valle RECONTACTO No No False
# 8.886.116-7
# Altos del Valle RECONTACTO No No False
# 8.895.881-0
# San Andres Del Valle INTERNET Si Si False
# 8.895.881-0
# San Andres Del Valle INTERNET Si Si False
# 8.906.439-2
# Edificio Junge RECONTACTO No No True
# 8.935.707-1
# San Andres Del Valle RECORRIDO POR EL SECTOR Si Si False
# 8.964.875-0
# San Andres Del Valle RECONTACTO Si Si False
# 8.978.404-2
# San Andres Del Valle RECONTACTO No No True
# 8.981.846-k
# Edificio Mil610 RECORRIDO POR EL SECTOR No No False
# 8.995.563-7
# Edificio Urban 1470 FINCO No No False
# 9.029.755-4
# San Andres Del Valle REFERIDOS No No False
# 9.053.649-4
# Edificio Mil610 RECORRIDO POR EL SECTOR No No True
# 9.054.033-5
# Edificio Urban 1470 RECONTACTO No No False
# 9.070.646-2
# San Andres Del Valle RECONTACTO No No False
# 9.112.947-7
# San Andres Del Valle LETREROS No No False
# 9.164.055-4
# Edificio Urban 1470 INTERNET Si Si False
# 9.173.017-0
# Edificio Urban 1470 RECORRIDO POR EL SECTOR Si Si False
# 9.174.340-k
# Edificio Urban 1470 INTERNET Si Si False
# 9.174.340-k
# Edificio Urban 1470 INTERNET Si Si False
# 9.184.085-5
# Edificio Junge INTERNET No No False
# 9.184.085-5
# Edificio Junge INTERNET Si Si False
# 9.184.085-5
# Edificio Junge INTERNET Si Si False
# 9.184.085-5
# Edificio Junge INTERNET Si Si False
# 9.184.085-5
# Edificio Mil610 RECONTACTO No No False
# 9.187.396-6
# Edificio Urban 1470 INTERNET No No False
# 9.198.433-4
# San Andres Del Valle RECONTACTO No No True
# 9.224.096-7
# Edificio Junge INTERNET No No False
# 9.244.277-2
# Edificio Mil610 LETREROS No No False
# 9.246.500-4
# Edificio Mil610 FINCO No No False
# 9.262.028-k
# San Andres Del Valle RECONTACTO No No False
# 9.262.028-k
# San Andres Del Valle RECONTACTO No No False
# 9.262.028-k
# San Andres Del Valle RECONTACTO No No True
# 9.276.763-9
# San Andres Del Valle RECONTACTO No No True
# 9.276.763-9
# San Andres Del Valle RECONTACTO No No False
# 9.280.438-0
# San Andres Del Valle RECONTACTO Si Si False
# 9.280.438-0
# San Andres Del Valle RECONTACTO Si Si True
# 9.306.801-7
# Edificio Urban 1470 INTERNET No No False
# 9.312.371-9
# San Andres Del Valle INTERNET No No False
# 9.313.807-4
# San Andres Del Valle FINCO No No False
# 9.317.421-6
# Edificio Urban 1470 INTERNET Si Si False
# 9.362.550-1
# Edificio Urban 1470 FINCO No No True
# 9.362.550-1
# Edificio Urban 1470 FINCO No No False
# 9.362.550-1
# Edificio Urban 1470 FINCO No No False
# 9.362.550-1
# Edificio Urban 1470 FINCO No No True
# 9.362.550-1
# Edificio Urban 1470 FINCO No No True
# 9.362.550-1
# Edificio Urban 1470 FINCO No No True
# 9.362.550-1
# Edificio Urban 1470 FINCO No No True
# 9.392.253-0
# Edificio Urban 1470 RECONTACTO No No False
# 9.392.253-0
# Edificio Urban 1470 RECONTACTO No No False
# 9.392.253-0
# Edificio Urban 1470 RECONTACTO No No False
# 9.392.253-0
# Edificio Urban 1470 RECONTACTO Si Si False
# 9.392.253-0
# Edificio Urban 1470 INTERNET Si Si True
# 9.422.000-9
# Edificio Mil610 RECONTACTO No No False
# 9.424.784-5
# San Andres Del Valle REFERIDOS No No False
# 9.428.450-3
# San Andres Del Valle FINCO No No False
# 9.437.772-2
# Edificio Mil610 RECONTACTO No No False
# 9.441.338-9
# San Andres Del Valle INTERNET No No False
# 9.441.338-9
# San Andres Del Valle INTERNET Si Si False
# 9.454.977-9
# Edificio Urban 1470 RECONTACTO No No False
# 9.461.907-6
# San Andres Del Valle INTERNET Si Si False
# 9.461.907-6
# San Andres Del Valle INTERNET Si Si False
# 9.461.907-6
# San Andres Del Valle INTERNET Si Si False
# 9.461.907-6
# San Andres Del Valle INTERNET Si Si False
# 9.479.401-3
# Edificio Urban 1470 INTERNET No No False
# 9.479.401-3
# Edificio Urban 1470 INTERNET No No False
# 9.479.401-3
# Edificio Urban 1470 INTERNET No No False
# 9.479.401-3
# Edificio Urban 1470 INTERNET No No False
# 9.479.401-3
# Edificio Urban 1470 INTERNET No No False
# 9.479.401-3
# Edificio Urban 1470 INTERNET No No False
# 9.479.401-3
# Edificio Urban 1470 INTERNET No No False
# 9.479.401-3
# Edificio Urban 1470 INTERNET No No False
# 9.503.888-3
# San Andres Del Valle RECONTACTO No No False
# 9.503.888-3
# San Andres Del Valle RECONTACTO No No False
# 9.503.888-3
# San Andres Del Valle RECONTACTO No No False
# 9.512.862-9
# Edificio Mil610 RECONTACTO No No False
# 9.535.870-5
# Edificio Mil610 REFERIDOS No No False
# 9.535.870-5
# Edificio Mil610 REFERIDOS No No False
# 9.560.501-k
# Edificio Junge REFERIDOS Si Si False
# 9.560.501-k
# Edificio Junge RECONTACTO No No False
# 9.560.501-k
# Edificio Junge RECONTACTO No No False
# 9.560.501-k
# Edificio Junge RECONTACTO No No False
# 9.560.501-k
# Edificio Junge RECONTACTO No No False
# 9.560.501-k
# Edificio Junge INTERNET No No False
# 9.560.501-k
# Edificio Junge INTERNET No No False
# 9.560.501-k
# Edificio Junge INTERNET No No False
# 9.560.501-k
# Edificio Junge INTERNET No No False
# 9.560.501-k
# Edificio Junge RECONTACTO No No True
# 9.560.501-k
# Edificio Junge RECONTACTO No No True
# 9.560.501-k
# Edificio Junge RECONTACTO No No False
# 9.560.501-k
# Edificio Junge RECONTACTO No No True
# 9.571.973-2
# San Andres Del Valle RECONTACTO No No False
# 9.593.988-0
# Edificio Urban 1470 RECONTACTO Si Si False
# 9.593.988-0
# Edificio Urban 1470 INTERNET Si Si False
# 9.593.988-0
# Edificio Urban 1470 INTERNET Si Si False
# 9.593.988-0
# Edificio Urban 1470 INTERNET No No False
# 9.634.657-3
# San Andres Del Valle INTERNET No No False
# 9.640.073-k
# Edificio Urban 1470 INTERNET No No False
# 9.640.073-k
# Edificio Urban 1470 INTERNET No No False
# 9.652.524-9
# San Andres Del Valle RECONTACTO No No False
# 9.656.026-5
# San Andres Del Valle RECORRIDO POR EL SECTOR No No False
# 9.656.026-5
# San Andres Del Valle RECONTACTO No No False
# 9.656.026-5
# San Andres Del Valle RECONTACTO No No False
# 9.693.039-9
# Edificio Junge RECONTACTO No No False
# 9.723.863-4
# San Andres Del Valle RECONTACTO No No False
# 9.723.863-4
# San Andres Del Valle REFERIDOS No No False
# 9.723.863-4
# San Andres Del Valle REFERIDOS No No False
# 9.733.821-3
# San Andres Del Valle FINCO No No False
# 9.747.337-4
# San Andres Del Valle RECORRIDO POR EL SECTOR No No True
# 9.747.510-5
# Edificio Urban 1470 FINCO No No False
# 9.751.590-5
# Edificio Mil610 RECONTACTO No No False
# 9.751.809-2
# San Andres Del Valle RECONTACTO Si Si False
# 9.754.370-4
# San Andres Del Valle LETREROS No No True
# 9.760.075-9
# San Andres Del Valle RECONTACTO Si Si False
# 9.775.334-2
# San Andres Del Valle RECONTACTO Si Si True
# 9.816.876-1
# Edificio Urban 1470 INTERNET No No False
# 9.822.596-K
# Edificio Urban 1470 INTERNET No No False
# 9.822.596-K
# Edificio Urban 1470 INTERNET No No False
# 9.838.698-k
# San Andres Del Valle RECONTACTO No No True
# 9.842.875-5
# San Andres Del Valle RECONTACTO No No False
# 9.842.875-5
# San Andres Del Valle RECONTACTO No No False
# 9.842.875-5
# San Andres Del Valle RECONTACTO No No False
# 9.845.601-5
# Edificio Urban 1470 REFERIDOS No No True
# 9.845.601-5
# Edificio Urban 1470 REFERIDOS No No True
# 9.845.601-5
# Edificio Urban 1470 REFERIDOS No No True
# 9.845.678-3
# Edificio Junge RECONTACTO No No True
# 9.845.678-3
# Edificio Junge RECONTACTO No No True
# 9.851.808-8
# Edificio Urban 1470 FINCO No No False
# 9.865.167-5
# Edificio Junge INTERNET Si Si False
# 9.865.167-5
# Edificio Junge INTERNET Si Si False
# 9.879.501-4
# Altos del Valle RECONTACTO No No True
# 9.879.501-4
# Altos del Valle RECONTACTO No No True
# 9.879.501-4
# Altos del Valle RECONTACTO No No True
# 9.879.501-4
# Altos del Valle RECONTACTO No No True
# 9.879.501-4
# Altos del Valle RECONTACTO No No True
# 9.884.654-9
# San Andres Del Valle INTERNET Si Si False
# 9.884.654-9
# San Andres Del Valle INTERNET Si Si False
# 9.884.654-9
# San Andres Del Valle INTERNET Si Si False
# 9.887.258-2
# Edificio Urban 1470 RECORRIDO POR EL SECTOR No No True
# 9.904.294-k
# San Andres Del Valle RECONTACTO No No False
# 9.904.294-k
# San Andres Del Valle RECONTACTO No No False
# 9.904.294-k
# San Andres Del Valle RECONTACTO No No False
# 9.904.294-k
# San Andres Del Valle RECONTACTO No No False
# 9.904.294-k
# San Andres Del Valle RECONTACTO No No False
# 9.909.417-6
# Edificio Urban 1470 RECONTACTO No No False
# 9.909.417-6
# Edificio Urban 1470 RECONTACTO No No False
# 9.909.417-6
# Edificio Urban 1470 INTERNET No No False
# 9.909.417-6
# Edificio Urban 1470 INTERNET No No False
# 9.909.417-6
# Edificio Urban 1470 INTERNET No No False
# 9.909.417-6
# Edificio Urban 1470 INTERNET Si Si False
# 9.909.417-6
# Edificio Urban 1470 INTERNET Si Si False
# 9.912.415-6
# Edificio Urban 1470 RECONTACTO No No False
# 9.913.367-8
# Edificio Junge INTERNET Si Si False
# 9.913.367-8
# Edificio Junge INTERNET Si Si False
# 9.913.367-8
# Edificio Junge INTERNET Si Si False
# 9.913.367-8
# Edificio Junge INTERNET Si Si False
# 9.913.367-8
# Edificio Junge INTERNET Si Si False
# 9.938.835-8
# Edificio Mil610 RECONTACTO No No False
# 9.938.835-8
# Edificio Mil610 RECONTACTO No No False
# 9.938.835-8
# Edificio Mil610 RECONTACTO No No False
# 9.938.835-8
# Edificio Mil610 RECONTACTO No No False
# 9.943.170-9
# San Andres Del Valle FINCO No No False
# 9.982.194-9
# San Andres Del Valle INTERNET No No False
# 9.982.194-9
# San Andres Del Valle RECONTACTO No No False
# 9.982.194-9
# San Andres Del Valle RECONTACTO No No True
# 9.982.194-9
# San Andres Del Valle RECONTACTO No No True
# 9.982.194-9
# San Andres Del Valle RECONTACTO No No False
# 9.982.194-9
# San Andres Del Valle RECONTACTO No No False
# 9.983.814-0
# San Andres Del Valle INTERNET No No False
# 91.860.000-0
# Edificio Junge RECONTACTO No No True
# 91.860.000-0
# Edificio Junge RECONTACTO No No True
# 3030

# %%
cot_mod.iloc[[3601, 14926]]
# Out:
#        Unnamed: 0      ID         Fecha Cotizacion     Medio    Tipo de Medio  \
# 3601          484   34368  2014-04-13 12:16:02.000     FINCO  Base Finco 2014
# 14926        1251  115101  2017-09-14 11:32:10.000  INTERNET        Web Aitue
#
#                    Proyecto                         Etapa Presencial Remoto  \
# 3601   San Andres Del Valle  SADV - ET01 Condominio Azapa        NaN    NaN
# 14926   Edificio Urban 1470          Urban 1470 - Etapa 1         No     Si
#
#              Jefe Comercial    ...    is_direccion  is_telefono  is_actividad  \
# 3601       Maribel Bastidas    ...           False        False          True
# 14926  Ximena Herrera Leiva    ...           False        False          True
#
#        is_estado_civil is_fnac is_celular is_profesion Edad Min Edad Max  \
# 3601             False    True       True         True        0        0
# 14926            False    True       True         True        0        0
#
#       is_nrofam
# 3601      False
# 14926     False
#
# [2 rows x 61 columns]

# %%
True in [False, True]
# Out:
# True

# %% [markdown]
# ### 3.1.10.Tiempo entre Cotizaciones
# Esta variable indica el numero de veces que el cliente ha hecho cotizaciones

# %%
# Construir 'promedio_de_tiempo' entre cotizacones donde participa el mismo rut

# %%
cot_mod.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Fecha Cotizacion', 'Medio', 'Tipo de Medio',
#        'Proyecto', 'Etapa', 'Presencial', 'Remoto', 'Jefe Comercial',
#        'Ejecutivo Comercial', 'Total Productos', 'Descuentos',
#        'Valor Final Venta', 'RUT', 'Celular', 'Direccion', 'Sexo',
#        'Estado Civil', 'Rango Edad', 'Fecha Nacimiento', 'Tipo Cliente',
#        'Razon Social', 'Giro', 'Nacionalidad', 'N° Grupo Familiar',
#        'Actividad', 'Cargo', 'Situacion Laboral', 'Empleador',
#        'Antiguedad Laboral', 'Negocio', 'Clean Rut', 'Valid Rut', 'Format Rut',
#        'profesion_agg', 'edad', 'recibio_descuento', '#vivienda', '#bodega',
#        '#estacionamiento', '#estudio', '#lan', 'region', 'provincia', 'comuna',
#        'is_nombre', 'is_apellido1', 'is_apellido2', 'is_nombrecompleto',
#        'is_correo', 'is_direccion', 'is_telefono', 'is_actividad',
#        'is_estado_civil', 'is_fnac', 'is_celular', 'is_profesion', 'Edad Min',
#        'Edad Max', 'is_nrofam'],
#       dtype='object')

# %%
len(cot_mod['Clean Rut'].unique())
# Out:
# 6184

# %% [markdown]
# # 4.Integrate Data

# %%
# Construir '#cotizaciones' a partir del nro de filas donde participa el mismo rut
cot_ruts = pd.DataFrame()

nro_cot_depto, nro_cot_esta, nro_cot_estu, nro_cot_bod  = [], [], [], []

mean_cot_depto, mean_cot_esta, mean_cot_estu, mean_cot_bod = [], [], [], []

ruts, ruts_nro_cot, rut_reg, rut_prov , rut_com = [], [], [] , [], []

is_nombre, is_apellido1, is_appelido2, is_nombrecompleto, is_direccion = [], [], [], [], [] 
is_telefono, is_celular, is_fnac, is_nrofam, is_profesion = [], [], [], [], []
is_recontacto = []

primer_medio = []
rut = []

max_rango_edad, profesion = [], []

nro_proyectos = []

negocio = []

tipo_cliente = []

sexo = []


iterator = 0
for group, frame in  cot_mod.groupby('Format Rut'):
    iterator += 1
    is_nombre.append(frame['is_nombre'].tolist()[0])
    is_apellido1.append(frame['is_apellido1'].tolist()[0])
    is_appelido2.append(frame['is_apellido2'].tolist()[0])
    is_nombrecompleto.append(frame['is_nombrecompleto'].tolist()[0])
    is_direccion.append(frame['is_direccion'].tolist()[0])
    is_telefono.append(frame['is_telefono'].tolist()[0])
    is_celular.append(frame['is_celular'].tolist()[0])
    is_fnac.append(frame['is_fnac'].tolist()[0])
    is_profesion.append(frame['is_profesion'].tolist()[0])
    is_nrofam.append(frame['is_nrofam'].tolist()[0])
    
    if frame['Medio'].tolist()[-1] == 'RECONTACTO':
        is_recontacto.append(True)
    else:
        is_recontacto.append(False)
    
    primer_medio.append(frame['Medio'].tolist()[0])
    
    profesion.append(frame['profesion_agg'].tolist()[0])
    rut.append(group)
    sexo.append(frame['Sexo'].tolist()[0])
    
    tipo_cliente.append(frame['Tipo Cliente'].tolist()[0])
    
    max_rango_edad.append(frame['Edad Max'].tolist()[0])

    nro_proyectos.append(len(frame['Proyecto'].unique()))
    
    arr = frame['Negocio'].tolist()
    if True in arr:   
        negocio.append(True)
    else:
        negocio.append(False)
    
    ruts.append(group)
    rut_reg.append(frame['region'].tolist()[0])
    rut_prov.append(frame['provincia'].tolist()[0])
    rut_com.append(frame['comuna'].tolist()[0])
    
    nro_cot_depto.append(frame['#vivienda'].sum())
    nro_cot_bod.append(frame['#bodega'].sum())
    nro_cot_esta.append(frame['#estacionamiento'].sum())
    nro_cot_estu.append(frame['#estudio'].sum())
    
    mean_cot_depto.append(frame['#vivienda'].mean())
    mean_cot_bod.append(frame['#bodega'].mean())
    mean_cot_esta.append(frame['#estacionamiento'].mean())
    mean_cot_estu.append(frame['#estudio'].mean())
    ruts_nro_cot.append(frame['ID'].count())
    
print(iterator)
# Out:
# 6184

# %% [markdown]
# ## NEW DATASET: Personas Dataset

# %%
list_cols = [ruts,rut_reg,rut_prov,rut_com,nro_proyectos,nro_cot_bod, nro_cot_depto, nro_cot_esta, nro_cot_estu, mean_cot_bod,
             mean_cot_depto,mean_cot_esta,mean_cot_estu, negocio,is_nombre,
             is_apellido1,is_appelido2,is_nombrecompleto,is_direccion,is_telefono,
             is_celular,is_fnac,max_rango_edad,tipo_cliente,sexo,
             is_nrofam, is_profesion,rut, profesion, is_recontacto, primer_medio]

list_labels = ['rut','loc_region','loc_provincia','loc_comuna','nro_proyectos','nro_cot_bod', 'nro_cot_depto', 
               'nro_cot_esta', 'nro_cot_estu', 'mean_cot_bod',
               'mean_cot_depto','mean_cot_esta','mean_cot_estu','negocio',
               'is_nombre','is_apellido1','is_appelido2','is_nombrecompleto','is_direccion','is_telefono',
               'is_celular','is_fnac','max_rango_edad','tipo_cliente','sexo','is_nrofam','is_profesion','rut','profesion',
               'is_recontacto', 'medio_inicial']

zipped = list(zip(list_labels,list_cols))
data = dict(zipped)
personas = pd.DataFrame(data)
print(personas.shape)
personas.head()
# Out:
# (6184, 30)
#    is_apellido1  is_appelido2  is_celular  is_direccion  is_fnac  is_nombre  \
# 0          True         False        True         False     True       True
# 1          True         False        True         False    False       True
# 2          True         False        True         False    False       True
# 3          True          True        True          True    False       True
# 4          True          True        True         False    False       True
#
#    is_nombrecompleto  is_nrofam  is_profesion  is_recontacto     ...       \
# 0               True      False          True          False     ...
# 1               True      False         False          False     ...
# 2               True      False         False          False     ...
# 3               True       True          True           True     ...
# 4               True      False         False          False     ...
#
#    negocio nro_cot_bod nro_cot_depto nro_cot_esta  nro_cot_estu  \
# 0    False           1             2            1             0
# 1    False           0             1            1             0
# 2    False           2             2            2             2
# 3     True           2             2            2             0
# 4    False           2             2            2             0
#
#    nro_proyectos  profesion            rut       sexo tipo_cliente
# 0              2    Abogado  000.000.000-0   Femenino      Natural
# 1              1        NaN    1.462.558-5  Masculino      Natural
# 2              1        NaN   10.000.513-1  Masculino      Natural
# 3              1     Médico   10.000.522-0  Masculino      Natural
# 4              1        NaN   10.005.853-7        NaN      Natural
#
# [5 rows x 30 columns]

# %%
print(len(personas['rut'].unique()))
# Out:
# 6184

# %%
len(personas[personas.negocio == True])
# Out:
# 1101

# %%
personas.columns
# Out:
# Index(['is_apellido1', 'is_appelido2', 'is_celular', 'is_direccion', 'is_fnac',
#        'is_nombre', 'is_nombrecompleto', 'is_nrofam', 'is_profesion',
#        'is_recontacto', 'is_telefono', 'loc_comuna', 'loc_provincia',
#        'loc_region', 'max_rango_edad', 'mean_cot_bod', 'mean_cot_depto',
#        'mean_cot_esta', 'mean_cot_estu', 'medio_inicial', 'negocio',
#        'nro_cot_bod', 'nro_cot_depto', 'nro_cot_esta', 'nro_cot_estu',
#        'nro_proyectos', 'profesion', 'rut', 'sexo', 'tipo_cliente'],
#       dtype='object')

# %% [markdown]
# ## Incorporate Proyectos RUT Data

# %%
# rut_proyectos es un dataset que describe el comportamiento de las personas en sus cotizaciones en los proyectos
personas = pd.merge(personas, rut_proyectos, how = 'inner', left_on='rut', right_on='index')
personas = personas.drop(['index'],axis=1)

# %%
print(len(personas['rut'].unique()))
# Out:
# 6184

# %%
personas.columns
# Out:
# Index(['is_apellido1', 'is_appelido2', 'is_celular', 'is_direccion', 'is_fnac',
#        'is_nombre', 'is_nombrecompleto', 'is_nrofam', 'is_profesion',
#        'is_recontacto', 'is_telefono', 'loc_comuna', 'loc_provincia',
#        'loc_region', 'max_rango_edad', 'mean_cot_bod', 'mean_cot_depto',
#        'mean_cot_esta', 'mean_cot_estu', 'medio_inicial', 'negocio',
#        'nro_cot_bod', 'nro_cot_depto', 'nro_cot_esta', 'nro_cot_estu',
#        'nro_proyectos', 'profesion', 'rut', 'sexo', 'tipo_cliente',
#        'Altos del Valle', 'Edificio Urban 1470', 'San Andres Del Valle',
#        'Edificio Mil610', 'Edificio Junge'],
#       dtype='object')

# %%
# personas.info()

# %%
# ruts_scrapped.info()

# %% [markdown]
# ## Scrapped RUT Data

# %%
ruts_scrapped = pd.read_csv('..\\..\\Datos\\working\\ruts_scrapped_mod.csv',encoding = "ISO-8859-1")
ruts_scrapped.drop('Unnamed: 0',axis=1,inplace=True)
ruts_scrapped.head()
# Out:
#                                    Name           RUT Gender  \
# 0    SCHNEIDER BARRERA RICARDO ERNESTO   10.023.348-7   VAR
# 1      MORALES ESPINOZA CLAUDIO ANDRES   10.020.262-k   VAR
# 2   SALGADO VALENZUELA ALFREDO EDUARDO   10.019.023-0   VAR
# 3          MEIER PUCHEU SERGIO RODRIGO   10.016.093-5   VAR
# 4      TEMPIO ETCHEVERRY MAURO RODRIGO   10.015.654-7   VAR
#
#                              Adress                 Comuna
# 0                J  CISTERNAS 1612              LA SERENA
# 1   ALEJANDRO SEXTO 2787LZO ARENAS      CONCEPCION CENTRO
# 2         ANDALIEN 395 CHILLANCITO      CONCEPCION CENTRO
# 3            RALUN S/NLONCO PARQUE            CHIGUAYANTE
# 4                  LOS AVELLANOS 8    SAN PEDRO DE LA PAZ

# %%
print(len(personas['rut'].unique()))
print(personas.shape)
# Out:
# 6184
# (6184, 35)

# %% [markdown]
# ## Incorporate Scrapped RUT Data

# %%
personas.columns
# Out:
# Index(['is_apellido1', 'is_appelido2', 'is_celular', 'is_direccion', 'is_fnac',
#        'is_nombre', 'is_nombrecompleto', 'is_nrofam', 'is_profesion',
#        'is_recontacto', 'is_telefono', 'loc_comuna', 'loc_provincia',
#        'loc_region', 'max_rango_edad', 'mean_cot_bod', 'mean_cot_depto',
#        'mean_cot_esta', 'mean_cot_estu', 'medio_inicial', 'negocio',
#        'nro_cot_bod', 'nro_cot_depto', 'nro_cot_esta', 'nro_cot_estu',
#        'nro_proyectos', 'profesion', 'rut', 'sexo', 'tipo_cliente',
#        'Altos del Valle', 'Edificio Urban 1470', 'San Andres Del Valle',
#        'Edificio Mil610', 'Edificio Junge', 'Name', 'RUT', 'Gender', 'Adress',
#        'Comuna'],
#       dtype='object')

# %%
ruts_scrapped.columns
# Out:
# Index(['Name', 'RUT', 'Gender', 'Adress', 'Comuna'], dtype='object')

# %%
personas = pd.merge(personas, ruts_scrapped, how='outer', left_on='rut', right_on='RUT')

# %%
personas = personas.drop(['Name','Adress','Comuna','RUT'],axis=1)

# %%
# personas.info()

# %%
sb.factorplot(x='sexo', kind='count', data=personas);

# %%
def clean_sex(x,y):
#     print(x)
    x = str(x)
    x = x.replace(' ','')
    if x == 'VAR':
        return 'Masculino'
    elif x == 'MUJ':
        return 'Femenino'
    else:
        return y

personas['sexo'] = [clean_sex(x,y) for x,y in zip(personas['Gender'].values, personas['sexo'].values)]

# %%
personas.sexo = personas.sexo.fillna('Sin Información')
sb.factorplot(x='sexo', kind='count', data=personas);

# %%
personas = personas.drop(['Gender'],axis=1)

# %%
print(personas.tipo_cliente.isnull().sum())
personas.tipo_cliente = personas.tipo_cliente.fillna('Natural')
# Out:
# 87

# %% [markdown]
# # 5.Format Data

# %%
print(len(personas['rut'].unique()))
# Out:
# 6185

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6271 entries, 0 to 6270
# Data columns (total 35 columns):
# is_apellido1            6184 non-null object
# is_appelido2            6184 non-null object
# is_celular              6184 non-null object
# is_direccion            6184 non-null object
# is_fnac                 6184 non-null object
# is_nombre               6184 non-null object
# is_nombrecompleto       6184 non-null object
# is_nrofam               6184 non-null object
# is_profesion            6184 non-null object
# is_recontacto           6184 non-null object
# is_telefono             6184 non-null object
# loc_comuna              6184 non-null object
# loc_provincia           6184 non-null object
# loc_region              6184 non-null object
# max_rango_edad          6184 non-null float64
# mean_cot_bod            6184 non-null float64
# mean_cot_depto          6184 non-null float64
# mean_cot_esta           6184 non-null float64
# mean_cot_estu           6184 non-null float64
# medio_inicial           6184 non-null object
# negocio                 6184 non-null object
# nro_cot_bod             6184 non-null float64
# nro_cot_depto           6184 non-null float64
# nro_cot_esta            6184 non-null float64
# nro_cot_estu            6184 non-null float64
# nro_proyectos           6184 non-null float64
# profesion               2251 non-null object
# rut                     6184 non-null object
# sexo                    6271 non-null object
# tipo_cliente            6271 non-null object
# Altos del Valle         6184 non-null float64
# Edificio Urban 1470     6184 non-null float64
# San Andres Del Valle    6184 non-null float64
# Edificio Mil610         6184 non-null float64
# Edificio Junge          6184 non-null float64
# dtypes: float64(15), object(20)
# memory usage: 1.9+ MB

# %%
personas['loc_comuna'] = personas['loc_comuna'].astype('category')
personas['loc_provincia'] = personas['loc_provincia'].astype('category')
personas['loc_region'] = personas['loc_region'].astype('category')
personas['tipo_cliente'] = personas['tipo_cliente'].astype('category')
personas['sexo'] = personas['sexo'].astype('category')
personas.profesion.fillna('sin informacion', inplace=True)
personas['profesion'] = personas['profesion'].astype('category')
personas['medio_inicial'] = personas['medio_inicial'].astype('category')

# personas = personas.dropna()

# %%
print(len(personas['rut'].unique()))
print(personas.shape)
# Out:
# 6185
# (6271, 35)

# %%
personas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6271 entries, 0 to 6270
# Data columns (total 35 columns):
# is_apellido1            6184 non-null object
# is_appelido2            6184 non-null object
# is_celular              6184 non-null object
# is_direccion            6184 non-null object
# is_fnac                 6184 non-null object
# is_nombre               6184 non-null object
# is_nombrecompleto       6184 non-null object
# is_nrofam               6184 non-null object
# is_profesion            6184 non-null object
# is_recontacto           6184 non-null object
# is_telefono             6184 non-null object
# loc_comuna              6184 non-null category
# loc_provincia           6184 non-null category
# loc_region              6184 non-null category
# max_rango_edad          6184 non-null float64
# mean_cot_bod            6184 non-null float64
# mean_cot_depto          6184 non-null float64
# mean_cot_esta           6184 non-null float64
# mean_cot_estu           6184 non-null float64
# medio_inicial           6184 non-null category
# negocio                 6184 non-null object
# nro_cot_bod             6184 non-null float64
# nro_cot_depto           6184 non-null float64
# nro_cot_esta            6184 non-null float64
# nro_cot_estu            6184 non-null float64
# nro_proyectos           6184 non-null float64
# profesion               6271 non-null category
# rut                     6184 non-null object
# sexo                    6271 non-null category
# tipo_cliente            6271 non-null category
# Altos del Valle         6184 non-null float64
# Edificio Urban 1470     6184 non-null float64
# San Andres Del Valle    6184 non-null float64
# Edificio Mil610         6184 non-null float64
# Edificio Junge          6184 non-null float64
# dtypes: category(7), float64(15), object(13)
# memory usage: 1.6+ MB

# %%
# personas.to_csv('..\\..\\Datos\\experiments\\personas_cotizacion6.csv')
# personas.to_excel('..\\..\\Datos\\experiments\\personas_cotizacion6.xlsx')

# %%
# personas.info()
# g = sb.factorplot(x='sexo', col='proyecto', kind='count', data=personas);
