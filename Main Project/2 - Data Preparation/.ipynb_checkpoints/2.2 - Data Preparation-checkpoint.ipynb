# %%
import pandas as pd
import seaborn as sb

# %% [markdown]
# # 1 Select Data

# %%
cot_mod = pd.read_csv("..\\..\\Datos\\working\\cotizaciones_to_personas.csv",encoding = "ISO-8859-1")
cot_all = pd.read_excel("..\\..\\Datos\\working\\cotizaciones_all.xlsx")
neg_all = pd.read_excel("..\\..\\Datos\\working\\negocios_all.xlsx")
# Out:
# C:\Users\joaquin\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## 3.1 Nuevos Atributos

# %% [markdown]
# ### 3.1.1 Edad
# Variable construida a partir de la fecha de nacimiento

# %%
# Construir variable 'Edad' a partir de fecha de Nacimiento
import datetime
now = datetime.datetime.now().year

fechas_nacimiento = pd.to_datetime(cot_all['Fecha Nacimiento']).apply(lambda x: x.date()).tolist()

def anio_nac(x):
    try:
        year = int(x.year)
        dif = now - year
        if dif >= 18:
            return dif
        else:
            return 0
    except (ValueError,AttributeError):
        return 0
        
    return r

edad = [anio_nac(x) for x in fechas_nacimiento]
cot_mod['edad'] = edad

# %%
# cot_mod = cot_mod.drop(['Fecha Nacimiento'], axis=1)

# %% [markdown]
# ### 3.1.2 Descuento
# Variable que indica si el cliente recibio descuento

# %%
# Construir 'descuento': binario : [True, False]
recibio_descuento = cot_all['Descuentos'].tolist()

def is_desc(x):
    try:
        desc = int(x)
        if desc > 0:
            return True
        else:
            return False
    except ValueError:
        return False

descuento = [is_desc(x) for x in recibio_descuento]
cot_mod['recibio_descuento'] = descuento
# descuento

# %% [markdown]
# ### 3.1.3.Cantidad de Productos

# %%
# Construir 'productos': categorico : ['depto','casa','estacionamiento','bodega','Estudio']
productos = cot_all['Productos'].tolist()
depto = []; estacionamiento=[]; bodega = []; estudio = [];nan = 0
def get_products(x,word,numeric=False):
    w=0
    try:
        p =str(x)
        arr_p = x.split(',')
        for e in arr_p:
            if word in e:
                w+=1
#                 print(word + " :",e)
                break
            elif numeric and ('B' not in e or 'Est' not in e):
                try:
                    int(e)
#                     print(word + " :",e)
                    w+=1
                except ValueError:
                    pass
        return w
    except (ValueError,AttributeError):
        try:
            int(x)
            if numeric:
                return 1
            else:
                return 0
        except ValueError:
            return 0

cot_mod['#vivienda'] = [get_products(x,'T',numeric=True) for x in productos]
cot_mod['#bodega'] = [get_products(x,'Bod') for x in productos]
cot_mod['#estacionamiento'] = [get_products(x,'Est') for x in productos]
cot_mod['#estudio'] = [get_products(x,'Estudio') for x in productos]
cot_mod['#lan'] = [get_products(x,'lan') for x in productos]

# %%
print(cot_mod[['Productos','#vivienda','#bodega','#estacionamiento','#estudio','#lan']].head())
print(cot_mod[['Productos','#vivienda','#bodega','#estacionamiento','#estudio','#lan']].tail())
# Out:
#               Productos  #vivienda  #bodega  #estacionamiento  #estudio  #lan
# 0         TB-104,Est-65          1        0                 1         0     0
# 1  TA-302,Est-41,Bod-02          1        1                 1         0     0
# 2         TA-303,Est-01          1        0                 1         0     0
# 3  TA-302,Est-41,Bod-06          1        1                 1         0     0
# 4         TA-604,Est-01          1        0                 1         0     0
#          Productos  #vivienda  #bodega  #estacionamiento  #estudio  #lan
# 16587  703,Est-003          1        0                 1         0     0
# 16588          912          1        0                 0         0     0
# 16589  Est-002,703          1        0                 1         0     0
# 16590  912,Est-002          1        0                 1         0     0
# 16591          912          1        0                 0         0     0

# %%
cot_mod = cot_mod.drop(['Productos'], axis=1)

# %% [markdown]
# ### 3.1.4 Latitud y Longitud

# %%
from geopy.geocoders import Nominatim

def get_latlong(direccion):
    geolocator = Nominatim()
    direccion = "TUCAPEL 937 , CONCEPCION CENTRO"
    location = geolocator.geocode(direccion)
#     print(location.address)
    # Flatiron Building, 175, 5th Avenue, Flatiron, New York, NYC, New York, ...
    print((location.latitude, location.longitude))
    # (40.7410861, -73.9896297241625)
#     print(location.raw)

# get_latlong('')

# cot_mod['loc_lat'] = []

# %% [markdown]
# ### 3.1.6 Region

# %%
cot_mod.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Fecha Cotizacion', 'Medio', 'Proyecto',
#        'Presencial', 'Jefe Comercial', 'Ejecutivo Comercial',
#        'Total Productos', 'Descuentos', 'Valor Final Venta', 'RUT', 'Nombre',
#        'Apellido 1', 'Apellido 2', 'Nombre Completo', 'Telefono', 'Celular',
#        'Direccion', 'Region', 'Provincia', 'Comuna', 'Correo Electronico',
#        'Sexo', 'Estado Civil', 'Rango Edad', 'Fecha Nacimiento',
#        'Tipo Cliente', 'Giro', 'Nacionalidad', 'N° Grupo Familiar',
#        'Actividad', 'Empleador', 'Profesión', 'Negocio', 'Clean Rut',
#        'Valid Rut', 'Format Rut', 'profesion_agg', 'edad', 'recibio_descuento',
#        '#vivienda', '#bodega', '#estacionamiento', '#estudio', '#lan'],
#       dtype='object')

# %%
cot_mod['Region'].unique()
# Out:
# array(['VIII Región del Bío-Bío', 'XIII Región Metropolitana de Santiago',
#        'VII Región del Maule', 'II Región de Antofagasta',
#        'IV Región de Coquimbo', 'X Región de Los Lagos',
#        'XII Región de Magallanes y de La Antártica Chilena',
#        'V Región de Valparaíso',
#        'VI Región del Libertador General Bernardo O Higgins',
#        'XIV Región de Los Ríos',
#        'XI Región de Aysen del General Carlos Ibáñez del Campo',
#        'I Región de Tarapacá', 'IX Región de La Araucanía',
#        'III Región de Atacama', 'XV Region de Arica y Parinacota'],
#       dtype=object)

# %%
cot_mod['region'] = cot_mod['Region']
cot_mod['region'] = cot_mod['region'].replace(
    {'VIII Región del Bío-Bío':'Bio-Bio',
     'XIII Región Metropolitana de Santiago':'Metropolitana'}
)
cot_mod['region'] = cot_mod['region'].replace(
    ['II Región de Antofagasta',
       'IV Región de Coquimbo', 'VII Región del Maule',
       'X Región de Los Lagos',
       'V Región de Valparaíso',
       'VI Región del Libertador General Bernardo O Higgins',
       'XIV Región de Los Ríos',
       'XI Región de Aysen del General Carlos Ibáñez del Campo',
       'I Región de Tarapacá', 'IX Región de La Araucanía',
       'XII Región de Magallanes y de La Antártica Chilena',
       'XV Region de Arica y Parinacota', 'III Región de Atacama'],'Otro'
)

# %%
cot_mod['region'] = cot_mod['region'].astype('category')
cot_mod['region'].head()
# Out:
# 0    Bio-Bio
# 1    Bio-Bio
# 2    Bio-Bio
# 3    Bio-Bio
# 4    Bio-Bio
# Name: region, dtype: category
# Categories (3, object): [Bio-Bio, Metropolitana, Otro]

# %%
cot_mod = cot_mod.drop(['Region'], axis=1)

# %% [markdown]
# ### 3.1.7 Provincia
# Esta variable indica si el cliente facilito el correo en alguna cotizacion

# %%
cot_all['Provincia'].unique()
# Out:
# array(['Concepción', 'Ñuble', 'Santiago', 'Talca', 'Biobío', 'Maipo',
#        'Antofagasta', 'Limarí', 'Llanquihue', 'Magallanes', 'El Loa',
#        'Isla de Pascua', 'Valparaíso', 'Cachapoal', 'Arauco',
#        'Cordillera', 'Valdivia', 'Coyhaique', 'Linares', 'Osorno',
#        'San Felipe de Aconcagua', 'Iquique', 'Cautín', 'Capitán Prat',
#        'Aysén', 'Chacabuco', 'Copiapó', 'Melipilla', 'Malleco', 'Arica',
#        'Elqui', 'Cauquenes', 'Colchagua', 'Última Esperanza', 'Curicó',
#        'Chiloé', 'Choapa', 'Huasco'], dtype=object)

# %%
cot_mod['provincia'] = cot_mod['Provincia'].copy()
cot_mod['provincia'] = cot_mod['provincia'].replace(
    {'Concepción':'Concepcion',
     'Santiago':'Santiago'}
)
cot_mod['provincia'] = cot_mod['provincia'].replace(
    ['Antofagasta', 'Limarí', 'Talca', 'Biobío', 'Ñuble',
       'Llanquihue','Maipo', 'Valparaíso', 'Cachapoal',
       'Arauco', 'Valdivia', 'Coyhaique', 'Linares', 'Osorno',
       'San Felipe de Aconcagua', 'Iquique', 'Cautín', 'Capitán Prat',
       'Aysén', 'Chacabuco', 'Melipilla', 'Magallanes', 'Malleco',
       'Arica ', 'Elqui', 'El Loa', 'Cauquenes', 'Colchagua', 'Valdivia ',
       'Copiapó', 'Última Esperanza', 'Cordillera', 'Curicó', 'Chiloé',
       'Choapa', 'Huasco','Arica','Isla de Pascua'],'Otro'
)

# %%
cot_mod['provincia'] = cot_mod['provincia'].astype('category')
cot_mod['provincia'].head()
# Out:
# 0    Concepcion
# 1    Concepcion
# 2    Concepcion
# 3    Concepcion
# 4          Otro
# Name: provincia, dtype: category
# Categories (3, object): [Concepcion, Otro, Santiago]

# %%
cot_mod = cot_mod.drop(['Provincia'], axis=1)

# %% [markdown]
# ### 3.1.8 Comuna
# Esta variable indica si el cliente facilito el correo en alguna cotizacion

# %%
cot_all['Comuna'].unique()
# Out:
# array(['Concepción', 'Chillán', 'San Pedro de la Paz', 'Talcahuano',
#        'La Florida', 'Hualpén', 'Santiago', 'Constitución', 'Los Ángeles',
#        'Ñuñoa', 'Providencia', 'Penco', 'Tomé', 'Buin', 'Antofagasta',
#        'Ovalle', 'Puerto Montt', 'Punta Arenas', 'Chiguayante',
#        'El Bosque', 'Yungay', 'Florida', 'Calama', 'Lota', 'Coronel',
#        'Isla de Pascua', 'Viña del Mar', 'Machalí', 'Arauco',
#        'Las Condes', 'Vitacura', 'Pirque', 'Contulmo', 'Concón',
#        'Santa Juana', 'Puerto Varas', 'Cañete', 'Huechuraba', 'Valdivia',
#        'Coyhaique', 'Colbún', 'Osorno', 'San Felipe', 'Iquique',
#        'Rancagua', 'Temuco', 'Cochrane', 'Chillán Viejo', 'Maipú',
#        'Aysén', 'Villarrica', 'La Reina', 'Peñalolén', 'Estación Central',
#        'Colina', 'Quilicura', 'Curanilahue', 'Copiapó', 'Algarrobo',
#        'Talca', 'San Carlos', 'Mulchén', 'Coelemu', 'Angol', 'Laja',
#        'Nacimiento', 'Arica', 'La Serena', 'Hualqui', 'San Miguel',
#        'Pelluhue', 'Quillón', 'Valparaíso', 'Llanquihue', 'Los Álamos',
#        'Renca', 'Santa Cruz', 'Panguipulli', 'Cabrero', 'Cerrillos',
#        'Pudahuel', 'Natales', 'Tirúa', 'Cauquenes', 'La Cisterna',
#        'Yumbel', 'Ránquil', 'Padre Las Casas', 'Las Cabras', 'Coquimbo',
#        'Lebu', 'San José de Maipo', 'San Ramón', 'Curicó',
#        'Independencia', 'Lampa', 'Castro', 'Punitaqui', 'Conchalí',
#        'San Rosendo', 'Alto Hospicio', 'Illapel', 'Huasco', 'Alto Biobío',
#        'Collipulli', 'Tucapel'], dtype=object)

# %%
cot_mod['comuna'] = cot_mod['Comuna'].copy()

cot_mod['comuna'] = cot_mod['comuna'].replace(
    ['Ovalle', 'Constitución','Tomé', 'Chillán','Yungay',
     'Puerto Montt', 'Santiago', 'El Bosque', 'La Florida','Las Condes',
     'Ñuñoa', 'Providencia', 'Buin','Florida','Viña del Mar',
     'Machalí', 'Vitacura', 'Arauco', 'Contulmo', 'Concón',
     'Santa Juana', 'Puerto Varas', 'Cañete', 'Huechuraba', 'Valdivia',
     'Coyhaique', 'Colbún', 'Osorno', 'San Felipe', 'Iquique',
     'Rancagua', 'Lota', 'Temuco', 'Cochrane', 'Chillán Viejo', 'Maipú',
     'Aysén', 'Villarrica', 'La Reina', 'Peñalolén', 'Estación Central',
     'Colina', 'Quilicura', 'Curanilahue', 'Algarrobo', 'Talca',
     'San Carlos', 'Punta Arenas', 'Mulchén', 'Coelemu', 'Angol',
     'Laja', 'Nacimiento', 'Arica', 'La Serena', 'Hualqui',
     'San Miguel', 'Calama', 'Pelluhue', 'Quillón', 'Valparaíso',
     'Llanquihue', 'Los Álamos', 'Renca', 'Santa Cruz', 'Panguipulli',
     'Cabrero', 'Cerrillos', 'Pudahuel', 'Copiapó', 'Natales', 'Tirúa',
     'Cauquenes', 'La Cisterna', 'Yumbel', 'Ránquil', 'Padre Las Casas',
     'Las Cabras', 'Coquimbo', 'Lebu', 'San José de Maipo', 'San Ramón',
     'Curicó', 'Independencia', 'Lampa ', 'Castro', 'Punitaqui',
     'Conchalí', 'San Rosendo', 'Alto Hospicio', 'Illapel', 'Huasco',
     'Collipulli', 'Tucapel', 'Alto Biobío','Pirque','Lampa','Isla de Pascua','Antofagasta', 'Arica'],'Otro'
)

# %%
cot_mod['comuna'] = cot_mod['comuna'].astype('category')
cot_mod['comuna'].head()
# Out:
# 0    Concepción
# 1    Concepción
# 2    Concepción
# 3    Concepción
# 4          Otro
# Name: comuna, dtype: category
# Categories (9, object): [Chiguayante, Concepción, Coronel, Hualpén, ..., Otro, Penco, San Pedro de la Paz, Talcahuano]

# %%
cot_mod = cot_mod.drop(['Comuna'], axis=1)

# %% [markdown]
# ### 3.1.9 Atributos Provistos
# Esta variable indica el numero de veces que el cliente ha hecho cotizaciones

# %%
cot_mod['is_nombre'] = ~cot_mod['Nombre'].isnull()
cot_mod['is_apellido1'] = ~cot_mod['Apellido 1'].isnull()
cot_mod['is_apellido2'] = ~cot_mod['Apellido 2'].isnull()
cot_mod['is_nombrecompleto'] = ~cot_mod['Nombre Completo'].isnull()
cot_mod['is_correo'] = ~cot_mod['Correo Electronico'].isnull()
cot_mod['is_direccion'] = ~cot_mod['Direccion'].isnull()
cot_mod['is_telefono'] = ~cot_mod['Telefono'].isnull()
cot_mod['is_actividad'] = ~cot_mod['Actividad'].isnull()
cot_mod['is_estado_civil'] = ~cot_mod['Estado Civil'].isnull()
cot_mod['is_fnac'] = ~cot_mod['Fecha Nacimiento'].isnull()
cot_mod['is_celular'] = ~cot_mod['Celular'].isnull()

cot_mod['is_profesion'] = cot_mod['profesion_agg'] != 'sin informacion'

cot_mod = cot_mod.drop(['Profesión','Telefono','Correo Electronico','Telefono','Nombre','Apellido 1','Apellido 2','Nombre Completo'], axis=1)

# %% [markdown]
# ### 3.1.9 Atributos Provistos
# Esta variable indica el numero de veces que el cliente ha hecho cotizaciones

# %% [markdown]
# ### 3.1.4 Cotizaciones por Proyecto

# %%
rut_dict = dict()

    
for index, row in cot_mod.iterrows():
    rut = row['Format Rut']
    pr = row['Proyecto']
    
    if rut not in rut_dict.keys():
        rut_dict[rut] = dict()
        rut_dict[rut]['Altos del Valle'] = 0
        rut_dict[rut]['Edificio Urban 1470'] = 0
        rut_dict[rut]['San Andres Del Valle'] = 0
        rut_dict[rut]['Edificio Mil610'] = 0
        rut_dict[rut]['Edificio Junge'] = 0
    
    rut_dict[rut][pr] +=1



rut_proyectos = pd.DataFrame.from_dict(rut_dict,orient='index').reset_index()
rut_proyectos.head()

# cot_mod = pd.merge(cot_mod_cp, rut_proyectos,how='left', left_on='Format Rut', right_on='index')
# Out:
#            index  Altos del Valle  Edificio Urban 1470  San Andres Del Valle  \
# 0  000.000.000-0                0                    1                     1
# 1    1.462.558-5                0                    0                     0
# 2   10.000.513-1                0                    0                     0
# 3   10.000.522-0                0                    0                     0
# 4   10.005.853-7                0                    0                     0
#
#    Edificio Mil610  Edificio Junge
# 0                0               0
# 1                1               0
# 2                0               2
# 3                0               2
# 4                0               2

# %%
cot_mod.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Fecha Cotizacion', 'Medio', 'Proyecto',
#        'Presencial', 'Jefe Comercial', 'Ejecutivo Comercial',
#        'Total Productos', 'Descuentos', 'Valor Final Venta', 'RUT', 'Celular',
#        'Direccion', 'Sexo', 'Estado Civil', 'Rango Edad', 'Fecha Nacimiento',
#        'Tipo Cliente', 'Giro', 'Nacionalidad', 'N° Grupo Familiar',
#        'Actividad', 'Empleador', 'Negocio', 'Clean Rut', 'Valid Rut',
#        'Format Rut', 'profesion_agg', 'edad', 'recibio_descuento', '#vivienda',
#        '#bodega', '#estacionamiento', '#estudio', '#lan', 'region',
#        'provincia', 'comuna', 'is_nombre', 'is_apellido1', 'is_apellido2',
#        'is_nombrecompleto', 'is_correo', 'is_direccion', 'is_telefono',
#        'is_actividad', 'is_estado_civil', 'is_fnac', 'is_celular',
#        'is_profesion'],
#       dtype='object')

# %% [markdown]
# ### 3.1.9 Rango Edad
# Esta variable indica el numero de veces que el cliente ha hecho cotizaciones

# %%
### Ver edades en cotizantes y cotizantes que llegan a negocios
rango_edad = cot_mod['Rango Edad'].tolist()
rango_edad_min = [];rango_edad_max = []

for e in rango_edad:
    try:
        edad = e.split('-')
        rango_edad_min.append(int(edad[0]))
        rango_edad_max.append(int(edad[1]))
    except (ValueError, AttributeError):
        rango_edad_min.append(0)
        rango_edad_max.append(0)
        
cot_mod['Edad Min'] = rango_edad_min
cot_mod['Edad Max'] = rango_edad_max

# %% [markdown]
# ### 3.1.11 Negocio
# Indica si el cliente siguio el proceso de cotizacion y lo transformo en un proceso de negocio

# %%
# ruts de los clientes en negocio
neg_ids = neg_all['ID Cotizacion'].unique().tolist()

# cot_neg = cot_all.copy()
cot_mod['Negocio'] = cot_mod['ID'].isin(neg_ids)
cot_mod[cot_mod['Negocio'] == True].shape
# Out:
# (2336, 53)

# %% [markdown]
# ### 3.1.12 N° Grupo Familiar

# %%
cot_mod['N° Grupo Familiar']=cot_mod['N° Grupo Familiar'].fillna('Sin Información')

# %%
def is_nrofam(x):
    if x == 'Sin Información':
        return False
    else:
        return True

cot_mod['is_nrofam'] = [ is_nrofam(x) for x in cot_mod['N° Grupo Familiar'] ]

# %%
cot_mod.to_excel('..\\..\\Datos\\working\\cotizaciones_transformed.xlsx')

# %% [markdown]
# ### 3.1.12 N° Grupo Familiar

# %% [markdown]
# ### 3.2. Extraccion de Datos
# Esta variable indica el numero de veces que el cliente ha hecho cotizaciones

# %%
#View data integration
iterator = 0
for group, frame in  cot_mod.groupby('Format Rut'):
    
#     print(frame['N° Grupo Familiar'].isnull())
    #Check , debe ir a data exploration
    print(group)
    print(frame['Medio'])
    arr = frame['Medio'].unique()
    l = len(arr)
    if l > 1:
        if True in arr: 
            iterator +=1
            print(group)
#         print(l)

print(iterator)
# Out:
# 000.000.000-0
# 3601        FINCO
# 14926    INTERNET
# Name: Medio, dtype: object
# 1.462.558-5
# 1651    INTERNET
# Name: Medio, dtype: object
# 10.000.513-1
# 595    RECORRIDO POR EL SECTOR
# 596    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.000.522-0
# 877    RECONTACTO
# 878    RECONTACTO
# Name: Medio, dtype: object
# 10.005.853-7
# 900    REFERIDOS
# 901    REFERIDOS
# Name: Medio, dtype: object
# 10.007.663-2
# 9961     INTERNET
# 10390    INTERNET
# Name: Medio, dtype: object
# 10.011.197-7
# 13764    RECORRIDO POR EL SECTOR
# 13821                  REFERIDOS
# Name: Medio, dtype: object
# 10.014.004-7
# 12668    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.014.880-3
# 11457    INTERNET
# Name: Medio, dtype: object
# 10.015.654-7
# 7807    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.016.093-5
# 1218    RECONTACTO
# 1219    RECONTACTO
# 6885    RECONTACTO
# 6886    RECONTACTO
# Name: Medio, dtype: object
# 10.019.023-0
# 5268    INTERNET
# Name: Medio, dtype: object
# 10.020.262-k
# 5559    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.023.348-7
# 16367    INTERNET
# Name: Medio, dtype: object
# 10.023.667-2
# 16157    FINCO
# Name: Medio, dtype: object
# 10.025.981-8
# 8592    RECORRIDO POR EL SECTOR
# 9041                 RECONTACTO
# 9042                 RECONTACTO
# 9043                 RECONTACTO
# 9044                 RECONTACTO
# Name: Medio, dtype: object
# 10.027.672-0
# 3208    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.028.126-0
# 5301      LETREROS
# 5302      LETREROS
# 5303    RECONTACTO
# 5465      INTERNET
# 5467      INTERNET
# 5468      INTERNET
# 5469      INTERNET
# 5498    RECONTACTO
# 5499    RECONTACTO
# Name: Medio, dtype: object
# 10.028.253-4
# 13791    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.028.666-1
# 16567    RECORRIDO POR EL SECTOR
# 16568    RECORRIDO POR EL SECTOR
# 16569    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.029.258-0
# 3270      LETREROS
# 14975    REFERIDOS
# 14977    REFERIDOS
# Name: Medio, dtype: object
# 10.033.390-2
# 6153    RECORRIDO POR EL SECTOR
# 6168                  REFERIDOS
# 6170                  REFERIDOS
# 6171                  REFERIDOS
# 6188                   INTERNET
# 6252                 RECONTACTO
# 6313    RECORRIDO POR EL SECTOR
# 6350                 RECONTACTO
# 6443                 RECONTACTO
# 6795                 RECONTACTO
# Name: Medio, dtype: object
# 10.034.279-0
# 2667    RECORRIDO POR EL SECTOR
# 2700    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.037.203-7
# 7836     INTERNET
# 15696    INTERNET
# 15697    INTERNET
# Name: Medio, dtype: object
# 10.037.368-8
# 9182    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.037.786-1
# 7935    RECORRIDO POR EL SECTOR
# 8145                 RECONTACTO
# 8146                 RECONTACTO
# Name: Medio, dtype: object
# 10.037.848-5
# 6771    INTERNET
# 6774    INTERNET
# 6775    INTERNET
# Name: Medio, dtype: object
# 10.038.242-3
# 13891    FINCO
# Name: Medio, dtype: object
# 10.038.900-2
# 8096      INTERNET
# 8097      INTERNET
# 8098      INTERNET
# 8099      INTERNET
# 8113    RECONTACTO
# Name: Medio, dtype: object
# 10.040.204-1
# 14383    REFERIDOS
# Name: Medio, dtype: object
# 10.040.651-9
# 13531    INTERNET
# Name: Medio, dtype: object
# 10.044.790-8
# 2538    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.046.270-2
# 3953    RECORRIDO POR EL SECTOR
# 4613                    EVENTOS
# 4614                    EVENTOS
# Name: Medio, dtype: object
# 10.047.763-7
# 15491    LETREROS
# Name: Medio, dtype: object
# 10.048.693-8
# 7462    RECORRIDO POR EL SECTOR
# 7463    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.051.640-3
# 14155    REFERIDOS
# 14156    REFERIDOS
# 14157    REFERIDOS
# 14203    REFERIDOS
# 14217    REFERIDOS
# 14218    REFERIDOS
# Name: Medio, dtype: object
# 10.053.156-9
# 6353    INTERNET
# 6354    INTERNET
# 6355    INTERNET
# Name: Medio, dtype: object
# 10.054.041-k
# 14492    INTERNET
# Name: Medio, dtype: object
# 10.054.460-1
# 6983    RECORRIDO POR EL SECTOR
# 6984                 RECONTACTO
# Name: Medio, dtype: object
# 10.057.512-4
# 2585    RECORRIDO POR EL SECTOR
# 2586    RECORRIDO POR EL SECTOR
# 2587    RECORRIDO POR EL SECTOR
# 2875                 RECONTACTO
# 2876                 RECONTACTO
# 2898                 RECONTACTO
# Name: Medio, dtype: object
# 10.058.927-3
# 5852    FINCO
# Name: Medio, dtype: object
# 10.062.959-3
# 3115    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.063.198-9
# 11520    RECONTACTO
# 11682    RECONTACTO
# 11683    RECONTACTO
# Name: Medio, dtype: object
# 10.065.290-0
# 15    RECORRIDO POR EL SECTOR
# 64    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.066.179-9
# 8820    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.068.204-4
# 14409    RECORRIDO POR EL SECTOR
# 14410    RECORRIDO POR EL SECTOR
# 14510                 RECONTACTO
# 14598                 RECONTACTO
# Name: Medio, dtype: object
# 10.069.788-2
# 7286    RECONTACTO
# 7287    RECONTACTO
# 7291    RECONTACTO
# 7292    RECONTACTO
# Name: Medio, dtype: object
# 10.072.477-4
# 8975    RECORRIDO POR EL SECTOR
# 8976    RECORRIDO POR EL SECTOR
# 8977    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.073.252-1
# 7643    RECONTACTO
# Name: Medio, dtype: object
# 10.075.429-0
# 3408    RECONTACTO
# Name: Medio, dtype: object
# 10.075.441-k
# 3349    RECONTACTO
# Name: Medio, dtype: object
# 10.076.129-7
# 7924    INTERNET
# Name: Medio, dtype: object
# 10.076.241-2
# 11    RECONTACTO
# Name: Medio, dtype: object
# 10.076.252-8
# 15263    REFERIDOS
# Name: Medio, dtype: object
# 10.080.393-3
# 12364    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.094.056-6
# 1952    RECORRIDO POR EL SECTOR
# 1953    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.094.196-1
# 12052    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.106.105-1
# 4389    RECORRIDO POR EL SECTOR
# 4390    RECORRIDO POR EL SECTOR
# 4392                   LETREROS
# 4394                   LETREROS
# Name: Medio, dtype: object
# 10.108.619-4
# 6066    FINCO
# Name: Medio, dtype: object
# 10.117.065-3
# 425    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.117.692-4
# 3572    FINCO
# Name: Medio, dtype: object
# 10.118.617-2
# 7520     RECORRIDO POR EL SECTOR
# 7521     RECORRIDO POR EL SECTOR
# 7522     RECORRIDO POR EL SECTOR
# 7523     RECORRIDO POR EL SECTOR
# 7524     RECORRIDO POR EL SECTOR
# 11959    RECORRIDO POR EL SECTOR
# 11960    RECORRIDO POR EL SECTOR
# 11961    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.124.480-6
# 3706    LETREROS
# Name: Medio, dtype: object
# 10.126.447-5
# 3319    RECONTACTO
# 4865    RECONTACTO
# 4866    RECONTACTO
# Name: Medio, dtype: object
# 10.132.817-1
# 11030    RECONTACTO
# 11031    RECONTACTO
# 11032    RECONTACTO
# 11033    RECONTACTO
# 11034    RECONTACTO
# 11035    RECONTACTO
# Name: Medio, dtype: object
# 10.137.843-8
# 14479    REFERIDOS
# 14480    REFERIDOS
# 14569    REFERIDOS
# Name: Medio, dtype: object
# 10.139.734-3
# 10276    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.142.997-0
# 7339    INTERNET
# 7340    INTERNET
# Name: Medio, dtype: object
# 10.147.113-6
# 3544    FINCO
# 3586    FINCO
# 3587    FINCO
# 3588    FINCO
# Name: Medio, dtype: object
# 10.147.861-0
# 16344    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.153.837-0
# 1867    INTERNET
# Name: Medio, dtype: object
# 10.155.954-8
# 16301    FINCO
# Name: Medio, dtype: object
# 10.161.184-1
# 10225    RECORRIDO POR EL SECTOR
# 10835                 RECONTACTO
# Name: Medio, dtype: object
# 10.163.032-3
# 5041    RECORRIDO POR EL SECTOR
# 5042    RECORRIDO POR EL SECTOR
# 5043    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.164.559-2
# 4759    INTERNET
# Name: Medio, dtype: object
# 10.164.731-5
# 3907    LETREROS
# Name: Medio, dtype: object
# 10.168.822-4
# 3118    INTERNET
# 3155    INTERNET
# 9213    INTERNET
# Name: Medio, dtype: object
# 10.168.842-9
# 768    INTERNET
# 769    INTERNET
# Name: Medio, dtype: object
# 10.169.741-k
# 8227    RECONTACTO
# 8228    RECONTACTO
# 8229    RECONTACTO
# 8230    RECONTACTO
# 8231    RECONTACTO
# Name: Medio, dtype: object
# 10.170.333-9
# 167    RECONTACTO
# Name: Medio, dtype: object
# 10.171.120-k
# 689                        FINCO
# 690      RECORRIDO POR EL SECTOR
# 12779                   INTERNET
# 12780                   INTERNET
# Name: Medio, dtype: object
# 10.177.000-1
# 13716    EVENTOS
# 13717    EVENTOS
# 13718    EVENTOS
# 13719    EVENTOS
# Name: Medio, dtype: object
# 10.180.004-0
# 4412                   LETREROS
# 4413                   LETREROS
# 4414    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.180.285-k
# 6662    INTERNET
# 6663    INTERNET
# Name: Medio, dtype: object
# 10.184.823-k
# 6838    INTERNET
# Name: Medio, dtype: object
# 10.184.906-6
# 9087     RECORRIDO POR EL SECTOR
# 9088     RECORRIDO POR EL SECTOR
# 9932                  RECONTACTO
# 9933                  RECONTACTO
# 9934                  RECONTACTO
# 10008                 RECONTACTO
# 10009                 RECONTACTO
# 10010                 RECONTACTO
# 10057                 RECONTACTO
# Name: Medio, dtype: object
# 10.186.597-5
# 9168    REFERIDOS
# 9169    REFERIDOS
# Name: Medio, dtype: object
# 10.187.893-7
# 5292    INTERNET
# 5293    INTERNET
# Name: Medio, dtype: object
# 10.193.821-2
# 202    INTERNET
# 203    INTERNET
# 204    INTERNET
# Name: Medio, dtype: object
# 10.204.640-4
# 5620    RECONTACTO
# Name: Medio, dtype: object
# 10.214.251-9
# 12977    INTERNET
# 12978    INTERNET
# 12979    INTERNET
# 12980    INTERNET
# Name: Medio, dtype: object
# 10.222.780-8
# 12540    REFERIDOS
# Name: Medio, dtype: object
# 10.228.682-0
# 8547    RECONTACTO
# 8587    RECONTACTO
# Name: Medio, dtype: object
# 10.232.375-0
# 15834    INTERNET
# Name: Medio, dtype: object
# 10.237.540-8
# 4228      INTERNET
# 4231      INTERNET
# 4265    RECONTACTO
# 4306    RECONTACTO
# Name: Medio, dtype: object
# 10.238.506-3
# 4901    LETREROS
# Name: Medio, dtype: object
# 10.250.082-2
# 4351    RECORRIDO POR EL SECTOR
# 4352    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.254.107-3
# 15679    RECORRIDO POR EL SECTOR
# 15684    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.255.699-2
# 60       RECORRIDO POR EL SECTOR
# 61       RECORRIDO POR EL SECTOR
# 13496    RECORRIDO POR EL SECTOR
# 13497    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.266.404-3
# 1278                   INTERNET
# 1279                   INTERNET
# 1713    RECORRIDO POR EL SECTOR
# 1714    RECORRIDO POR EL SECTOR
# 1715    RECORRIDO POR EL SECTOR
# 2041                   INTERNET
# 2042                   INTERNET
# Name: Medio, dtype: object
# 10.266.428-0
# 1670    LETREROS
# Name: Medio, dtype: object
# 10.267.047-7
# 11276    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.270.104-6
# 4155    INTERNET
# Name: Medio, dtype: object
# 10.272.204-3
# 16139    FINCO
# 16282    FINCO
# Name: Medio, dtype: object
# 10.272.955-2
# 10633    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.273.637-0
# 14447    INTERNET
# Name: Medio, dtype: object
# 10.278.036-1
# 294     RECORRIDO POR EL SECTOR
# 1322                   INTERNET
# 1323                   INTERNET
# 2101    RECORRIDO POR EL SECTOR
# 2102    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.278.988-1
# 4145    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.281.426-6
# 8087    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.281.727-3
# 16121    FINCO
# 16122    FINCO
# Name: Medio, dtype: object
# 10.281.990-K
# 15925    INTERNET
# Name: Medio, dtype: object
# 10.290.085-5
# 7988      INTERNET
# 7993    RECONTACTO
# 7994    RECONTACTO
# 7995    RECONTACTO
# 7996    RECONTACTO
# Name: Medio, dtype: object
# 10.292.510-6
# 2995                    INTERNET
# 14043                   INTERNET
# 14044                   INTERNET
# 14045                   INTERNET
# 14046                   INTERNET
# 14276                   INTERNET
# 14285                 RECONTACTO
# 14286                 RECONTACTO
# 14679                   INTERNET
# 14683    RECORRIDO POR EL SECTOR
# 15532                   INTERNET
# 16140                   INTERNET
# 16402    RECORRIDO POR EL SECTOR
# 16403    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.299.543-0
# 4463      INTERNET
# 4464      INTERNET
# 4465      INTERNET
# 4466     REFERIDOS
# 4467     REFERIDOS
# 4468    RECONTACTO
# 4469      INTERNET
# Name: Medio, dtype: object
# 10.305.436-2
# 7687     RECORRIDO POR EL SECTOR
# 7688     RECORRIDO POR EL SECTOR
# 7689     RECORRIDO POR EL SECTOR
# 9917     RECORRIDO POR EL SECTOR
# 9918     RECORRIDO POR EL SECTOR
# 9919     RECORRIDO POR EL SECTOR
# 9920     RECORRIDO POR EL SECTOR
# 11515                 RECONTACTO
# 11592                 RECONTACTO
# 11593                 RECONTACTO
# Name: Medio, dtype: object
# 10.305.957-7
# 13832       FINCO
# 14104       FINCO
# 15436    INTERNET
# Name: Medio, dtype: object
# 10.307.061-9
# 3265                 RECONTACTO
# 9472    RECORRIDO POR EL SECTOR
# 9473    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.307.244-1
# 8797     RECORRIDO POR EL SECTOR
# 8798     RECORRIDO POR EL SECTOR
# 11424                 RECONTACTO
# Name: Medio, dtype: object
# 10.308.520-9
# 8466    FINCO
# Name: Medio, dtype: object
# 10.310.133-6
# 16008    INTERNET
# Name: Medio, dtype: object
# 10.310.497-1
# 5490    RECONTACTO
# Name: Medio, dtype: object
# 10.311.071-8
# 8223    FINCO
# 8319    FINCO
# Name: Medio, dtype: object
# 10.311.890-5
# 6726     RECORRIDO POR EL SECTOR
# 8568                   REFERIDOS
# 10249    RECORRIDO POR EL SECTOR
# 10250    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.312.153-1
# 8431    RECORRIDO POR EL SECTOR
# 8875                 RECONTACTO
# 8876    RECORRIDO POR EL SECTOR
# 9492                 RECONTACTO
# 9493                 RECONTACTO
# 9494                 RECONTACTO
# 9544                 RECONTACTO
# 9587                 RECONTACTO
# 9774                 RECONTACTO
# 9775                 RECONTACTO
# 9776                 RECONTACTO
# Name: Medio, dtype: object
# 10.313.261-4
# 2237    REFERIDOS
# Name: Medio, dtype: object
# 10.316.844-9
# 16502    FINCO
# Name: Medio, dtype: object
# 10.319.046-0
# 11314    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.319.120-3
# 15281                   INTERNET
# 15282                   INTERNET
# 15283                   INTERNET
# 15296    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.323.247-3
# 16144    FINCO
# Name: Medio, dtype: object
# 10.323.248-1
# 7506    RECORRIDO POR EL SECTOR
# 7507    RECORRIDO POR EL SECTOR
# 7547                 RECONTACTO
# Name: Medio, dtype: object
# 10.323.789-0
# 4651    INTERNET
# Name: Medio, dtype: object
# 10.324.991-0
# 11209    INTERNET
# 11210    INTERNET
# 11211    INTERNET
# Name: Medio, dtype: object
# 10.327.568-7
# 7928    INTERNET
# 7929    INTERNET
# Name: Medio, dtype: object
# 10.331.526-3
# 15799    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.333.153-6
# 16107    FINCO
# 16551    FINCO
# Name: Medio, dtype: object
# 10.335.265-7
# 7244    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.335.964-3
# 5196     INTERNET
# 5198    REFERIDOS
# Name: Medio, dtype: object
# 10.336.815-4
# 15117    RECORRIDO POR EL SECTOR
# 15118    RECORRIDO POR EL SECTOR
# 15119    RECORRIDO POR EL SECTOR
# 15134    RECORRIDO POR EL SECTOR
# 15135    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.339.624-7
# 12654    REFERIDOS
# 12655    REFERIDOS
# 13267        FINCO
# Name: Medio, dtype: object
# 10.341.629-9
# 16106    FINCO
# 16550    FINCO
# Name: Medio, dtype: object
# 10.344.199-4
# 4072    RECORRIDO POR EL SECTOR
# 4073    RECORRIDO POR EL SECTOR
# 4075    RECORRIDO POR EL SECTOR
# 4114                 RECONTACTO
# Name: Medio, dtype: object
# 10.344.658-9
# 10101    INTERNET
# 10102    INTERNET
# Name: Medio, dtype: object
# 10.345.363-1
# 16373    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.345.538-3
# 15672    REFERIDOS
# 15673    REFERIDOS
# Name: Medio, dtype: object
# 10.349.563-6
# 227    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.350.350-7
# 1424    RECONTACTO
# 1425    RECONTACTO
# 1563      INTERNET
# 1564      INTERNET
# Name: Medio, dtype: object
# 10.350.362-0
# 2176    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.352.115-7
# 6499    RECORRIDO POR EL SECTOR
# 6505                 RECONTACTO
# 6530                 RECONTACTO
# Name: Medio, dtype: object
# 10.354.605-2
# 5464    RECORRIDO POR EL SECTOR
# 5586                   INTERNET
# Name: Medio, dtype: object
# 10.355.504-3
# 15601    RECORRIDO POR EL SECTOR
# 15602    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.356.073-k
# 11615    RECORRIDO POR EL SECTOR
# 11616    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.362.175-5
# 14735    RECORRIDO POR EL SECTOR
# 14736    RECORRIDO POR EL SECTOR
# 14737    RECORRIDO POR EL SECTOR
# 14738    RECORRIDO POR EL SECTOR
# 14899                 RECONTACTO
# 14900                 RECONTACTO
# 14921    RECORRIDO POR EL SECTOR
# 15322                   INTERNET
# Name: Medio, dtype: object
# 10.364.582-4
# 2530    RECORRIDO POR EL SECTOR
# 2531    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.364.660-k
# 8464    FINCO
# Name: Medio, dtype: object
# 10.364.916-1
# 4281    INTERNET
# 4282    INTERNET
# 4283    INTERNET
# Name: Medio, dtype: object
# 10.364.923-4
# 5849    FINCO
# 5850    FINCO
# Name: Medio, dtype: object
# 10.365.007-0
# 1066    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.365.172-7
# 12730    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.365.174-3
# 16270    FINCO
# Name: Medio, dtype: object
# 10.369.376-4
# 3048    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.370.338-7
# 3651    FINCO
# Name: Medio, dtype: object
# 10.370.352-2
# 987    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.371.470-2
# 9801    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.378.670-3
# 3178    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.383.584-4
# 3998    RECONTACTO
# Name: Medio, dtype: object
# 10.384.073-2
# 15423    LETREROS
# 15424    LETREROS
# 15425    INTERNET
# Name: Medio, dtype: object
# 10.384.088-0
# 8198    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.388.079-3
# 11700    INTERNET
# Name: Medio, dtype: object
# 10.393.657-8
# 5138      LETREROS
# 5149    RECONTACTO
# 5150    RECONTACTO
# Name: Medio, dtype: object
# 10.395.384-7
# 469    RECORRIDO POR EL SECTOR
# 470    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.398.483-1
# 2260    RECORRIDO POR EL SECTOR
# 2261    RECORRIDO POR EL SECTOR
# 2262    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.402.639-7
# 116    RECORRIDO POR EL SECTOR
# 117    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.402.657-5
# 8879    RECORRIDO POR EL SECTOR
# 9530                 RECONTACTO
# Name: Medio, dtype: object
# 10.405.641-5
# 4103    INTERNET
# 4104    INTERNET
# Name: Medio, dtype: object
# 10.406.205-9
# 8202    RECORRIDO POR EL SECTOR
# 8203    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.406.949-5
# 3843    RECORRIDO POR EL SECTOR
# 3844    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.409.154-7
# 1084    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.413.195-6
# 1939    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.413.644-3
# 10174    INTERNET
# Name: Medio, dtype: object
# 10.413.966-3
# 4709    INTERNET
# Name: Medio, dtype: object
# 10.414.127-7
# 347    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.418.448-0
# 874    INTERNET
# 875    INTERNET
# Name: Medio, dtype: object
# 10.424.152-2
# 3467    LETREROS
# Name: Medio, dtype: object
# 10.424.352-5
# 8117    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.424.643-5
# 8997      INTERNET
# 9215    RECONTACTO
# Name: Medio, dtype: object
# 10.425.732-1
# 5648    INTERNET
# 5649    INTERNET
# Name: Medio, dtype: object
# 10.428.942-8
# 4799    INTERNET
# Name: Medio, dtype: object
# 10.435.358-4
# 7154    RECORRIDO POR EL SECTOR
# 7155    RECORRIDO POR EL SECTOR
# 7156    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.439.719-0
# 5549    RECONTACTO
# 5550    RECONTACTO
# 5551    RECONTACTO
# 5552    RECONTACTO
# 5553    RECONTACTO
# 5554    RECONTACTO
# Name: Medio, dtype: object
# 10.440.320-4
# 5861    FINCO
# Name: Medio, dtype: object
# 10.444.048-7
# 149      RECONTACTO
# 9672       INTERNET
# 10770    RECONTACTO
# 10771    RECONTACTO
# 10794    RECONTACTO
# 11319    RECONTACTO
# 11419    RECONTACTO
# Name: Medio, dtype: object
# 10.444.114-9
# 6685    RECONTACTO
# Name: Medio, dtype: object
# 10.447.306-7
# 4956    LETREROS
# Name: Medio, dtype: object
# 10.453.609-3
# 5353    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.455.079-7
# 11982    RECONTACTO
# 12063    RECONTACTO
# Name: Medio, dtype: object
# 10.462.028-0
# 13157    RECORRIDO POR EL SECTOR
# 13158    RECORRIDO POR EL SECTOR
# 13197                 RECONTACTO
# 13342                 RECONTACTO
# Name: Medio, dtype: object
# 10.464.557-7
# 10192    RECONTACTO
# 10193    RECONTACTO
# Name: Medio, dtype: object
# 10.467.908-0
# 7761    INTERNET
# Name: Medio, dtype: object
# 10.475.609-3
# 10298                   INTERNET
# 13649    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.476.033-3
# 4232    LETREROS
# Name: Medio, dtype: object
# 10.476.999-3
# 1047    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.478.502-6
# 15129    RECORRIDO POR EL SECTOR
# 15130    RECORRIDO POR EL SECTOR
# 15131    RECORRIDO POR EL SECTOR
# 15132    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.478.863-7
# 4267    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.479.661-3
# 5956    RECORRIDO POR EL SECTOR
# 5960                 RECONTACTO
# Name: Medio, dtype: object
# 10.480.255-9
# 6464                   INTERNET
# 8589    RECORRIDO POR EL SECTOR
# 8590    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.481.398-4
# 16322    FINCO
# Name: Medio, dtype: object
# 10.481.542-1
# 4519    RECONTACTO
# Name: Medio, dtype: object
# 10.481.733-5
# 3538    FINCO
# 3630    FINCO
# 3631    FINCO
# 3632    FINCO
# 3633    FINCO
# 3857    FINCO
# Name: Medio, dtype: object
# 10.483.016-1
# 16002    INTERNET
# Name: Medio, dtype: object
# 10.490.080-1
# 10127    RECORRIDO POR EL SECTOR
# 10128    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.493.354-8
# 11368    INTERNET
# 11369    INTERNET
# Name: Medio, dtype: object
# 10.496.229-7
# 8320    FINCO
# Name: Medio, dtype: object
# 10.498.832-6
# 8992     RECONTACTO
# 9135     RECONTACTO
# 13235         FINCO
# Name: Medio, dtype: object
# 10.500.435-4
# 13946    RECONTACTO
# 13955    RECONTACTO
# Name: Medio, dtype: object
# 10.500.603-9
# 633    INTERNET
# Name: Medio, dtype: object
# 10.505.591-9
# 4323    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.506.030-0
# 13878         FINCO
# 14029    RECONTACTO
# Name: Medio, dtype: object
# 10.506.033-5
# 6844                   INTERNET
# 6893    RECORRIDO POR EL SECTOR
# 6894    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.506.051-3
# 10503         FINCO
# 10585         FINCO
# 10586         FINCO
# 10647         FINCO
# 10726         FINCO
# 10966    RECONTACTO
# Name: Medio, dtype: object
# 10.506.639-2
# 15711    INTERNET
# 15984    INTERNET
# Name: Medio, dtype: object
# 10.516.915-9
# 255        INTERNET
# 256        INTERNET
# 257        INTERNET
# 258        INTERNET
# 13555    RECONTACTO
# 13558    RECONTACTO
# 13559    RECONTACTO
# Name: Medio, dtype: object
# 10.517.885-9
# 2711    REFERIDOS
# Name: Medio, dtype: object
# 10.521.947-4
# 10055    RECORRIDO POR EL SECTOR
# 10056    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.527.246-4
# 6432    RECORRIDO POR EL SECTOR
# 6433    RECORRIDO POR EL SECTOR
# 6434    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.528.726-7
# 10221    RECORRIDO POR EL SECTOR
# 10222    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.529.918-4
# 11913    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.532.336-0
# 9986    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.540.070-5
# 6382    RECORRIDO POR EL SECTOR
# 6915                 RECONTACTO
# Name: Medio, dtype: object
# 10.540.356-9
# 5218    INTERNET
# Name: Medio, dtype: object
# 10.540.668-1
# 2848    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.540.790-4
# 445       LETREROS
# 446       LETREROS
# 3409      LETREROS
# 3525    RECONTACTO
# 3526    RECONTACTO
# 4621       EVENTOS
# Name: Medio, dtype: object
# 10.541.541-9
# 5645    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.545.485-6
# 16158    FINCO
# Name: Medio, dtype: object
# 10.548.020-2
# 12398    REFERIDOS
# Name: Medio, dtype: object
# 10.548.356-2
# 523      INTERNET
# 5780    REFERIDOS
# 8499     INTERNET
# 8500     INTERNET
# Name: Medio, dtype: object
# 10.549.014-3
# 3971    INTERNET
# Name: Medio, dtype: object
# 10.552.598-2
# 237      RECONTACTO
# 238      RECONTACTO
# 13843         FINCO
# 13844         FINCO
# 15831      INTERNET
# 15832      INTERNET
# 15833      INTERNET
# 15856      INTERNET
# 15945      INTERNET
# Name: Medio, dtype: object
# 10.555.698-5
# 7571     RECORRIDO POR EL SECTOR
# 7572     RECORRIDO POR EL SECTOR
# 7626                  RECONTACTO
# 10196                 RECONTACTO
# 10198                 RECONTACTO
# 10234                 RECONTACTO
# 10235                 RECONTACTO
# 10236                 RECONTACTO
# Name: Medio, dtype: object
# 10.556.056-7
# 12592    RECORRIDO POR EL SECTOR
# 12608                 RECONTACTO
# Name: Medio, dtype: object
# 10.557.336-7
# 15615    INTERNET
# Name: Medio, dtype: object
# 10.557.431-2
# 3321    RECONTACTO
# Name: Medio, dtype: object
# 10.559.714-2
# 10003    REFERIDOS
# Name: Medio, dtype: object
# 10.568.363-4
# 259    RECORRIDO POR EL SECTOR
# 260    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.575.141-9
# 9799    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.577.927-5
# 12138                   INTERNET
# 12139                   INTERNET
# 12140                   INTERNET
# 12585    RECORRIDO POR EL SECTOR
# 12586                 RECONTACTO
# 12587                 RECONTACTO
# 12712                 RECONTACTO
# 12734                 RECONTACTO
# 12786                 RECONTACTO
# Name: Medio, dtype: object
# 10.579.247-6
# 9583     RECORRIDO POR EL SECTOR
# 9584     RECORRIDO POR EL SECTOR
# 9756                  RECONTACTO
# 9757                  RECONTACTO
# 11259                 RECONTACTO
# 11260                 RECONTACTO
# 11261                 RECONTACTO
# Name: Medio, dtype: object
# 10.583.279-6
# 2749     INTERNET
# 15390    INTERNET
# Name: Medio, dtype: object
# 10.586.326-8
# 14717    RECORRIDO POR EL SECTOR
# 14718    RECORRIDO POR EL SECTOR
# 14719    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.588.792-2
# 12030    RECONTACTO
# 12031    RECONTACTO
# Name: Medio, dtype: object
# 10.589.623-9
# 3893    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.592.132-2
# 12969    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.592.310-4
# 3679                      FINCO
# 3710                      FINCO
# 5081    RECORRIDO POR EL SECTOR
# 5082    RECORRIDO POR EL SECTOR
# 5195                      FINCO
# 5204                 RECONTACTO
# 5224                 RECONTACTO
# 5537                 RECONTACTO
# Name: Medio, dtype: object
# 10.598.648-3
# 16169    FINCO
# Name: Medio, dtype: object
# 10.603.708-6
# 4739    INTERNET
# Name: Medio, dtype: object
# 10.607.848-3
# 489    REFERIDOS
# 490    REFERIDOS
# 491    REFERIDOS
# 492    REFERIDOS
# Name: Medio, dtype: object
# 10.611.322-k
# 7842    INTERNET
# 8342       FINCO
# Name: Medio, dtype: object
# 10.612.657-7
# 12888    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.614.582-2
# 15267    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.615.011-7
# 3519         FINCO
# 3521         FINCO
# 3594         FINCO
# 3634         FINCO
# 3637    RECONTACTO
# 3723         FINCO
# 3726    RECONTACTO
# Name: Medio, dtype: object
# 10.619.053-4
# 16571    RECORRIDO POR EL SECTOR
# 16572    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.620.860-3
# 14892    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.623.668-2
# 3288    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.623.814-6
# 3412    RECONTACTO
# 3438    RECONTACTO
# 6023      LETREROS
# 6024      LETREROS
# 6025    RECONTACTO
# 6030    RECONTACTO
# 6031    RECONTACTO
# 6114    RECONTACTO
# Name: Medio, dtype: object
# 10.625.289-0
# 3759    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.627.157-7
# 11603      INTERNET
# 11604      INTERNET
# 11779    RECONTACTO
# 11780    RECONTACTO
# 11781    RECONTACTO
# 11782    RECONTACTO
# Name: Medio, dtype: object
# 10.628.804-6
# 14493    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.628.904-2
# 13230    FINCO
# Name: Medio, dtype: object
# 10.631.960-k
# 5574    INTERNET
# 8064    INTERNET
# Name: Medio, dtype: object
# 10.631.973-1
# 271    INTERNET
# Name: Medio, dtype: object
# 10.636.520-2
# 3638    FINCO
# 3752    FINCO
# Name: Medio, dtype: object
# 10.636.583-0
# 15791    INTERNET
# 15792    INTERNET
# Name: Medio, dtype: object
# 10.637.991-2
# 8090    RECORRIDO POR EL SECTOR
# 8091    RECORRIDO POR EL SECTOR
# 8621                 RECONTACTO
# 8622                 RECONTACTO
# Name: Medio, dtype: object
# 10.637.993-9
# 12371      INTERNET
# 12372      INTERNET
# 12373      INTERNET
# 12460    RECONTACTO
# 12578    RECONTACTO
# Name: Medio, dtype: object
# 10.645.374-8
# 1621    INTERNET
# Name: Medio, dtype: object
# 10.651.490-9
# 6943    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.651.716-9
# 7212    RECONTACTO
# Name: Medio, dtype: object
# 10.651.904-8
# 1344    RECORRIDO POR EL SECTOR
# 1355                 RECONTACTO
# Name: Medio, dtype: object
# 10.653.297-4
# 15511    INTERNET
# 15512    INTERNET
# Name: Medio, dtype: object
# 10.654.107-8
# 8205    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.656.826-k
# 3138    INTERNET
# 3166       RADIO
# Name: Medio, dtype: object
# 10.657.084-1
# 16219    FINCO
# 16220    FINCO
# Name: Medio, dtype: object
# 10.658.228-6
# 890    INTERNET
# 891    INTERNET
# 892    INTERNET
# Name: Medio, dtype: object
# 10.658.682-9
# 3231    INTERNET
# Name: Medio, dtype: object
# 10.659.272-1
# 7665    RECONTACTO
# 7666    RECONTACTO
# 7667    RECONTACTO
# Name: Medio, dtype: object
# 10.662.350-3
# 14498    RECORRIDO POR EL SECTOR
# 14499    RECORRIDO POR EL SECTOR
# 14642                 RECONTACTO
# 14643                 RECONTACTO
# 14644                 RECONTACTO
# 14645                 RECONTACTO
# 14722                  REFERIDOS
# 14751                 RECONTACTO
# Name: Medio, dtype: object
# 10.664.273-7
# 16300    FINCO
# Name: Medio, dtype: object
# 10.664.658-9
# 1911    INTERNET
# Name: Medio, dtype: object
# 10.665.303-8
# 1200    INTERNET
# 1201    INTERNET
# Name: Medio, dtype: object
# 10.665.970-2
# 9153    RECORRIDO POR EL SECTOR
# 9154    RECORRIDO POR EL SECTOR
# 9155    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.666.541-9
# 1872    RECORRIDO POR EL SECTOR
# 1873    RECORRIDO POR EL SECTOR
# 1875    RECORRIDO POR EL SECTOR
# 1876    RECORRIDO POR EL SECTOR
# 1877    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.672.111-4
# 594    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.673.784-3
# 1092    INTERNET
# Name: Medio, dtype: object
# 10.674.056-9
# 4791    REFERIDOS
# 4792    REFERIDOS
# 4793    REFERIDOS
# 4794    REFERIDOS
# 4795    REFERIDOS
# Name: Medio, dtype: object
# 10.674.993-0
# 15619    RECORRIDO POR EL SECTOR
# 15620    RECORRIDO POR EL SECTOR
# 15621    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.675.549-3
# 16101    FINCO
# 16103    FINCO
# 16473    FINCO
# Name: Medio, dtype: object
# 10.675.554-k
# 16543    FINCO
# Name: Medio, dtype: object
# 10.676.438-7
# 3402    LETREROS
# Name: Medio, dtype: object
# 10.676.443-3
# 4689    RECORRIDO POR EL SECTOR
# 4712                 RECONTACTO
# 4767                 RECONTACTO
# Name: Medio, dtype: object
# 10.676.741-6
# 5003    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.678.010-2
# 2648    RECORRIDO POR EL SECTOR
# 2649    RECORRIDO POR EL SECTOR
# 2650    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.678.288-1
# 910    RECORRIDO POR EL SECTOR
# 911    RECORRIDO POR EL SECTOR
# 912    RECORRIDO POR EL SECTOR
# 913    RECORRIDO POR EL SECTOR
# 914                   INTERNET
# Name: Medio, dtype: object
# 10.679.069-8
# 3999    LETREROS
# 4000    LETREROS
# Name: Medio, dtype: object
# 10.681.174-1
# 15170    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.681.675-1
# 4185    INTERNET
# Name: Medio, dtype: object
# 10.681.800-2
# 16314    FINCO
# Name: Medio, dtype: object
# 10.683.916-6
# 13237    FINCO
# Name: Medio, dtype: object
# 10.686.068-8
# 13352    FINCO
# Name: Medio, dtype: object
# 10.686.102-1
# 6446    RECORRIDO POR EL SECTOR
# 6548    RECORRIDO POR EL SECTOR
# 6555                 RECONTACTO
# 6592    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.686.979-0
# 5059      INTERNET
# 5060      INTERNET
# 5061      INTERNET
# 5062      INTERNET
# 5088    RECONTACTO
# 7652    RECONTACTO
# Name: Medio, dtype: object
# 10.688.452-8
# 8946    RECORRIDO POR EL SECTOR
# 8947    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.691.607-1
# 13566    INTERNET
# 16361       FINCO
# Name: Medio, dtype: object
# 10.699.889-2
# 13423    RECORRIDO POR EL SECTOR
# 13424    RECORRIDO POR EL SECTOR
# 13425    RECORRIDO POR EL SECTOR
# 13433                 RECONTACTO
# 13445                 RECONTACTO
# 13463                 RECONTACTO
# Name: Medio, dtype: object
# 10.699.946-5
# 3692    REFERIDOS
# Name: Medio, dtype: object
# 10.700.620-6
# 8793    RECORRIDO POR EL SECTOR
# 8794    RECORRIDO POR EL SECTOR
# 8795    RECORRIDO POR EL SECTOR
# 8796    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.701.799-2
# 2434    INTERNET
# Name: Medio, dtype: object
# 10.703.450-1
# 15373    INTERNET
# Name: Medio, dtype: object
# 10.708.748-6
# 3539    FINCO
# Name: Medio, dtype: object
# 10.711.924-8
# 7433    RECONTACTO
# 7434    RECONTACTO
# Name: Medio, dtype: object
# 10.713.713-0
# 15083      INTERNET
# 15312    RECONTACTO
# 15358      INTERNET
# Name: Medio, dtype: object
# 10.718.067-2
# 8712    RECORRIDO POR EL SECTOR
# 8713    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.719.125-9
# 7511    RECORRIDO POR EL SECTOR
# 7512    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.720.953-0
# 12602    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.721.575-1
# 4016    INTERNET
# Name: Medio, dtype: object
# 10.721.679-0
# 4387    INTERNET
# Name: Medio, dtype: object
# 10.725.505-2
# 16259    FINCO
# Name: Medio, dtype: object
# 10.727.505-3
# 5439    INTERNET
# Name: Medio, dtype: object
# 10.728.961-5
# 1385     RECORRIDO POR EL SECTOR
# 2370                  RECONTACTO
# 15141                 RECONTACTO
# Name: Medio, dtype: object
# 10.729.632-8
# 14003    RECORRIDO POR EL SECTOR
# 14004    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.731.863-1
# 16104    FINCO
# 16289    FINCO
# Name: Medio, dtype: object
# 10.732.435-6
# 12253    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.733.896-9
# 5471                   INTERNET
# 5472                   INTERNET
# 5473                   INTERNET
# 5950                 RECONTACTO
# 5973    RECORRIDO POR EL SECTOR
# 5974    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.734.707-0
# 455    FINCO
# 456    FINCO
# Name: Medio, dtype: object
# 10.736.871-k
# 6879    RECONTACTO
# 6880    RECONTACTO
# 6881    RECONTACTO
# Name: Medio, dtype: object
# 10.741.773-7
# 3216    LETREROS
# Name: Medio, dtype: object
# 10.741.829-6
# 3498    INTERNET
# 3499    INTERNET
# Name: Medio, dtype: object
# 10.746.753-K
# 12269    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.747.102-2
# 14269    RECORRIDO POR EL SECTOR
# 14384                 RECONTACTO
# 14393                 RECONTACTO
# Name: Medio, dtype: object
# 10.748.815-4
# 10598    RECONTACTO
# 10600      LETREROS
# 11493    RECONTACTO
# 11494    RECONTACTO
# 11591    RECONTACTO
# Name: Medio, dtype: object
# 10.748.932-0
# 12361    REFERIDOS
# Name: Medio, dtype: object
# 10.748.933-9
# 11719    RECORRIDO POR EL SECTOR
# 11720    RECORRIDO POR EL SECTOR
# 12362                 RECONTACTO
# 12363                 RECONTACTO
# Name: Medio, dtype: object
# 10.750.318-8
# 3781         FINCO
# 3782    RECONTACTO
# 3783    RECONTACTO
# 3784         FINCO
# Name: Medio, dtype: object
# 10.751.939-4
# 7672    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.754.287-6
# 1375    RECORRIDO POR EL SECTOR
# 1376    RECORRIDO POR EL SECTOR
# 1377    RECORRIDO POR EL SECTOR
# 1668    RECORRIDO POR EL SECTOR
# 4857    RECORRIDO POR EL SECTOR
# 4867                 RECONTACTO
# Name: Medio, dtype: object
# 10.758.920-1
# 9559      INTERNET
# 9560      INTERNET
# 9571    RECONTACTO
# 9572    RECONTACTO
# Name: Medio, dtype: object
# 10.765.295-7
# 5570    INTERNET
# Name: Medio, dtype: object
# 10.770.093-5
# 1329    RECONTACTO
# 1338    RECONTACTO
# 1892    RECONTACTO
# 2452    RECONTACTO
# 2453    RECONTACTO
# Name: Medio, dtype: object
# 10.771.433-2
# 4823    RECORRIDO POR EL SECTOR
# 4824    RECORRIDO POR EL SECTOR
# 4825    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.772.385-4
# 16114    FINCO
# 16555    FINCO
# Name: Medio, dtype: object
# 10.772.644-6
# 15182    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.775.855-0
# 1192    RECONTACTO
# 1193    RECONTACTO
# 1194    RECONTACTO
# 1195    RECONTACTO
# Name: Medio, dtype: object
# 10.779.249-k
# 3180      INTERNET
# 3264    RECONTACTO
# Name: Medio, dtype: object
# 10.780.375-0
# 6157       INTERNET
# 10035    RECONTACTO
# 10036    RECONTACTO
# 10037    RECONTACTO
# 10038    RECONTACTO
# 12941    RECONTACTO
# 12942    RECONTACTO
# Name: Medio, dtype: object
# 10.780.738-1
# 11576    INTERNET
# 11584    INTERNET
# 11585    INTERNET
# Name: Medio, dtype: object
# 10.780.739-k
# 4332    LETREROS
# Name: Medio, dtype: object
# 10.784.972-6
# 88      RECORRIDO POR EL SECTOR
# 89      RECORRIDO POR EL SECTOR
# 364     RECORRIDO POR EL SECTOR
# 9910    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.788.689-3
# 6123    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.789.924-3
# 15973    INTERNET
# 15980    INTERNET
# Name: Medio, dtype: object
# 10.790.094-2
# 15159    INTERNET
# 15160    INTERNET
# 15161    INTERNET
# 15162    INTERNET
# Name: Medio, dtype: object
# 10.790.940-0
# 5213    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.791.004-2
# 5829         FINCO
# 5830         FINCO
# 7907    RECONTACTO
# 7908    RECONTACTO
# 7909    RECONTACTO
# 8015    RECONTACTO
# 8028    RECONTACTO
# 8047    RECONTACTO
# Name: Medio, dtype: object
# 10.792.684-4
# 13562    RECORRIDO POR EL SECTOR
# 13563    RECORRIDO POR EL SECTOR
# 13605                 RECONTACTO
# Name: Medio, dtype: object
# 10.798.800-9
# 13708    RECORRIDO POR EL SECTOR
# 13709    RECORRIDO POR EL SECTOR
# 13710    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.801.125-4
# 4141    RECORRIDO POR EL SECTOR
# 4142    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.801.522-5
# 114     RECORRIDO POR EL SECTOR
# 115     RECORRIDO POR EL SECTOR
# 2793    RECORRIDO POR EL SECTOR
# 2794    RECORRIDO POR EL SECTOR
# 2795    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.802.123-3
# 7096    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.802.765-7
# 1454    INTERNET
# 2843    INTERNET
# 2844    INTERNET
# 2845    INTERNET
# 2846    INTERNET
# Name: Medio, dtype: object
# 10.806.380-7
# 6627    RECORRIDO POR EL SECTOR
# 6628    RECORRIDO POR EL SECTOR
# 6629    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.811.126-7
# 15763    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.816.944-3
# 13688    RECONTACTO
# 13689    RECONTACTO
# 13712    RECONTACTO
# 13713    RECONTACTO
# Name: Medio, dtype: object
# 10.817.813-2
# 12542    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.818.179-6
# 11194    INTERNET
# Name: Medio, dtype: object
# 10.820.870-8
# 16440    INTERNET
# Name: Medio, dtype: object
# 10.824.498-4
# 4422                    INTERNET
# 4423                    INTERNET
# 8956     RECORRIDO POR EL SECTOR
# 8957     RECORRIDO POR EL SECTOR
# 8958     RECORRIDO POR EL SECTOR
# 8959     RECORRIDO POR EL SECTOR
# 11471                 RECONTACTO
# Name: Medio, dtype: object
# 10.840.446-9
# 16534    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.841.335-2
# 14128                   INTERNET
# 15061    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.841.693-9
# 8748    INTERNET
# 8752    INTERNET
# 8753    INTERNET
# Name: Medio, dtype: object
# 10.842.123-1
# 7125    INTERNET
# Name: Medio, dtype: object
# 10.842.139-8
# 9056    RECORRIDO POR EL SECTOR
# 9057    RECORRIDO POR EL SECTOR
# 9058    RECORRIDO POR EL SECTOR
# 9062    RECORRIDO POR EL SECTOR
# 9072    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.842.892-9
# 2348                   INTERNET
# 2349                   INTERNET
# 2358    RECORRIDO POR EL SECTOR
# 2359    RECORRIDO POR EL SECTOR
# 2360    RECORRIDO POR EL SECTOR
# 2361    RECORRIDO POR EL SECTOR
# 2368                   INTERNET
# 2396    RECORRIDO POR EL SECTOR
# 2397    RECORRIDO POR EL SECTOR
# 2430    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.843.003-6
# 9303    RECORRIDO POR EL SECTOR
# 9304    RECORRIDO POR EL SECTOR
# 9305    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.845.422-9
# 10321    RECONTACTO
# Name: Medio, dtype: object
# 10.850.859-0
# 11922      INTERNET
# 11923      INTERNET
# 12238    RECONTACTO
# Name: Medio, dtype: object
# 10.852.905-9
# 14460    RECONTACTO
# 14461    RECONTACTO
# 14462    RECONTACTO
# Name: Medio, dtype: object
# 10.858.552-8
# 4284          FINCO
# 4285          FINCO
# 10529         FINCO
# 10530         FINCO
# 10713         FINCO
# 10714         FINCO
# 10793    RECONTACTO
# 10876         FINCO
# 11670    RECONTACTO
# 11672    RECONTACTO
# 12014    RECONTACTO
# 12203    RECONTACTO
# Name: Medio, dtype: object
# 10.861.165-0
# 9846    RECORRIDO POR EL SECTOR
# 9847    RECORRIDO POR EL SECTOR
# 9848    RECORRIDO POR EL SECTOR
# 9849    RECORRIDO POR EL SECTOR
# 9850    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.862.627-5
# 1190    RECORRIDO POR EL SECTOR
# 1191    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.863.583-5
# 3983    RECONTACTO
# Name: Medio, dtype: object
# 10.864.058-8
# 1247    RECORRIDO POR EL SECTOR
# 3033    RECORRIDO POR EL SECTOR
# 3034    RECORRIDO POR EL SECTOR
# 3035    RECORRIDO POR EL SECTOR
# 3036    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.866.547-5
# 2470    RECORRIDO POR EL SECTOR
# 2471    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.867.475-k
# 12173    RECORRIDO POR EL SECTOR
# 12174    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.867.539-k
# 5111    LETREROS
# 5112    LETREROS
# Name: Medio, dtype: object
# 10.868.070-9
# 1153    INTERNET
# 1154    INTERNET
# Name: Medio, dtype: object
# 10.869.847-0
# 8943    RECORRIDO POR EL SECTOR
# 8944    RECORRIDO POR EL SECTOR
# 8945    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.869.979-5
# 1886                   INTERNET
# 1887                   INTERNET
# 1888                   INTERNET
# 1908    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.869.981-7
# 3250    INTERNET
# Name: Medio, dtype: object
# 10.872.319-k
# 5782     RECORRIDO POR EL SECTOR
# 5783     RECORRIDO POR EL SECTOR
# 5785     RECORRIDO POR EL SECTOR
# 5786     RECORRIDO POR EL SECTOR
# 14850    RECORRIDO POR EL SECTOR
# 14851    RECORRIDO POR EL SECTOR
# 14852    RECORRIDO POR EL SECTOR
# 14853    RECORRIDO POR EL SECTOR
# 14854    RECORRIDO POR EL SECTOR
# 14855    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.877.439-8
# 11028    RECORRIDO POR EL SECTOR
# 11029    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.877.862-8
# 44                      EVENTOS
# 7651    RECORRIDO POR EL SECTOR
# 7800                   LETREROS
# 7801                   LETREROS
# 9681                 RECONTACTO
# Name: Medio, dtype: object
# 10.878.432-6
# 1895    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.879.781-9
# 15492    INTERNET
# 15493    INTERNET
# Name: Medio, dtype: object
# 10.882.925-7
# 14934    REFERIDOS
# 14935    REFERIDOS
# 14936    REFERIDOS
# Name: Medio, dtype: object
# 10.883.911-2
# 4623    INTERNET
# Name: Medio, dtype: object
# 10.884.073-0
# 5491    INTERNET
# Name: Medio, dtype: object
# 10.887.535-6
# 12142    INTERNET
# Name: Medio, dtype: object
# 10.892.063-7
# 15906    INTERNET
# 15907    INTERNET
# 15908    INTERNET
# 15909    INTERNET
# 15910    INTERNET
# Name: Medio, dtype: object
# 10.893.868-4
# 4859    RECORRIDO POR EL SECTOR
# 4860    RECORRIDO POR EL SECTOR
# 5324                 RECONTACTO
# 5325                 RECONTACTO
# 5326                 RECONTACTO
# Name: Medio, dtype: object
# 10.894.352-1
# 14110    RECORRIDO POR EL SECTOR
# 14115                  REFERIDOS
# 14116                  REFERIDOS
# Name: Medio, dtype: object
# 10.899.949-7
# 13523    FINCO
# Name: Medio, dtype: object
# 10.901.653-5
# 15805    RECORRIDO POR EL SECTOR
# 15806    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.906.135-2
# 10612    INTERNET
# Name: Medio, dtype: object
# 10.911.826-5
# 7746    RECONTACTO
# Name: Medio, dtype: object
# 10.916.065-2
# 8535    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.918.515-9
# 5898                   INTERNET
# 5899    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.921.352-7
# 9502    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.923.772-8
# 119    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.924.000-1
# 8458    FINCO
# Name: Medio, dtype: object
# 10.924.968-8
# 1456    INTERNET
# 9173    INTERNET
# 9188    INTERNET
# 9189    INTERNET
# 9190    INTERNET
# 9191    INTERNET
# 9192    INTERNET
# 9193    INTERNET
# Name: Medio, dtype: object
# 10.931.624-5
# 1270    RECONTACTO
# 1271      INTERNET
# 1272      INTERNET
# Name: Medio, dtype: object
# 10.931.772-1
# 150      RECORRIDO POR EL SECTOR
# 3122     RECORRIDO POR EL SECTOR
# 3193                  RECONTACTO
# 7959                  RECONTACTO
# 7965     RECORRIDO POR EL SECTOR
# 10672                 RECONTACTO
# Name: Medio, dtype: object
# 10.931.921-k
# 3248    LETREROS
# Name: Medio, dtype: object
# 10.932.083-8
# 298    RECONTACTO
# Name: Medio, dtype: object
# 10.932.782-4
# 8526    RECORRIDO POR EL SECTOR
# 8527    RECORRIDO POR EL SECTOR
# 8528    RECORRIDO POR EL SECTOR
# 8529    RECORRIDO POR EL SECTOR
# 8565    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.935.358-2
# 14114    RECONTACTO
# Name: Medio, dtype: object
# 10.936.707-9
# 3241    INTERNET
# 3242    INTERNET
# 3243    INTERNET
# Name: Medio, dtype: object
# 10.938.353-8
# 15902    EVENTOS
# 15903    EVENTOS
# Name: Medio, dtype: object
# 10.939.389-4
# 3282                   REFERIDOS
# 6496                  RECONTACTO
# 9906     RECORRIDO POR EL SECTOR
# 16459    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.940.668-6
# 13135    RECONTACTO
# Name: Medio, dtype: object
# 10.942.177-4
# 3256    INTERNET
# Name: Medio, dtype: object
# 10.949.080-6
# 4102    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.956.493-1
# 6942    INTERNET
# Name: Medio, dtype: object
# 10.964.075-1
# 941       FINCO
# 942    INTERNET
# 943    INTERNET
# Name: Medio, dtype: object
# 10.964.274-6
# 3235    LETREROS
# 3236    LETREROS
# 3237    LETREROS
# 3238    LETREROS
# Name: Medio, dtype: object
# 10.964.685-7
# 7073    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.967.798-1
# 16363    INTERNET
# Name: Medio, dtype: object
# 10.972.232-4
# 4869                    INTERNET
# 4955                       FINCO
# 5079                       RADIO
# 5206                    LETREROS
# 5211                       FINCO
# 5212                       FINCO
# 7030                  RECONTACTO
# 7213                  RECONTACTO
# 7353                  RECONTACTO
# 7363                  RECONTACTO
# 7633                  RECONTACTO
# 7634                  RECONTACTO
# 8686                  RECONTACTO
# 8687                  RECONTACTO
# 8688                  RECONTACTO
# 8689                  RECONTACTO
# 8690                  RECONTACTO
# 9301                  RECONTACTO
# 9302                  RECONTACTO
# 9353                  RECONTACTO
# 9354                  RECONTACTO
# 9355                  RECONTACTO
# 9356                  RECONTACTO
# 9357                  RECONTACTO
# 9358                  RECONTACTO
# 9416                  RECONTACTO
# 9417                  RECONTACTO
# 9419                  RECONTACTO
# 9447                  RECONTACTO
# 9448                  RECONTACTO
# 9496                       RADIO
# 9589                  RECONTACTO
# 9709                  RECONTACTO
# 9889     RECORRIDO POR EL SECTOR
# 9890     RECORRIDO POR EL SECTOR
# 9891     RECORRIDO POR EL SECTOR
# 9892     RECORRIDO POR EL SECTOR
# 9893     RECORRIDO POR EL SECTOR
# 9894     RECORRIDO POR EL SECTOR
# 10025                 RECONTACTO
# 10068                 RECONTACTO
# 10732                 RECONTACTO
# 11087                   LETREROS
# 11088                   LETREROS
# 11702                    EVENTOS
# Name: Medio, dtype: object
# 10.973.168-4
# 11918      LETREROS
# 11919      LETREROS
# 11920      LETREROS
# 11921      LETREROS
# 11948    RECONTACTO
# 11997    RECONTACTO
# Name: Medio, dtype: object
# 10.973.879-4
# 4501                 RECONTACTO
# 4502                 RECONTACTO
# 4551    RECORRIDO POR EL SECTOR
# 4552    RECORRIDO POR EL SECTOR
# 4923                 RECONTACTO
# 5789                      FINCO
# 5896                 RECONTACTO
# 5961                 RECONTACTO
# 5988                 RECONTACTO
# 6737                 RECONTACTO
# Name: Medio, dtype: object
# 10.974.169-8
# 14225    INTERNET
# 14806    INTERNET
# Name: Medio, dtype: object
# 10.974.813-7
# 3661    FINCO
# Name: Medio, dtype: object
# 10.975.267-3
# 6279    RECONTACTO
# 6280    RECONTACTO
# Name: Medio, dtype: object
# 10.976.037-4
# 13220    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.977.373-5
# 15007    INTERNET
# Name: Medio, dtype: object
# 10.980.589-0
# 14538    RECORRIDO POR EL SECTOR
# 15455                   INTERNET
# Name: Medio, dtype: object
# 10.981.269-2
# 2014    RECORRIDO POR EL SECTOR
# 2017    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.985.049-7
# 5407    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.991.519-k
# 15538    INTERNET
# Name: Medio, dtype: object
# 10.992.129-7
# 6440    RECORRIDO POR EL SECTOR
# 6441    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.992.425-3
# 1971     INTERNET
# 5987     INTERNET
# 10933    INTERNET
# Name: Medio, dtype: object
# 10.993.225-6
# 13619    INTERNET
# Name: Medio, dtype: object
# 10.994.400-9
# 10667                   LETREROS
# 10668                   LETREROS
# 10719    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 10.994.496-3
# 10011    RECORRIDO POR EL SECTOR
# ...
# 9.461.002-8
# 7946    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.461.907-6
# 8716    INTERNET
# 8717    INTERNET
# 8718    INTERNET
# 8719    INTERNET
# Name: Medio, dtype: object
# 9.464.657-K
# 13474    FINCO
# Name: Medio, dtype: object
# 9.468.300-9
# 3374    LETREROS
# 6336    INTERNET
# 6337    INTERNET
# Name: Medio, dtype: object
# 9.479.401-3
# 11844    INTERNET
# 14117    INTERNET
# 14118    INTERNET
# 14119    INTERNET
# 14120    INTERNET
# 14121    INTERNET
# 14123    INTERNET
# 14125    INTERNET
# 14126    INTERNET
# Name: Medio, dtype: object
# 9.487.622-2
# 3795    RECONTACTO
# 4427    RECONTACTO
# Name: Medio, dtype: object
# 9.503.888-3
# 11114    RECONTACTO
# 11115    RECONTACTO
# 11116    RECONTACTO
# Name: Medio, dtype: object
# 9.505.032-8
# 12202    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.507.823-0
# 12484    RECORRIDO POR EL SECTOR
# 12485    RECORRIDO POR EL SECTOR
# 12486                 RECONTACTO
# 12487                 RECONTACTO
# Name: Medio, dtype: object
# 9.512.862-9
# 2828    RECONTACTO
# Name: Medio, dtype: object
# 9.513.285-5
# 807    RECORRIDO POR EL SECTOR
# 808    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.515.703-3
# 3810    RECONTACTO
# Name: Medio, dtype: object
# 9.516.332-7
# 6331    RECONTACTO
# Name: Medio, dtype: object
# 9.516.689-k
# 4972    INTERNET
# 4973    INTERNET
# 5007    INTERNET
# Name: Medio, dtype: object
# 9.528.647-k
# 14152    RECORRIDO POR EL SECTOR
# 14153    RECORRIDO POR EL SECTOR
# 14154    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.529.343-3
# 16028    RECONTACTO
# 16029    RECONTACTO
# 16033    RECONTACTO
# 16034    RECONTACTO
# Name: Medio, dtype: object
# 9.535.870-5
# 2981    REFERIDOS
# 2982    REFERIDOS
# Name: Medio, dtype: object
# 9.542.047-8
# 4549    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.544.315-k
# 7445    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.544.738-4
# 8909    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.545.276-0
# 6037    RECORRIDO POR EL SECTOR
# 6038    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.557.754-7
# 5953    INTERNET
# 5954    INTERNET
# Name: Medio, dtype: object
# 9.560.501-k
# 646                  REFERIDOS
# 647                  REFERIDOS
# 648                  REFERIDOS
# 649                  REFERIDOS
# 650                 RECONTACTO
# 651                 RECONTACTO
# 652                 RECONTACTO
# 653                 RECONTACTO
# 654                 RECONTACTO
# 655                 RECONTACTO
# 656                 RECONTACTO
# 657                   INTERNET
# 658                   INTERNET
# 659                   INTERNET
# 660                   INTERNET
# 661                 RECONTACTO
# 662                 RECONTACTO
# 663                 RECONTACTO
# 664    RECORRIDO POR EL SECTOR
# 665                 RECONTACTO
# Name: Medio, dtype: object
# 9.561.561-9
# 8629    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.562.059-0
# 8731    RECORRIDO POR EL SECTOR
# 8732    RECORRIDO POR EL SECTOR
# 8733    RECORRIDO POR EL SECTOR
# 8734    RECORRIDO POR EL SECTOR
# 8735    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.562.214-3
# 6013         FINCO
# 6014         FINCO
# 6045      INTERNET
# 6060    RECONTACTO
# 6062    RECONTACTO
# 6073      INTERNET
# 6074      INTERNET
# 6112    RECONTACTO
# Name: Medio, dtype: object
# 9.571.973-2
# 9586    RECONTACTO
# Name: Medio, dtype: object
# 9.593.988-0
# 15650      INTERNET
# 15653    RECONTACTO
# 15654      INTERNET
# 15655      INTERNET
# 15988      INTERNET
# Name: Medio, dtype: object
# 9.594.006-4
# 16075    FINCO
# 16247    FINCO
# Name: Medio, dtype: object
# 9.612.253-5
# 6183    RECONTACTO
# Name: Medio, dtype: object
# 9.622.103-7
# 1831    INTERNET
# Name: Medio, dtype: object
# 9.623.393-0
# 16370    INTERNET
# 16387    INTERNET
# Name: Medio, dtype: object
# 9.634.657-3
# 10846    INTERNET
# Name: Medio, dtype: object
# 9.640.073-k
# 15019    INTERNET
# 15020    INTERNET
# Name: Medio, dtype: object
# 9.643.901-6
# 3662        FINCO
# 12285    INTERNET
# Name: Medio, dtype: object
# 9.645.837-1
# 3182    INTERNET
# Name: Medio, dtype: object
# 9.646.985-3
# 11723    RECORRIDO POR EL SECTOR
# 11724    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.652.524-9
# 6358     RECONTACTO
# 9609     RECONTACTO
# 9612     RECONTACTO
# 9691     RECONTACTO
# 9692     RECONTACTO
# 9693     RECONTACTO
# 9694     RECONTACTO
# 9695     RECONTACTO
# 9696     RECONTACTO
# 11097    RECONTACTO
# Name: Medio, dtype: object
# 9.652.858-2
# 12940    REFERIDOS
# Name: Medio, dtype: object
# 9.656.026-5
# 9369    RECORRIDO POR EL SECTOR
# 9385    RECORRIDO POR EL SECTOR
# 9392    RECORRIDO POR EL SECTOR
# 9399    RECORRIDO POR EL SECTOR
# 9400                 RECONTACTO
# 9401                 RECONTACTO
# 9611                 RECONTACTO
# Name: Medio, dtype: object
# 9.658.489-k
# 6448    RECORRIDO POR EL SECTOR
# 6449    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.659.432-1
# 14345    INTERNET
# Name: Medio, dtype: object
# 9.672.355-5
# 3901      INTERNET
# 3903      INTERNET
# 3904      INTERNET
# 4736    RECONTACTO
# 5020    RECONTACTO
# 5021    RECONTACTO
# 5022    RECONTACTO
# 5023    RECONTACTO
# 5083    RECONTACTO
# Name: Medio, dtype: object
# 9.673.910-9
# 3776    INTERNET
# 3777    INTERNET
# Name: Medio, dtype: object
# 9.677.871-6
# 1560    RECORRIDO POR EL SECTOR
# 1561    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.683.936-7
# 2272    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.693.039-9
# 679    RECONTACTO
# 680    RECONTACTO
# 681    RECONTACTO
# Name: Medio, dtype: object
# 9.694.297-4
# 15599    RECORRIDO POR EL SECTOR
# 15600    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.698.521-5
# 1122    RECORRIDO POR EL SECTOR
# 1123    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.705.991-8
# 14231    INTERNET
# 14232    INTERNET
# 14233    INTERNET
# Name: Medio, dtype: object
# 9.706.979-4
# 2163    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.718.429-1
# 3900    INTERNET
# Name: Medio, dtype: object
# 9.723.863-4
# 7404    RECONTACTO
# 7417     REFERIDOS
# 7418     REFERIDOS
# Name: Medio, dtype: object
# 9.724.003-5
# 3490    REFERIDOS
# 3491    REFERIDOS
# 3492    REFERIDOS
# Name: Medio, dtype: object
# 9.724.302-6
# 15461    INTERNET
# Name: Medio, dtype: object
# 9.725.751-5
# 1173    LETREROS
# Name: Medio, dtype: object
# 9.727.699-4
# 2999    INTERNET
# Name: Medio, dtype: object
# 9.732.031-4
# 7479    RECONTACTO
# Name: Medio, dtype: object
# 9.732.116-7
# 3820    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.733.821-3
# 13381    FINCO
# Name: Medio, dtype: object
# 9.735.755-2
# 11611    LETREROS
# 11612    LETREROS
# 11613    LETREROS
# 11614    LETREROS
# Name: Medio, dtype: object
# 9.737.031-1
# 7638    RECORRIDO POR EL SECTOR
# 7639    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.738.967-5
# 6910    RECORRIDO POR EL SECTOR
# 6911    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.747.337-4
# 6652                   INTERNET
# 6653                   INTERNET
# 6931                 RECONTACTO
# 6962                 RECONTACTO
# 7018    RECORRIDO POR EL SECTOR
# 7070                 RECONTACTO
# 7122                 RECONTACTO
# 7182                 RECONTACTO
# Name: Medio, dtype: object
# 9.747.375-7
# 11144    REFERIDOS
# 11145    REFERIDOS
# Name: Medio, dtype: object
# 9.747.510-5
# 16079    FINCO
# 16163    FINCO
# Name: Medio, dtype: object
# 9.751.590-5
# 1571    RECONTACTO
# Name: Medio, dtype: object
# 9.751.809-2
# 6783    RECONTACTO
# Name: Medio, dtype: object
# 9.753.455-1
# 3505    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.754.370-4
# 7735    LETREROS
# Name: Medio, dtype: object
# 9.758.522-9
# 4014    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.760.075-9
# 6800     RECONTACTO
# 11652      INTERNET
# Name: Medio, dtype: object
# 9.761.801-1
# 5294    RECONTACTO
# 8650    RECONTACTO
# 8651    RECONTACTO
# 8652    RECONTACTO
# Name: Medio, dtype: object
# 9.767.642-9
# 3368    RECORRIDO POR EL SECTOR
# 3369                 RECONTACTO
# Name: Medio, dtype: object
# 9.773.513-1
# 6670    LETREROS
# 6671    LETREROS
# Name: Medio, dtype: object
# 9.775.334-2
# 4565                   INTERNET
# 4566                   INTERNET
# 4567                   INTERNET
# 6551    RECORRIDO POR EL SECTOR
# 7100                 RECONTACTO
# 7101                 RECONTACTO
# Name: Medio, dtype: object
# 9.778.535-k
# 1450    RECORRIDO POR EL SECTOR
# 1451    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.786.878-6
# 16432    RECORRIDO POR EL SECTOR
# 16433    RECORRIDO POR EL SECTOR
# 16434    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.793.961-6
# 2621                 RECONTACTO
# 2622                 RECONTACTO
# 2641    RECORRIDO POR EL SECTOR
# 2642    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.799.617-2
# 6969    RECONTACTO
# 6970    RECONTACTO
# 6971    RECONTACTO
# 7962    RECONTACTO
# 7963    RECONTACTO
# 7964    RECONTACTO
# Name: Medio, dtype: object
# 9.800.449-1
# 14279    INTERNET
# Name: Medio, dtype: object
# 9.812.196-k
# 5090    RECORRIDO POR EL SECTOR
# 5091    RECORRIDO POR EL SECTOR
# 5382    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.812.269-9
# 8448    RECORRIDO POR EL SECTOR
# 8450    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.815.863-4
# 15883    EVENTOS
# Name: Medio, dtype: object
# 9.816.619-k
# 3513    INTERNET
# Name: Medio, dtype: object
# 9.816.876-1
# 2774     RECORRIDO POR EL SECTOR
# 2775     RECORRIDO POR EL SECTOR
# 2776     RECORRIDO POR EL SECTOR
# 3049     RECORRIDO POR EL SECTOR
# 15764                   INTERNET
# 15765                   INTERNET
# Name: Medio, dtype: object
# 9.817.054-5
# 1179    RECONTACTO
# 1180    RECONTACTO
# Name: Medio, dtype: object
# 9.817.982-8
# 4534                   INTERNET
# 4535                   INTERNET
# 4536                   INTERNET
# 4837    RECORRIDO POR EL SECTOR
# 4838    RECORRIDO POR EL SECTOR
# 4839    RECORRIDO POR EL SECTOR
# 4840    RECORRIDO POR EL SECTOR
# 4841    RECORRIDO POR EL SECTOR
# 4870    RECORRIDO POR EL SECTOR
# 4932                 RECONTACTO
# 4968                 RECONTACTO
# 5012                 RECONTACTO
# 5013                 RECONTACTO
# 5014                 RECONTACTO
# 5015                 RECONTACTO
# 5016                 RECONTACTO
# 5136                 RECONTACTO
# 5175                 RECONTACTO
# Name: Medio, dtype: object
# 9.818.653-0
# 4069    RECORRIDO POR EL SECTOR
# 4070    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.821.654-5
# 12658    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.821.734-7
# 14100    RECORRIDO POR EL SECTOR
# 14101    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.822.081-K
# 12760    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.822.596-K
# 15550    INTERNET
# 15551    INTERNET
# Name: Medio, dtype: object
# 9.823.223-0
# 14849    INTERNET
# Name: Medio, dtype: object
# 9.826.943-6
# 14864    RECONTACTO
# Name: Medio, dtype: object
# 9.833.269-3
# 10407    RECONTACTO
# Name: Medio, dtype: object
# 9.833.932-9
# 2577    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.834.346-6
# 8968                 RECONTACTO
# 9012    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.835.142-6
# 2968    RECORRIDO POR EL SECTOR
# 2989                      FINCO
# Name: Medio, dtype: object
# 9.838.698-k
# 10646      LETREROS
# 10720    RECONTACTO
# 10772    RECONTACTO
# Name: Medio, dtype: object
# 9.842.450-4
# 9339    RECORRIDO POR EL SECTOR
# 9379    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.842.875-5
# 12538    RECONTACTO
# 12539    RECONTACTO
# 12541    RECONTACTO
# Name: Medio, dtype: object
# 9.845.601-5
# 13682    REFERIDOS
# 13690    REFERIDOS
# 13691    REFERIDOS
# Name: Medio, dtype: object
# 9.845.678-3
# 758    RECONTACTO
# 759    RECONTACTO
# 760    RECONTACTO
# 761    RECONTACTO
# Name: Medio, dtype: object
# 9.848.973-8
# 81    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.851.808-8
# 16509    FINCO
# Name: Medio, dtype: object
# 9.853.149-1
# 7528    RECORRIDO POR EL SECTOR
# 7529    RECORRIDO POR EL SECTOR
# 7876                 RECONTACTO
# 7877                 RECONTACTO
# Name: Medio, dtype: object
# 9.863.435-5
# 6972    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.865.167-5
# 745    INTERNET
# 746    INTERNET
# Name: Medio, dtype: object
# 9.870.673-9
# 5460                  RECONTACTO
# 5461                  RECONTACTO
# 5585                  RECONTACTO
# 5598     RECORRIDO POR EL SECTOR
# 5599     RECORRIDO POR EL SECTOR
# 5657                  RECONTACTO
# 10417                 RECONTACTO
# 10418                 RECONTACTO
# Name: Medio, dtype: object
# 9.876.228-0
# 2070    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.879.501-4
# 13     RECONTACTO
# 145    RECONTACTO
# 200    RECONTACTO
# 247    RECONTACTO
# 344    RECONTACTO
# Name: Medio, dtype: object
# 9.884.025-7
# 1183    REFERIDOS
# 1184    REFERIDOS
# Name: Medio, dtype: object
# 9.884.654-9
# 11139      INTERNET
# 11140      INTERNET
# 11141      INTERNET
# 12013    RECONTACTO
# Name: Medio, dtype: object
# 9.887.258-2
# 10420                   INTERNET
# 15536                   INTERNET
# 15537                   INTERNET
# 15788    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.888.074-7
# 1416    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.890.346-1
# 6661    LETREROS
# Name: Medio, dtype: object
# 9.895.193-8
# 6121    RECORRIDO POR EL SECTOR
# 6122    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.900.432-0
# 705    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.904.294-k
# 8825    RECONTACTO
# 8826    RECONTACTO
# 8827    RECONTACTO
# 8828    RECONTACTO
# 8829    RECONTACTO
# 8830    RECONTACTO
# 8831    RECONTACTO
# 8952    RECONTACTO
# 8953    RECONTACTO
# 8954    RECONTACTO
# 8955    RECONTACTO
# 8969    RECONTACTO
# 8970    RECONTACTO
# 8971    RECONTACTO
# 8972    RECONTACTO
# 8973    RECONTACTO
# Name: Medio, dtype: object
# 9.905.437-9
# 2095    LETREROS
# 2096    LETREROS
# 2105    LETREROS
# 2106    LETREROS
# 2107    LETREROS
# 2108    LETREROS
# Name: Medio, dtype: object
# 9.909.417-6
# 15055    RECONTACTO
# 15056    RECONTACTO
# 15681      INTERNET
# 15682      INTERNET
# 15683      INTERNET
# 15688      INTERNET
# 15689      INTERNET
# Name: Medio, dtype: object
# 9.912.415-6
# 15149    RECONTACTO
# Name: Medio, dtype: object
# 9.913.367-8
# 706      INTERNET
# 707      INTERNET
# 708      INTERNET
# 709      INTERNET
# 710      INTERNET
# 711      INTERNET
# 712      INTERNET
# 713    RECONTACTO
# Name: Medio, dtype: object
# 9.913.669-3
# 384    FINCO
# 392    FINCO
# 393    FINCO
# 423    FINCO
# Name: Medio, dtype: object
# 9.933.385-5
# 10525    FINCO
# Name: Medio, dtype: object
# 9.938.835-8
# 1457                 RECONTACTO
# 1458                 RECONTACTO
# 1682    RECORRIDO POR EL SECTOR
# 1683    RECORRIDO POR EL SECTOR
# 1737                 RECONTACTO
# 1749                 RECONTACTO
# Name: Medio, dtype: object
# 9.943.170-9
# 13370    FINCO
# Name: Medio, dtype: object
# 9.943.377-9
# 3636     RECONTACTO
# 8697     RECONTACTO
# 11934    RECONTACTO
# 11935    RECONTACTO
# 11936    RECONTACTO
# Name: Medio, dtype: object
# 9.945.232-3
# 16243    FINCO
# Name: Medio, dtype: object
# 9.951.329-2
# 15568    RECORRIDO POR EL SECTOR
# 15569                   INTERNET
# Name: Medio, dtype: object
# 9.970.764-k
# 6543    RECONTACTO
# Name: Medio, dtype: object
# 9.970.766-6
# 2284    RECORRIDO POR EL SECTOR
# 2285    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.975.359-5
# 8684    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.978.207-2
# 2480    INTERNET
# 2481    INTERNET
# 2482    INTERNET
# Name: Medio, dtype: object
# 9.981.392-k
# 5562    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.982.194-9
# 1982      REFERIDOS
# 1983      REFERIDOS
# 11302      INTERNET
# 11303      INTERNET
# 11384    RECONTACTO
# 11385    RECONTACTO
# 11462    RECONTACTO
# 11704    RECONTACTO
# 11705    RECONTACTO
# 12160    RECONTACTO
# 12397    RECONTACTO
# Name: Medio, dtype: object
# 9.983.697-0
# 1845    INTERNET
# Name: Medio, dtype: object
# 9.983.814-0
# 7401    INTERNET
# Name: Medio, dtype: object
# 9.984.897-9
# 6572    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 9.985.643-2
# 3666    LETREROS
# Name: Medio, dtype: object
# 9.994.832-9
# 4211    RECORRIDO POR EL SECTOR
# 4212    RECORRIDO POR EL SECTOR
# 4213    RECORRIDO POR EL SECTOR
# 4247                   INTERNET
# Name: Medio, dtype: object
# 9.996.079-5
# 4432      LETREROS
# 4433      LETREROS
# 4434      LETREROS
# 4525    RECONTACTO
# 4526    RECONTACTO
# 4547    RECONTACTO
# 4579    RECONTACTO
# 4726    RECONTACTO
# 4727    RECONTACTO
# 4728    RECONTACTO
# 4729    RECONTACTO
# Name: Medio, dtype: object
# 9.996.125-2
# 9680    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 91.860.000-0
# 694    RECONTACTO
# 695    RECONTACTO
# Name: Medio, dtype: object
# 955.952-4
# 12216    RECORRIDO POR EL SECTOR
# Name: Medio, dtype: object
# 99.590.680-5
# 2865    RECONTACTO
# Name: Medio, dtype: object
# 0

# %%
True in [False, True]
# Out:
# True

# %% [markdown]
# ### 3.1.10.Tiempo entre Cotizaciones
# Esta variable indica el numero de veces que el cliente ha hecho cotizaciones

# %%
# Construir 'promedio_de_tiempo' entre cotizacones donde participa el mismo rut

# %%
cot_mod.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Fecha Cotizacion', 'Medio', 'Proyecto',
#        'Presencial', 'Jefe Comercial', 'Ejecutivo Comercial',
#        'Total Productos', 'Descuentos', 'Valor Final Venta', 'RUT', 'Celular',
#        'Direccion', 'Sexo', 'Estado Civil', 'Rango Edad', 'Fecha Nacimiento',
#        'Tipo Cliente', 'Giro', 'Nacionalidad', 'N° Grupo Familiar',
#        'Actividad', 'Empleador', 'Negocio', 'Clean Rut', 'Valid Rut',
#        'Format Rut', 'profesion_agg', 'edad', 'recibio_descuento', '#vivienda',
#        '#bodega', '#estacionamiento', '#estudio', '#lan', 'region',
#        'provincia', 'comuna', 'is_nombre', 'is_apellido1', 'is_apellido2',
#        'is_nombrecompleto', 'is_correo', 'is_direccion', 'is_telefono',
#        'is_actividad', 'is_estado_civil', 'is_fnac', 'is_celular',
#        'is_profesion', 'Edad Min', 'Edad Max', 'is_nrofam'],
#       dtype='object')

# %%
len(cot_mod['Clean Rut'].unique())
# Out:
# 6184

# %% [markdown]
# # 4.Integrate Data

# %%
# Construir '#cotizaciones' a partir del nro de filas donde participa el mismo rut
cot_ruts = pd.DataFrame()

nro_cot_depto, nro_cot_esta, nro_cot_estu, nro_cot_bod  = [], [], [], []

mean_cot_depto, mean_cot_esta, mean_cot_estu, mean_cot_bod = [], [], [], []

ruts, ruts_nro_cot, rut_reg, rut_prov , rut_com = [], [], [] , [], []

is_nombre, is_apellido1, is_appelido2, is_nombrecompleto, is_direccion = [], [], [], [], [] 
is_telefono, is_celular, is_fnac, is_nrofam, is_profesion = [], [], [], [], []
is_recontacto = []

primer_medio = []
rut = []

max_rango_edad, profesion = [], []

nro_proyectos = []

negocio = []

tipo_cliente = []

sexo = []


iterator = 0
for group, frame in  cot_mod.groupby('Format Rut'):
    iterator += 1
    is_nombre.append(frame['is_nombre'].tolist()[0])
    is_apellido1.append(frame['is_apellido1'].tolist()[0])
    is_appelido2.append(frame['is_apellido2'].tolist()[0])
    is_nombrecompleto.append(frame['is_nombrecompleto'].tolist()[0])
    is_direccion.append(frame['is_direccion'].tolist()[0])
    is_telefono.append(frame['is_telefono'].tolist()[0])
    is_celular.append(frame['is_celular'].tolist()[0])
    is_fnac.append(frame['is_fnac'].tolist()[0])
    is_profesion.append(frame['is_profesion'].tolist()[0])
    is_nrofam.append(frame['is_nrofam'].tolist()[0])
    
    if frame['Medio'].tolist()[-1] == 'RECONTACTO':
        is_recontacto.append(True)
    else:
        is_recontacto.append(False)
    
    primer_medio.append(frame['Medio'].tolist()[0])
    
    profesion.append(frame['profesion_agg'].tolist()[0])
    rut.append(group)
    sexo.append(frame['Sexo'].tolist()[0])
    
    tipo_cliente.append(frame['Tipo Cliente'].tolist()[0])
    
    max_rango_edad.append(frame['Edad Max'].tolist()[0])

    nro_proyectos.append(len(frame['Proyecto'].unique()))
    
    arr = frame['Negocio'].tolist()
    if True in arr:   
        negocio.append(True)
    else:
        negocio.append(False)
    
    ruts.append(group)
    rut_reg.append(frame['region'].tolist()[0])
    rut_prov.append(frame['provincia'].tolist()[0])
    rut_com.append(frame['comuna'].tolist()[0])
    
    nro_cot_depto.append(frame['#vivienda'].sum())
    nro_cot_bod.append(frame['#bodega'].sum())
    nro_cot_esta.append(frame['#estacionamiento'].sum())
    nro_cot_estu.append(frame['#estudio'].sum())
    
    mean_cot_depto.append(frame['#vivienda'].mean())
    mean_cot_bod.append(frame['#bodega'].mean())
    mean_cot_esta.append(frame['#estacionamiento'].mean())
    mean_cot_estu.append(frame['#estudio'].mean())
    ruts_nro_cot.append(frame['ID'].count())
    
print(iterator)
# Out:
# 6184

# %%
list_cols = [ruts,rut_reg,rut_prov,rut_com,nro_proyectos,nro_cot_bod, nro_cot_depto, nro_cot_esta, nro_cot_estu, mean_cot_bod,
             mean_cot_depto,mean_cot_esta,mean_cot_estu, negocio,is_nombre,
             is_apellido1,is_appelido2,is_nombrecompleto,is_direccion,is_telefono,
             is_celular,is_fnac,max_rango_edad,tipo_cliente,sexo,
             is_nrofam, is_profesion,rut, profesion, is_recontacto, primer_medio]
list_labels = ['rut','loc_region','loc_provincia','loc_comuna','nro_proyectos','nro_cot_bod', 'nro_cot_depto', 
               'nro_cot_esta', 'nro_cot_estu', 'mean_cot_bod',
               'mean_cot_depto','mean_cot_esta','mean_cot_estu','negocio',
               'is_nombre','is_apellido1','is_appelido2','is_nombrecompleto','is_direccion','is_telefono',
               'is_celular','is_fnac','max_rango_edad','tipo_cliente','sexo','is_nrofam','is_profesion','rut','profesion',
               'is_recontacto', 'medio_inicial']

zipped = list(zip(list_labels,list_cols))
data = dict(zipped)
personas = pd.DataFrame(data)
print(personas.shape)
personas.head()
# Out:
# (6184, 30)
#    is_apellido1  is_appelido2  is_celular  is_direccion  is_fnac  is_nombre  \
# 0          True          True        True         False     True       True
# 1          True          True        True         False    False       True
# 2          True          True        True         False    False       True
# 3          True          True        True          True    False       True
# 4          True          True        True         False    False       True
#
#    is_nombrecompleto  is_nrofam  is_profesion  is_recontacto     ...       \
# 0               True      False          True          False     ...
# 1               True      False         False          False     ...
# 2               True      False         False          False     ...
# 3               True       True          True           True     ...
# 4               True      False         False          False     ...
#
#    negocio nro_cot_bod nro_cot_depto nro_cot_esta  nro_cot_estu  \
# 0    False           1             2            1             0
# 1    False           0             1            1             0
# 2    False           2             2            2             2
# 3     True           2             2            2             0
# 4    False           2             2            2             0
#
#    nro_proyectos        profesion            rut       sexo tipo_cliente
# 0              2          Abogado  000.000.000-0   Femenino      Natural
# 1              1  sin informacion    1.462.558-5  Masculino      Natural
# 2              1  sin informacion   10.000.513-1  Masculino      Natural
# 3              1           Médico   10.000.522-0  Masculino      Natural
# 4              1  sin informacion   10.005.853-7        NaN      Natural
#
# [5 rows x 30 columns]

# %%
print(len(personas['rut'].unique()))
# Out:
# 6184

# %%
len(personas[personas.negocio == True])
# Out:
# 1101

# %%
personas.columns
# Out:
# Index(['is_apellido1', 'is_appelido2', 'is_celular', 'is_direccion', 'is_fnac',
#        'is_nombre', 'is_nombrecompleto', 'is_nrofam', 'is_profesion',
#        'is_recontacto', 'is_telefono', 'loc_comuna', 'loc_provincia',
#        'loc_region', 'max_rango_edad', 'mean_cot_bod', 'mean_cot_depto',
#        'mean_cot_esta', 'mean_cot_estu', 'medio_inicial', 'negocio',
#        'nro_cot_bod', 'nro_cot_depto', 'nro_cot_esta', 'nro_cot_estu',
#        'nro_proyectos', 'profesion', 'rut', 'sexo', 'tipo_cliente'],
#       dtype='object')

# %%
personas = pd.merge(personas, rut_proyectos, how = 'inner', left_on='rut', right_on='index')
personas = personas.drop(['index'],axis=1)

# %%
print(len(personas['rut'].unique()))
# Out:
# 6184

# %%
personas.columns
# Out:
# Index(['is_apellido1', 'is_appelido2', 'is_celular', 'is_direccion', 'is_fnac',
#        'is_nombre', 'is_nombrecompleto', 'is_nrofam', 'is_profesion',
#        'is_recontacto', 'is_telefono', 'loc_comuna', 'loc_provincia',
#        'loc_region', 'max_rango_edad', 'mean_cot_bod', 'mean_cot_depto',
#        'mean_cot_esta', 'mean_cot_estu', 'medio_inicial', 'negocio',
#        'nro_cot_bod', 'nro_cot_depto', 'nro_cot_esta', 'nro_cot_estu',
#        'nro_proyectos', 'profesion', 'rut', 'sexo', 'tipo_cliente',
#        'Altos del Valle', 'Edificio Urban 1470', 'San Andres Del Valle',
#        'Edificio Mil610', 'Edificio Junge'],
#       dtype='object')

# %%
# personas.info()

# %%
# ruts_scrapped.info()

# %%
ruts_scrapped = pd.read_csv('..\\..\\Datos\\working\\ruts_scrapped_mod.csv',encoding = "ISO-8859-1")
ruts_scrapped.drop('Unnamed: 0',axis=1,inplace=True)
ruts_scrapped.head()
# Out:
#                                    Name           RUT Gender  \
# 0    SCHNEIDER BARRERA RICARDO ERNESTO   10.023.348-7   VAR
# 1      MORALES ESPINOZA CLAUDIO ANDRES   10.020.262-k   VAR
# 2   SALGADO VALENZUELA ALFREDO EDUARDO   10.019.023-0   VAR
# 3          MEIER PUCHEU SERGIO RODRIGO   10.016.093-5   VAR
# 4      TEMPIO ETCHEVERRY MAURO RODRIGO   10.015.654-7   VAR
#
#                              Adress                 Comuna
# 0                J  CISTERNAS 1612              LA SERENA
# 1   ALEJANDRO SEXTO 2787LZO ARENAS      CONCEPCION CENTRO
# 2         ANDALIEN 395 CHILLANCITO      CONCEPCION CENTRO
# 3            RALUN S/NLONCO PARQUE            CHIGUAYANTE
# 4                  LOS AVELLANOS 8    SAN PEDRO DE LA PAZ

# %%
print(len(personas['rut'].unique()))
print(personas.shape)
# Out:
# 6184
# (6184, 35)

# %%
personas = pd.merge(personas, ruts_scrapped,how='outer',left_on='rut',right_on='RUT')

# %%
personas.columns
# Out:
# Index(['is_apellido1', 'is_appelido2', 'is_celular', 'is_direccion', 'is_fnac',
#        'is_nombre', 'is_nombrecompleto', 'is_nrofam', 'is_profesion',
#        'is_recontacto', 'is_telefono', 'loc_comuna', 'loc_provincia',
#        'loc_region', 'max_rango_edad', 'mean_cot_bod', 'mean_cot_depto',
#        'mean_cot_esta', 'mean_cot_estu', 'medio_inicial', 'negocio',
#        'nro_cot_bod', 'nro_cot_depto', 'nro_cot_esta', 'nro_cot_estu',
#        'nro_proyectos', 'profesion', 'rut', 'sexo', 'tipo_cliente',
#        'Altos del Valle', 'Edificio Urban 1470', 'San Andres Del Valle',
#        'Edificio Mil610', 'Edificio Junge', 'Name', 'RUT', 'Gender', 'Adress',
#        'Comuna'],
#       dtype='object')

# %%
personas = personas.drop(['Name','Adress','Comuna','RUT'],axis=1)

# %%
# personas.info()

# %%
sb.factorplot(x='sexo', kind='count', data=personas);

# %%
def clean_sex(x,y):
#     print(x)
    x = str(x)
    x = x.replace(' ','')
    if x == 'VAR':
        return 'Masculino'
    elif x == 'MUJ':
        return 'Femenino'
    else:
        return y

personas['sexo'] = [clean_sex(x,y) for x,y in zip(personas['Gender'].values, personas['sexo'].values)]

# %%
personas.sexo = personas.sexo.fillna('Sin Información')
sb.factorplot(x='sexo', kind='count', data=personas);

# %%
personas = personas.drop(['Gender'],axis=1)

# %%
print(personas.tipo_cliente.isnull().sum())
personas.tipo_cliente = personas.tipo_cliente.fillna('Natural')
# Out:
# 87

# %% [markdown]
# # 5.Format Data

# %%
print(len(personas['rut'].unique()))
# Out:
# 6185

# %%
personas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6184 entries, 0 to 6183
# Data columns (total 35 columns):
# is_apellido1            6184 non-null object
# is_appelido2            6184 non-null object
# is_celular              6184 non-null object
# is_direccion            6184 non-null object
# is_fnac                 6184 non-null object
# is_nombre               6184 non-null object
# is_nombrecompleto       6184 non-null object
# is_nrofam               6184 non-null object
# is_profesion            6184 non-null object
# is_recontacto           6184 non-null object
# is_telefono             6184 non-null object
# loc_comuna              6184 non-null category
# loc_provincia           6184 non-null category
# loc_region              6184 non-null category
# max_rango_edad          6184 non-null float64
# mean_cot_bod            6184 non-null float64
# mean_cot_depto          6184 non-null float64
# mean_cot_esta           6184 non-null float64
# mean_cot_estu           6184 non-null float64
# medio_inicial           6184 non-null object
# negocio                 6184 non-null object
# nro_cot_bod             6184 non-null float64
# nro_cot_depto           6184 non-null float64
# nro_cot_esta            6184 non-null float64
# nro_cot_estu            6184 non-null float64
# nro_proyectos           6184 non-null float64
# profesion               6184 non-null category
# rut                     6184 non-null object
# sexo                    6184 non-null category
# tipo_cliente            6184 non-null category
# Altos del Valle         6184 non-null float64
# Edificio Urban 1470     6184 non-null float64
# San Andres Del Valle    6184 non-null float64
# Edificio Mil610         6184 non-null float64
# Edificio Junge          6184 non-null float64
# dtypes: category(6), float64(15), object(14)
# memory usage: 1.5+ MB

# %%
personas['loc_comuna'] = personas['loc_comuna'].astype('category')
personas['loc_provincia'] = personas['loc_provincia'].astype('category')
personas['loc_region'] = personas['loc_region'].astype('category')
personas['tipo_cliente'] = personas['tipo_cliente'].astype('category')
personas['sexo'] = personas['sexo'].astype('category')
personas['profesion'] = personas['profesion'].astype('category')
personas['medio_inicial'] = personas['medio_inicial'].astype('category')
personas = personas.dropna()

# %%
print(len(personas['rut'].unique()))
print(personas.shape)
# Out:
# 6184
# (6184, 35)

# %%
personas.to_csv('..\\..\\Datos\\working\\personas_cotizacion5.csv')
personas.to_excel('..\\..\\Datos\\working\\personas_cotizacion5.xlsx')

# %%
# personas.info()
# g = sb.factorplot(x='sexo', col='proyecto', kind='count', data=personas);
